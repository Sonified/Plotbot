# %%
import plotbot as pb
from plotbot import get_data
# Out:
# initialized server_access
# initialized global_tracker
# initialized ploptions
# initialized data_cubby
# initialized plot_manager
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=all
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=br
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bt
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bn
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bmag
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=pmag
# initialized mag_rtn_4sa class
# [ZARR] Using plot_options: data_type=mag_RTN, class=mag_rtn, subclass=all
# [ZARR] Using plot_options: data_type=mag_RTN, class=mag_rtn, subclass=br
# [ZARR] Using plot_options: data_type=mag_RTN, class=mag_rtn, subclass=bt
# [ZARR] Using plot_options: data_type=mag_RTN, class=mag_rtn, subclass=bn
# [ZARR] Using plot_options: data_type=mag_RTN, class=mag_rtn, subclass=bmag
# [ZARR] Using plot_options: data_type=mag_RTN, class=mag_rtn, subclass=pmag
# initialized mag_rtn class
# [ZARR] Using plot_options: data_type=mag_SC_4sa, class=mag_sc_4sa, subclass=all
# [ZARR] Using plot_options: data_type=mag_SC_4sa, class=mag_sc_4sa, subclass=bx
# [ZARR] Using plot_options: data_type=mag_SC_4sa, class=mag_sc_4sa, subclass=by
# [ZARR] Using plot_options: data_type=mag_SC_4sa, class=mag_sc_4sa, subclass=bz
# [ZARR] Using plot_options: data_type=mag_SC_4sa, class=mag_sc_4sa, subclass=bmag
# [ZARR] Using plot_options: data_type=mag_SC_4sa, class=mag_sc_4sa, subclass=pmag
# initialized mag_sc_4sa class
# [ZARR] Using plot_options: data_type=mag_SC, class=mag_sc, subclass=all
# [ZARR] Using plot_options: data_type=mag_SC, class=mag_sc, subclass=bx
# [ZARR] Using plot_options: data_type=mag_SC, class=mag_sc, subclass=by
# [ZARR] Using plot_options: data_type=mag_SC, class=mag_sc, subclass=bz
# [ZARR] Using plot_options: data_type=mag_SC, class=mag_sc, subclass=bmag
# [ZARR] Using plot_options: data_type=mag_SC, class=mag_sc, subclass=pmag
# initialized mag_sc class
# [ZARR] Using plot_options: data_type=spe_sf0_pad, class=epad, subclass=strahl
# [ZARR] Using plot_options: data_type=spe_sf0_pad, class=epad, subclass=centroids
# initialized epad class
# [ZARR] Using plot_options: data_type=spe_af0_pad, class=epad_hr, subclass=strahl
# [ZARR] Using plot_options: data_type=spe_af0_pad, class=epad_hr, subclass=centroids
# initialized epad_hr class
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=t_par
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=t_perp
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=anisotropy
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=v_alfven
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=v_sw
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=m_alfven
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=beta_ppar
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=beta_pperp
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=pressure_ppar
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=pressure_pperp
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=pressure
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=density
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=temperature
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=bmag
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=vr
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=vt
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=vn
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=energy_flux
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=theta_flux
# [ZARR] Using plot_options: data_type=spi_sf00_l3_mom, class=proton, subclass=phi_flux
# initialized proton class
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=t_par
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=t_perp
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=anisotropy
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=v_alfven
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=v_sw
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=m_alfven
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=beta_ppar
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=beta_pperp
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=pressure_ppar
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=pressure_pperp
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=pressure
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=density
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=temperature
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=bmag
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=vr
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=vt
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=vn
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=energy_flux
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=theta_flux
# [ZARR] Using plot_options: data_type=spi_af00_L3_mom, class=proton_hr, subclass=phi_flux
# initialized proton_hr class
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=qz_p
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vsw_mach_pfits
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=beta_ppar_pfits
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=beta_pperp_pfits
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=ham_param
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=np1
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=np2
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=n_tot
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=np2_np1_ratio
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vp1_x
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vp1_y
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vp1_z
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vp1_mag
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vcm_x
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vcm_y
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vcm_z
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vcm_mag
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vdrift
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vdrift_abs
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=vdrift_va_pfits
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Trat1
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Trat2
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Trat_tot
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Tpar1
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Tpar2
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Tpar_tot
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Tperp1
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Tperp2
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Tperp_tot
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=Temp_tot
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=abs_qz_p
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=chi_p
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=chi_p_norm
# [ZARR] Using plot_options: data_type=proton_fits, class=proton_fits, subclass=valfven_pfits
# initialized proton_fits class
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamstring
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamogram_30s
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamogram_og_30s
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamogram_2m
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamogram_og_2m
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamogram_20m
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamogram_90m
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamogram_4h
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=hamogram_og_4h
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=trat_ham
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=trat_ham_og
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=ham_core_drift
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=ham_core_drift_va
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=Nham_div_Ncore
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=Nham_div_Ncore_og
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=Nham_div_Ntot
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=Nham_div_Ntot_og
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=Tperp_ham_div_core
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=Tperp_ham_div_core_og
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=Tperprat_driftva_hc
# [ZARR] Using plot_options: data_type=ham, class=ham, subclass=Tperprat_driftva_hc_og
# initialized ham_class
# 🔉 initialized audifier
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Imported numpy, pandas, and scipy libraries.
# ✅ Imported matplotlib libraries.
# ✅ Imported cdflib, BeautifulSoup, requests, dateutil, and datetime libraries.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_05_03_v1.94
#    Commit: fix: v1.94: Make installer script universally robust to conda location, fix README folder casing
#
# 🤖 Plotbot Initialized

# %%
trange_test = ['2022-02-25 12:00:00', '2022-02-25 13:00:00']

# Call get_data on the actual data arrays, not the parent container
get_data(
    trange_test,
    pb.mag_rtn_4sa.br,
    pb.mag_rtn_4sa.bt,
    pb.mag_rtn_4sa.bn,
    pb.mag_rtn_4sa.bmag,
    pb.mag_rtn_4sa.pmag
)

# Print info about each component
for comp in ['br', 'bt', 'bn', 'bmag', 'pmag']:
    arr = getattr(pb.mag_rtn_4sa, comp, None)
    if arr is not None and hasattr(arr, 'shape'):
        print(f"{comp}: shape = {arr.shape}, first 3 values = {arr[:3]}")
    else:
        print(f"{comp}: not found or not loaded")
# Out:
# 03-May-25 19:30:09: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf to psp_data/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf
# 03-May-25 19:30:36: Download complete: psp_data/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=all
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=br
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bt
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bn
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bmag
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=pmag
# br: shape = (16479,), first 3 values = [-559.9504  -545.551   -551.91864]
# bt: shape = (16479,), first 3 values = [-125.6601  -134.86739 -160.42174]
# bn: shape = (16479,), first 3 values = [-173.14844 -209.96484 -168.59773]
# bmag: shape = (16479,), first 3 values = [599.42914 599.917   598.9779 ]
# pmag: shape = (16479,), first 3 values = [142.96701 143.19983 142.75186]

# %%
trange_test = ['2022-02-25 12:00:00', '2022-02-25 13:00:00']

# Call get_data on the actual data arrays, not the parent container
get_data(
    trange_test,
    pb.mag_rtn_4sa.br,
    pb.mag_rtn_4sa.bt,
    pb.mag_rtn_4sa.bn,
    pb.mag_rtn_4sa.bmag,
    pb.mag_rtn_4sa.pmag
)

# Print info about each component
for comp in ['br', 'bt', 'bn', 'bmag', 'pmag']:
    arr = getattr(pb.mag_rtn_4sa, comp, None)
    if arr is not None and hasattr(arr, 'shape'):
        print(f"{comp}: shape = {arr.shape}, first 3 values = {arr[:3]}")
    else:
        print(f"{comp}: not found or not loaded")
# Out:
# 03-May-25 19:30:09: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf to psp_data/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf
# 03-May-25 19:30:36: Download complete: psp_data/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=all
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=br
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bt
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bn
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bmag
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=pmag
# br: shape = (16479,), first 3 values = [-559.9504  -545.551   -551.91864]
# bt: shape = (16479,), first 3 values = [-125.6601  -134.86739 -160.42174]
# bn: shape = (16479,), first 3 values = [-173.14844 -209.96484 -168.59773]
# bmag: shape = (16479,), first 3 values = [599.42914 599.917   598.9779 ]
# pmag: shape = (16479,), first 3 values = [142.96701 143.19983 142.75186]

# %%
trange_test = ['2022-02-25 12:00:00', '2022-02-25 13:00:00']

# Call get_data on the actual data arrays, not the parent container
get_data(
    trange_test,
    pb.mag_rtn_4sa.br,
    pb.mag_rtn_4sa.bt,
    pb.mag_rtn_4sa.bn,
    pb.mag_rtn_4sa.bmag,
    pb.mag_rtn_4sa.pmag
)

# Print info about each component
for comp in ['br', 'bt', 'bn', 'bmag', 'pmag']:
    arr = getattr(pb.mag_rtn_4sa, comp, None)
    if arr is not None and hasattr(arr, 'shape'):
        print(f"{comp}: shape = {arr.shape}, first 3 values = {arr[:3]}")
    else:
        print(f"{comp}: not found or not loaded")
# Out:
# 03-May-25 19:30:09: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf to psp_data/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf
# 03-May-25 19:30:36: Download complete: psp_data/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=all
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=br
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bt
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bn
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=bmag
# [ZARR] Using plot_options: data_type=mag_RTN_4sa, class=mag_rtn_4sa, subclass=pmag
# br: shape = (16479,), first 3 values = [-559.9504  -545.551   -551.91864]
# bt: shape = (16479,), first 3 values = [-125.6601  -134.86739 -160.42174]
# bn: shape = (16479,), first 3 values = [-173.14844 -209.96484 -168.59773]
# bmag: shape = (16479,), first 3 values = [599.42914 599.917   598.9779 ]
# pmag: shape = (16479,), first 3 values = [142.96701 143.19983 142.75186]
