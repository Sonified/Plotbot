# %%
import plotbot
from plotbot import *
# Out:
# initialized server_access
# initialized global_tracker
# initialized ploptions
# initialized plot_manager
# initialized mag_rtn_4sa class
# initialized mag_rtn class
# initialized mag_sc_4sa class
# initialized mag_sc class
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized data_cubby
# initialized proton_fits class
# initialized ham_class
# 🔉 initialized audifier
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Imported numpy, pandas, and scipy libraries.
# ✅ Imported matplotlib libraries.
# ✅ Imported cdflib, BeautifulSoup, requests, dateutil, and datetime libraries.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_05_04_v2.03
# Commit: v2.03: Clone of f186bfc, follows an accidental github compression command that was not pushed, restoring balance in the universe
#
# 🤖 Plotbot Initialized

# %%
print_manager.show_data_snapshot= True  # Status prints, useful for status updates

data_snapshot.load_data_snapshot('full_mission_mag_rtn_4sa.pkl') 
from plotbot.data_tracker import global_tracker
print("Calculated Ranges:", global_tracker.calculated_ranges)
# Out:
# Starting load from data_snapshots/full_mission_mag_rtn_4sa.pkl
# Detected compression extension: .pkl
# Using no compression
# Data snapshot loaded from file. Keys: ['mag_rtn_4sa']
# Processing mag_rtn_4sa from snapshot (type: <class 'plotbot.data_classes.psp_mag_classes.mag_rtn_4sa_class'>)
#     Attempting restore_from_snapshot for mag_rtn_4sa into existing global instance (ID: 6041305888)...
#     - restore_from_snapshot successful for mag_rtn_4sa.
#     - Called set_ploptions on updated global instance for mag_rtn_4sa.
#     - Determined time range for mag_rtn_4sa: 2018-11-03/03:27:00.001 to 2025-03-25/22:41:59.811
#     - Repaired plot_manager state/options for mag_rtn_4sa.all
#     - Repaired plot_manager state/options for mag_rtn_4sa.bmag
#     - Repaired plot_manager state/options for mag_rtn_4sa.bn
#     - Repaired plot_manager state/options for mag_rtn_4sa.br
#     - Repaired plot_manager state/options for mag_rtn_4sa.bt
#     - Repaired plot_manager state/options for mag_rtn_4sa.pmag
# Updating DataTracker with loaded time ranges...
#    - Updated tracker for 'mag_rtn_4sa' with range: 2018-11-03/03:27:00.001 to 2025-03-25/22:41:59.811
# Calculated Ranges: {'mag_rtn_4sa': [(Timestamp('2018-11-03 03:27:00.001528576+0000', tz='UTC'), Timestamp('2025-03-25 22:41:59.811959552+0000', tz='UTC'))]}

# %%
config.data_server = 'berkeley'

# %%
#######-----📈📈📈📈📈 MULTIPLOTTING MAGIC 📉📉📉📉📉📉-----#######

rainbow_encounters = [
    {'perihelion': '2018/11/06 03:27:00.000'}, #Enc 1
    {'perihelion': '2019/04/04 22:39:00.000'}, #Enc 2
    {'perihelion': '2019/09/01 17:50:00.000'}, #Enc 3
    {'perihelion': '2020/01/29 09:37:00.000'}, #Enc 4
    {'perihelion': '2020/06/07 08:23:00.000'}, #Enc 5
    {'perihelion': '2020/09/27 09:16:00.000'}, #Enc 6
    {'perihelion': '2021/01/17 17:40:00.000'}, #Enc 7
    {'perihelion': '2021/04/29 08:48:00.000'}, #Enc 8
    {'perihelion': '2021/08/09 19:11:00.000'}, #Enc 9
    {'perihelion': '2021/11/21 08:23:00.000'}, #Enc 10
    {'perihelion': '2022/02/25 15:38:00.000'}, #Enc 11
    {'perihelion': '2022/06/01 22:51:00.000'}, #Enc 12
    {'perihelion': '2022/09/06 06:04:00.000'}, #Enc 13
    {'perihelion': '2022/12/11 13:16:00.000'}, #Enc 14
    {'perihelion': '2023/03/17 20:30:00.000'}, #Enc 15
    {'perihelion': '2023/06/22 03:46:00.000'}, #Enc 16
    {'perihelion': '2023/09/27 23:28:00.000'}, #Enc 17
    {'perihelion': '2023/12/29 00:56:00.000'}, #Enc 18
    {'perihelion': '2024/03/30 02:21:00.000'}, #Enc 19 
    {'perihelion': '2024/06/30 03:47:00.000'}, #Enc 20 Not yet publicly available
    {'perihelion': '2024/09/30 05:15:00.000'}, #Enc 21 Not yet publicly available
    {'perihelion': '2024/12/24 11:53:00.000'}, #Enc 22 Not yet publicly available
    {'perihelion': '2025/03/22 22:42:00.000'}, #Enc 23 Not yet publicly available
]

#====================================================================
# CONFIGURE PRINT MANAGER AND SERVER ACCESS
#====================================================================
print_manager.show_status = True  # Status prints, useful for status updates
# print_manager.show_debug = False  # Debug prints, helpful for debugging

server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.

# RESET PLOTTING OPTIONS (safe practice!)
#====================================================================
plt.options.reset() # Resetting options to ensure a clean slate

# ✨ ACTIVATE r_sunAXIS! ✨
#====================================================================
# plt.options.x_axis_r_sun = True  # Use radial distance (R_sun)
# plt.options.use_longitude_x_axis = False
# plt.options.x_axis_carrington_lon = False

plt.options.use_single_x_axis = False
plt.options.use_custom_x_axis_label = False
plt.options.custom_x_axis_label = None

plt.options.x_axis_positional_range = None

# CONFIGURE GENERAL PLOT OPTIONS
#====================================================================

plt.options.constrained_layout = False  # or False

plt.options.save_bbox_inches = 'tight' #or try  'tight', this setting overrides the margin settings

# Plot Sizing
plt.options.width = 20
plt.options.height_per_panel = 1.3
plt.options.hspace = .5

# Font Sizes and Padding
plt.options.title_font_size = 15
plt.options.title_y_position = .965
plt.options.title_pad = 10

plt.options.y_axis_label_font_size = 15
plt.options.x_axis_label_font_size = 15
plt.options.x_tick_label_font_size = 10
plt.options.y_tick_label_font_size = 10
plt.options.y_label_pad = 5
plt.options.x_label_pad = 7

plt.options.y_label_uses_encounter = True
plt.options.y_label_includes_time = False

# CONFIGURE Title
#====================================================================

plt.options.use_single_title = True
plt.options.single_title_text = "PSP FIELDS Mag RTN R-Sun At Perihelion for Multiple Encounters"

# CONFIGURE Vertical Line
#====================================================================

plt.options.draw_vertical_line = True
plt.options.vertical_line_width = 1
plt.options.vertical_line_color = 'red'
plt.options.vertical_line_style = '--'

# Rainbow Plot 🌈 -- Uncomment the second set for a single color plot!
#====================================================================
plt.options.color_mode = 'rainbow'  # Options: 'default', 'rainbow', 'single'
plt.options.single_color = None     # Used when color_mode = 'single'

# DATA SELECTION FOR PLOTTING
#====================================================================

plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!

plt.options.window = '144:00:00.000'
plt.options.position = 'around'  # Position options for multiplot: 'before', 'after', 'around'

# Create the plot data list using list comprehension
plot_data = [(encounter['perihelion'], plot_variable) for encounter in rainbow_encounters]

# CALL MULTIPLOT WITH UPDATED OPTIONS
#====================================================================
multiplot(plot_data); #You'll need server access to plot this variable! ✨Un-comment to Plot!
# Out:
# mag_rtn_4sa already calculated for the time range: 2018-11-03/03:27:00.000000 to 2018-11-09/03:27:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2019-04-01/22:39:00.000000 to 2019-04-07/22:39:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2019-08-29/17:50:00.000000 to 2019-09-04/17:50:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-01-26/09:37:00.000000 to 2020-02-01/09:37:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-02-22/15:38:00.000000 to 2022-02-28/15:38:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-05-29/22:51:00.000000 to 2022-06-04/22:51:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-09-03/06:04:00.000000 to 2022-09-09/06:04:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-12-08/13:16:00.000000 to 2022-12-14/13:16:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-03-14/20:30:00.000000 to 2023-03-20/20:30:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-06-19/03:46:00.000000 to 2023-06-25/03:46:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-09-24/23:28:00.000000 to 2023-09-30/23:28:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-12-26/00:56:00.000000 to 2024-01-01/00:56:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-03-27/02:21:00.000000 to 2024-04-02/02:21:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-06-27/03:47:00.000000 to 2024-07-03/03:47:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-09-27/05:15:00.000000 to 2024-10-03/05:15:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-12-21/11:53:00.000000 to 2024-12-27/11:53:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# Using constrained_layout=False and letting matplotlib handle all margins and spacing.
# Set margins (top=0.98, bottom=0.05, left=0.1, right=0.9) and hspace=0.5
# Panel 1 - HAM feature status: hamify=False, ham_var=False
# Panel 1: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 2 - HAM feature status: hamify=False, ham_var=False
# Panel 2: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 3 - HAM feature status: hamify=False, ham_var=False
# Panel 3: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 4 - HAM feature status: hamify=False, ham_var=False
# Panel 4: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 5 - HAM feature status: hamify=False, ham_var=False
# Panel 5: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 6 - HAM feature status: hamify=False, ham_var=False
# Panel 6: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 7 - HAM feature status: hamify=False, ham_var=False
# Panel 7: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 8 - HAM feature status: hamify=False, ham_var=False
# Panel 8: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 9 - HAM feature status: hamify=False, ham_var=False
# Panel 9: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 10 - HAM feature status: hamify=False, ham_var=False
# Panel 10: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 11 - HAM feature status: hamify=False, ham_var=False
# Panel 11: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 12 - HAM feature status: hamify=False, ham_var=False
# Panel 12: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 13 - HAM feature status: hamify=False, ham_var=False
# Panel 13: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 14 - HAM feature status: hamify=False, ham_var=False
# Panel 14: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 15 - HAM feature status: hamify=False, ham_var=False
# Panel 15: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 16 - HAM feature status: hamify=False, ham_var=False
# Panel 16: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 17 - HAM feature status: hamify=False, ham_var=False
# Panel 17: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 18 - HAM feature status: hamify=False, ham_var=False
# Panel 18: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 19 - HAM feature status: hamify=False, ham_var=False
# Panel 19: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 20 - HAM feature status: hamify=False, ham_var=False
# Panel 20: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 21 - HAM feature status: hamify=False, ham_var=False
# Panel 21: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 22 - HAM feature status: hamify=False, ham_var=False
# Panel 22: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 23 - HAM feature status: hamify=False, ham_var=False
# Panel 23: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Generating multiplot...

# %%
#######-----📈📈📈📈📈 MULTIPLOTTING MAGIC 📉📉📉📉📉📉-----#######

rainbow_encounters = [
    {'perihelion': '2018/11/06 03:27:00.000'}, #Enc 1
    {'perihelion': '2019/04/04 22:39:00.000'}, #Enc 2
    {'perihelion': '2019/09/01 17:50:00.000'}, #Enc 3
    {'perihelion': '2020/01/29 09:37:00.000'}, #Enc 4
    {'perihelion': '2020/06/07 08:23:00.000'}, #Enc 5
    {'perihelion': '2020/09/27 09:16:00.000'}, #Enc 6
    {'perihelion': '2021/01/17 17:40:00.000'}, #Enc 7
    {'perihelion': '2021/04/29 08:48:00.000'}, #Enc 8
    {'perihelion': '2021/08/09 19:11:00.000'}, #Enc 9
    {'perihelion': '2021/11/21 08:23:00.000'}, #Enc 10
    {'perihelion': '2022/02/25 15:38:00.000'}, #Enc 11
    {'perihelion': '2022/06/01 22:51:00.000'}, #Enc 12
    {'perihelion': '2022/09/06 06:04:00.000'}, #Enc 13
    {'perihelion': '2022/12/11 13:16:00.000'}, #Enc 14
    {'perihelion': '2023/03/17 20:30:00.000'}, #Enc 15
    {'perihelion': '2023/06/22 03:46:00.000'}, #Enc 16
    {'perihelion': '2023/09/27 23:28:00.000'}, #Enc 17
    {'perihelion': '2023/12/29 00:56:00.000'}, #Enc 18
    {'perihelion': '2024/03/30 02:21:00.000'}, #Enc 19 
    {'perihelion': '2024/06/30 03:47:00.000'}, #Enc 20 Not yet publicly available
    {'perihelion': '2024/09/30 05:15:00.000'}, #Enc 21 Not yet publicly available
    {'perihelion': '2024/12/24 11:53:00.000'}, #Enc 22 Not yet publicly available
    {'perihelion': '2025/03/22 22:42:00.000'}, #Enc 23 Not yet publicly available
]

#====================================================================
# CONFIGURE PRINT MANAGER AND SERVER ACCESS
#====================================================================
print_manager.show_status = True  # Status prints, useful for status updates
# print_manager.show_debug = False  # Debug prints, helpful for debugging

server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.

# RESET PLOTTING OPTIONS (safe practice!)
#====================================================================
plt.options.reset() # Resetting options to ensure a clean slate

# ✨ ACTIVATE r_sunAXIS! ✨
#====================================================================
# plt.options.x_axis_r_sun = True  # Use radial distance (R_sun)
# plt.options.use_longitude_x_axis = False
# plt.options.x_axis_carrington_lon = False

plt.options.use_single_x_axis = False
plt.options.use_custom_x_axis_label = False
plt.options.custom_x_axis_label = None

plt.options.x_axis_positional_range = None

# CONFIGURE GENERAL PLOT OPTIONS
#====================================================================

plt.options.constrained_layout = False  # or False

plt.options.save_bbox_inches = 'tight' #or try  'tight', this setting overrides the margin settings

# Plot Sizing
plt.options.width = 20
plt.options.height_per_panel = 1.3
plt.options.hspace = .5

# Font Sizes and Padding
plt.options.title_font_size = 15
plt.options.title_y_position = .965
plt.options.title_pad = 10

plt.options.y_axis_label_font_size = 15
plt.options.x_axis_label_font_size = 15
plt.options.x_tick_label_font_size = 10
plt.options.y_tick_label_font_size = 10
plt.options.y_label_pad = 5
plt.options.x_label_pad = 7

plt.options.y_label_uses_encounter = True
plt.options.y_label_includes_time = False

# CONFIGURE Title
#====================================================================

plt.options.use_single_title = True
plt.options.single_title_text = "PSP FIELDS Mag RTN R-Sun At Perihelion for Multiple Encounters"

# CONFIGURE Vertical Line
#====================================================================

plt.options.draw_vertical_line = True
plt.options.vertical_line_width = 1
plt.options.vertical_line_color = 'red'
plt.options.vertical_line_style = '--'

# Rainbow Plot 🌈 -- Uncomment the second set for a single color plot!
#====================================================================
plt.options.color_mode = 'rainbow'  # Options: 'default', 'rainbow', 'single'
plt.options.single_color = None     # Used when color_mode = 'single'

# DATA SELECTION FOR PLOTTING
#====================================================================

plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!

plt.options.window = '144:00:00.000'
plt.options.position = 'around'  # Position options for multiplot: 'before', 'after', 'around'

# Create the plot data list using list comprehension
plot_data = [(encounter['perihelion'], plot_variable) for encounter in rainbow_encounters]

# CALL MULTIPLOT WITH UPDATED OPTIONS
#====================================================================
multiplot(plot_data); #You'll need server access to plot this variable! ✨Un-comment to Plot!
# Out:
# mag_rtn_4sa already calculated for the time range: 2018-11-03/03:27:00.000000 to 2018-11-09/03:27:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2019-04-01/22:39:00.000000 to 2019-04-07/22:39:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2019-08-29/17:50:00.000000 to 2019-09-04/17:50:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-01-26/09:37:00.000000 to 2020-02-01/09:37:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-02-22/15:38:00.000000 to 2022-02-28/15:38:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-05-29/22:51:00.000000 to 2022-06-04/22:51:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-09-03/06:04:00.000000 to 2022-09-09/06:04:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-12-08/13:16:00.000000 to 2022-12-14/13:16:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-03-14/20:30:00.000000 to 2023-03-20/20:30:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-06-19/03:46:00.000000 to 2023-06-25/03:46:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-09-24/23:28:00.000000 to 2023-09-30/23:28:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-12-26/00:56:00.000000 to 2024-01-01/00:56:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-03-27/02:21:00.000000 to 2024-04-02/02:21:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-06-27/03:47:00.000000 to 2024-07-03/03:47:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-09-27/05:15:00.000000 to 2024-10-03/05:15:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-12-21/11:53:00.000000 to 2024-12-27/11:53:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# Using constrained_layout=False and letting matplotlib handle all margins and spacing.
# Set margins (top=0.98, bottom=0.05, left=0.1, right=0.9) and hspace=0.5
# Panel 1 - HAM feature status: hamify=False, ham_var=False
# Panel 1: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 2 - HAM feature status: hamify=False, ham_var=False
# Panel 2: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 3 - HAM feature status: hamify=False, ham_var=False
# Panel 3: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 4 - HAM feature status: hamify=False, ham_var=False
# Panel 4: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 5 - HAM feature status: hamify=False, ham_var=False
# Panel 5: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 6 - HAM feature status: hamify=False, ham_var=False
# Panel 6: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 7 - HAM feature status: hamify=False, ham_var=False
# Panel 7: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 8 - HAM feature status: hamify=False, ham_var=False
# Panel 8: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 9 - HAM feature status: hamify=False, ham_var=False
# Panel 9: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 10 - HAM feature status: hamify=False, ham_var=False
# Panel 10: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 11 - HAM feature status: hamify=False, ham_var=False
# Panel 11: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 12 - HAM feature status: hamify=False, ham_var=False
# Panel 12: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 13 - HAM feature status: hamify=False, ham_var=False
# Panel 13: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 14 - HAM feature status: hamify=False, ham_var=False
# Panel 14: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 15 - HAM feature status: hamify=False, ham_var=False
# Panel 15: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 16 - HAM feature status: hamify=False, ham_var=False
# Panel 16: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 17 - HAM feature status: hamify=False, ham_var=False
# Panel 17: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 18 - HAM feature status: hamify=False, ham_var=False
# Panel 18: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 19 - HAM feature status: hamify=False, ham_var=False
# Panel 19: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 20 - HAM feature status: hamify=False, ham_var=False
# Panel 20: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 21 - HAM feature status: hamify=False, ham_var=False
# Panel 21: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 22 - HAM feature status: hamify=False, ham_var=False
# Panel 22: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 23 - HAM feature status: hamify=False, ham_var=False
# Panel 23: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Generating multiplot...

# %%
#######-----📈📈📈📈📈 MULTIPLOTTING MAGIC 📉📉📉📉📉📉-----#######

rainbow_encounters = [
    {'perihelion': '2018/11/06 03:27:00.000'}, #Enc 1
    {'perihelion': '2019/04/04 22:39:00.000'}, #Enc 2
    {'perihelion': '2019/09/01 17:50:00.000'}, #Enc 3
    {'perihelion': '2020/01/29 09:37:00.000'}, #Enc 4
    {'perihelion': '2020/06/07 08:23:00.000'}, #Enc 5
    {'perihelion': '2020/09/27 09:16:00.000'}, #Enc 6
    {'perihelion': '2021/01/17 17:40:00.000'}, #Enc 7
    {'perihelion': '2021/04/29 08:48:00.000'}, #Enc 8
    {'perihelion': '2021/08/09 19:11:00.000'}, #Enc 9
    {'perihelion': '2021/11/21 08:23:00.000'}, #Enc 10
    {'perihelion': '2022/02/25 15:38:00.000'}, #Enc 11
    {'perihelion': '2022/06/01 22:51:00.000'}, #Enc 12
    {'perihelion': '2022/09/06 06:04:00.000'}, #Enc 13
    {'perihelion': '2022/12/11 13:16:00.000'}, #Enc 14
    {'perihelion': '2023/03/17 20:30:00.000'}, #Enc 15
    {'perihelion': '2023/06/22 03:46:00.000'}, #Enc 16
    {'perihelion': '2023/09/27 23:28:00.000'}, #Enc 17
    {'perihelion': '2023/12/29 00:56:00.000'}, #Enc 18
    {'perihelion': '2024/03/30 02:21:00.000'}, #Enc 19 
    {'perihelion': '2024/06/30 03:47:00.000'}, #Enc 20 Not yet publicly available
    {'perihelion': '2024/09/30 05:15:00.000'}, #Enc 21 Not yet publicly available
    {'perihelion': '2024/12/24 11:53:00.000'}, #Enc 22 Not yet publicly available
    {'perihelion': '2025/03/22 22:42:00.000'}, #Enc 23 Not yet publicly available
]

#====================================================================
# CONFIGURE PRINT MANAGER AND SERVER ACCESS
#====================================================================
print_manager.show_status = True  # Status prints, useful for status updates
# print_manager.show_debug = False  # Debug prints, helpful for debugging

server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.

# RESET PLOTTING OPTIONS (safe practice!)
#====================================================================
plt.options.reset() # Resetting options to ensure a clean slate

# ✨ ACTIVATE r_sunAXIS! ✨
#====================================================================
# plt.options.x_axis_r_sun = True  # Use radial distance (R_sun)
# plt.options.use_longitude_x_axis = False
# plt.options.x_axis_carrington_lon = False

plt.options.use_single_x_axis = False
plt.options.use_custom_x_axis_label = False
plt.options.custom_x_axis_label = None

plt.options.x_axis_positional_range = None

# CONFIGURE GENERAL PLOT OPTIONS
#====================================================================

plt.options.constrained_layout = False  # or False

plt.options.save_bbox_inches = 'tight' #or try  'tight', this setting overrides the margin settings

# Plot Sizing
plt.options.width = 20
plt.options.height_per_panel = 1.3
plt.options.hspace = .5

# Font Sizes and Padding
plt.options.title_font_size = 15
plt.options.title_y_position = .965
plt.options.title_pad = 10

plt.options.y_axis_label_font_size = 15
plt.options.x_axis_label_font_size = 15
plt.options.x_tick_label_font_size = 10
plt.options.y_tick_label_font_size = 10
plt.options.y_label_pad = 5
plt.options.x_label_pad = 7

plt.options.y_label_uses_encounter = True
plt.options.y_label_includes_time = False

# CONFIGURE Title
#====================================================================

plt.options.use_single_title = True
plt.options.single_title_text = "PSP FIELDS Mag RTN R-Sun At Perihelion for Multiple Encounters"

# CONFIGURE Vertical Line
#====================================================================

plt.options.draw_vertical_line = True
plt.options.vertical_line_width = 1
plt.options.vertical_line_color = 'red'
plt.options.vertical_line_style = '--'

# Rainbow Plot 🌈 -- Uncomment the second set for a single color plot!
#====================================================================
plt.options.color_mode = 'rainbow'  # Options: 'default', 'rainbow', 'single'
plt.options.single_color = None     # Used when color_mode = 'single'

# DATA SELECTION FOR PLOTTING
#====================================================================

plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!

plt.options.window = '144:00:00.000'
plt.options.position = 'around'  # Position options for multiplot: 'before', 'after', 'around'

# Create the plot data list using list comprehension
plot_data = [(encounter['perihelion'], plot_variable) for encounter in rainbow_encounters]

# CALL MULTIPLOT WITH UPDATED OPTIONS
#====================================================================
multiplot(plot_data); #You'll need server access to plot this variable! ✨Un-comment to Plot!
# Out:
# mag_rtn_4sa already calculated for the time range: 2018-11-03/03:27:00.000000 to 2018-11-09/03:27:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2019-04-01/22:39:00.000000 to 2019-04-07/22:39:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2019-08-29/17:50:00.000000 to 2019-09-04/17:50:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-01-26/09:37:00.000000 to 2020-02-01/09:37:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-02-22/15:38:00.000000 to 2022-02-28/15:38:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-05-29/22:51:00.000000 to 2022-06-04/22:51:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-09-03/06:04:00.000000 to 2022-09-09/06:04:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2022-12-08/13:16:00.000000 to 2022-12-14/13:16:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-03-14/20:30:00.000000 to 2023-03-20/20:30:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-06-19/03:46:00.000000 to 2023-06-25/03:46:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-09-24/23:28:00.000000 to 2023-09-30/23:28:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2023-12-26/00:56:00.000000 to 2024-01-01/00:56:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-03-27/02:21:00.000000 to 2024-04-02/02:21:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-06-27/03:47:00.000000 to 2024-07-03/03:47:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-09-27/05:15:00.000000 to 2024-10-03/05:15:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2024-12-21/11:53:00.000000 to 2024-12-27/11:53:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# mag_rtn_4sa already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing mag_rtn_4sa data, calculation/import not needed.
# ✅ Complete
# Using constrained_layout=False and letting matplotlib handle all margins and spacing.
# Set margins (top=0.98, bottom=0.05, left=0.1, right=0.9) and hspace=0.5
# Panel 1 - HAM feature status: hamify=False, ham_var=False
# Panel 1: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 2 - HAM feature status: hamify=False, ham_var=False
# Panel 2: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 3 - HAM feature status: hamify=False, ham_var=False
# Panel 3: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 4 - HAM feature status: hamify=False, ham_var=False
# Panel 4: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 5 - HAM feature status: hamify=False, ham_var=False
# Panel 5: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 6 - HAM feature status: hamify=False, ham_var=False
# Panel 6: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 7 - HAM feature status: hamify=False, ham_var=False
# Panel 7: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 8 - HAM feature status: hamify=False, ham_var=False
# Panel 8: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 9 - HAM feature status: hamify=False, ham_var=False
# Panel 9: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 10 - HAM feature status: hamify=False, ham_var=False
# Panel 10: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 11 - HAM feature status: hamify=False, ham_var=False
# Panel 11: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 12 - HAM feature status: hamify=False, ham_var=False
# Panel 12: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 13 - HAM feature status: hamify=False, ham_var=False
# Panel 13: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 14 - HAM feature status: hamify=False, ham_var=False
# Panel 14: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 15 - HAM feature status: hamify=False, ham_var=False
# Panel 15: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 16 - HAM feature status: hamify=False, ham_var=False
# Panel 16: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 17 - HAM feature status: hamify=False, ham_var=False
# Panel 17: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 18 - HAM feature status: hamify=False, ham_var=False
# Panel 18: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 19 - HAM feature status: hamify=False, ham_var=False
# Panel 19: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 20 - HAM feature status: hamify=False, ham_var=False
# Panel 20: Not plotting HAM data - conditions not met: hamify=False, ham_var=False, second_variable_on_right_axis=False
# Panel 21 - HAM feature status: hamify=False, ham_var=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 112
#     108 plot_data = [(encounter['perihelion'], plot_variable) for encounter in rainbow_encounters]
#     110 # CALL MULTIPLOT WITH UPDATED OPTIONS
#     111 #====================================================================
# --> 112 multiplot(plot_data); #You'll need server access to plot this variable! ✨Un-comment to Plot!
#
# File ~/GitHub/Plotbot/plotbot/multiplot.py:660, in multiplot(plot_list, **kwargs)
#     658     print_manager.debug(f"Panel {i+1} pre-clip: Requested trange: {trange[0]} to {trange[1]}")
#     659     # <<< END ADDED DEBUG PRINTS >>>
# --> 660     indices = time_clip(var.datetime_array, trange[0], trange[1])
#     661 else:
#     662     print_manager.warning(f"Empty datetime_array for panel {i+1} - cannot clip times")
#
# File ~/GitHub/Plotbot/plotbot/plotbot_helpers.py:94, in time_clip(datetime_array, start_time, end_time)
#      92 # Perform comparison using numpy datetime64
#      93 try:
# ---> 94     indices = np.where((datetime_array_np >= start_dt_np) &
#      95                        (datetime_array_np <= end_dt_np))[0]
#      96     print_manager.custom_debug(f"Successfully compared numpy datetime64 times, found {len(indices)} indices.")
#      97 except TypeError as e:
#      98     # This might happen if datetime_array_np contains incompatible types despite best efforts
#
# File /opt/anaconda3/envs/plotbot_env/lib/python3.12/site-packages/numpy/core/multiarray.py:346, in where(condition, x, y)
#     256     """
#     257     inner(a, b, /)
#     258
#    (...)    341
#     342     """
#     343     return (a, b)
# --> 346 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     347 def where(condition, x=None, y=None):
#     348     """
#     349     where(condition, [x, y], /)
#     350
#    (...)    416            [ 0,  3, -1]])
#     417     """
#     418     return (condition, x, y)
#
# KeyboardInterrupt:

# %%
print_manager.show_data_snapshot= True  # Status prints, useful for status updates

data_snapshot.load_data_snapshot('full_mission_mag_rtn_4sa.pkl')
# Out:
# Starting load from data_snapshots/full_mission_mag_rtn_4sa.pkl
# Detected compression extension: .pkl
# Using no compression
# Data snapshot loaded from file. Keys: ['mag_rtn_4sa']
# Processing mag_rtn_4sa from snapshot (type: <class 'plotbot.data_classes.psp_mag_classes.mag_rtn_4sa_class'>)
#     Attempting restore_from_snapshot for mag_rtn_4sa into existing global instance (ID: 5466860592)...
#     - restore_from_snapshot successful for mag_rtn_4sa.
#     - Called set_ploptions on updated global instance for mag_rtn_4sa.
#     - Determined time range for mag_rtn_4sa: 2018-11-03/03:27:00.001 to 2025-03-25/22:41:59.811
#     - Repaired plot_manager state/options for mag_rtn_4sa.all
#     - Repaired plot_manager state/options for mag_rtn_4sa.bmag
#     - Repaired plot_manager state/options for mag_rtn_4sa.bn
#     - Repaired plot_manager state/options for mag_rtn_4sa.br
#     - Repaired plot_manager state/options for mag_rtn_4sa.bt
#     - Repaired plot_manager state/options for mag_rtn_4sa.pmag
# Updating DataTracker with loaded time ranges...
#    - Updated tracker for 'mag_rtn_4sa' with range: 2018-11-03/03:27:00.001 to 2025-03-25/22:41:59.811
# Snapshot load finished from data_snapshots/full_mission_mag_rtn_4sa.pkl (Compression: none)
# True

# %%
#== It really can be this easy! ==
#Save all currently loaded data to an auto-named file
# data_snapshot.save_data_snapshot('full_mission_mag_rtn_4sa.pkl') 
#Load data back from a specific file (replace with your auto-generated name if needed)
# data_snapshot.load_data_snapshot('full_mission_mag_rtn_4sa.pkl') # Example filename
#=================================

# SAVE OPERATIONS
# data_snapshot.save_data_snapshot('auto')                        # Auto filename, all data
# data_snapshot.save_data_snapshot('mag_data.pkl', classes=['mag_rtn_4sa', 'mag_sc_4sa']) # Specific classes (optional)
# data_snapshot.save_data_snapshot('data.pkl', classes=pb.proton_fits)  # Class instance (optional)

# # COMPRESSION OPTIONS
# # none: fastest/largest | low: quick/good | medium: balanced | high: slowest/smallest
# data_snapshot.save_data_snapshot('data.pkl', compression="none|low|medium|high|gzip|bz2|lzma")

# # TIME FILTERING & SEGMENTATION
# data_snapshot.save_data_snapshot('data.pkl', auto_split=True)   # Auto-detect & split at time gaps
# data_snapshot.save_data_snapshot('data.pkl', time_range=['2021/04/26', '2021/05/02'])  # Filter by time
# data_snapshot.save_data_snapshot('auto', time_range=['2021/04/26', '2021/05/02'], 
#                      auto_split=True, compression="medium")  # Combined options

# # LOADING
# data_snapshot.load_data_snapshot('data.pkl')                    # Load everything
# data_snapshot.load_data_snapshot('data.pkl', classes=['mag_rtn_4sa'])  # Specific classes
# data_snapshot.load_data_snapshot('data.pkl', merge_segments=False)  # Keep segments separate

# AUTO FILENAME FORMAT: [variables]_from_[starttime]_to_[endtime]_[filtered]_[segmented].pkl
# Example: mag4+pro_from_20210426-000000_to_20210502-000000_filtered_segmented.pkl
