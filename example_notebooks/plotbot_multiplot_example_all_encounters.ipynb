# %%
import plotbot
from plotbot import *
# Out:
# 🕒 Starting import timing session: plotbot_full_initialization
#   ✅ matplotlib.pyplot: 0.257s
#   ✅ numpy: 0.000s
#   🔧 Starting block: core_components
# initialized server_access
# initialized global_tracker
# initialized ploptions
# initialized plot_manager
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized ham_class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# initialized data_cubby.
# CDF classes added to data_cubby type map.
#   ✅ Block 'core_components' completed in 0.692s
#   🔧 Starting block: psp_data_classes
# initialized proton_fits class
# initialized alpha_fits class
#   ✅ Block 'psp_data_classes' completed in 0.001s
#   🔧 Starting block: wind_data_classes
#   ✅ Block 'wind_data_classes' completed in 0.000s
#   🔧 Starting block: data_cubby_registration
#   ✅ Block 'data_cubby_registration' completed in 0.001s
#   🔧 Starting block: auto_register_custom_classes
#   ✅ Block 'auto_register_custom_classes' completed in 0.002s
#   🔧 Starting block: custom_variables
#   ✅ Block 'custom_variables' completed in 0.000s
# 🔉 initialized audifier
#   ✅ from plotbot import audifier: 0.105s
#   🔧 Starting block: enhanced_plt
#   ✅ Block 'enhanced_plt' completed in 0.000s
#   🔧 Starting block: main_plotting_functions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# ✅ Imported cdflib, BeautifulSoup, requests, dateutil, and datetime libraries.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#   ✅ Block 'main_plotting_functions' completed in 0.410s
#   🔧 Starting block: cdf_functions
#   ✅ Block 'cdf_functions' completed in 0.001s
#
# 🤖 Plotbot Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_09_10_v3.29
#    Commit: v3.29 Config: Set default data directory to 'default' in Plotbot.ipynb
#
#
# 🏁 Session 'plotbot_full_initialization' completed in 1.469s
#
# ============================================================
# 📊 IMPORT TIMING REPORT - plotbot_full_initialization
# ============================================================
# Total session time: 1.469s
#
# 🐌 SLOWEST IMPORTS (Top 3):
# --------------------------------------------------
#  1. matplotlib.pyplot               0.257s (71.0%)
#  2. from plotbot import audifier    0.105s (29.0%)
#  3. numpy                           0.000s ( 0.0%)
#
# 🔧 BLOCK TIMING SUMMARY:
# --------------------------------------------------
# core_components                 0.692s (avg: 0.692s, runs: 1)
# psp_data_classes                0.001s (avg: 0.001s, runs: 1)
# wind_data_classes               0.000s (avg: 0.000s, runs: 1)
# data_cubby_registration         0.001s (avg: 0.001s, runs: 1)
# auto_register_custom_classes    0.002s (avg: 0.002s, runs: 1)
# custom_variables                0.000s (avg: 0.000s, runs: 1)
# enhanced_plt                    0.000s (avg: 0.000s, runs: 1)
# main_plotting_functions         0.410s (avg: 0.410s, runs: 1)
# cdf_functions                   0.001s (avg: 0.001s, runs: 1)
#
# ⏰ IMPORT TIMELINE:
# --------------------------------------------------
#  0.000s: matplotlib.pyplot              (+0.257s)
#  0.257s: numpy                          (+0.000s)
#  0.953s: from plotbot import audifier   (+0.105s)
#
# 💡 OPTIMIZATION SUGGESTIONS:
# --------------------------------------------------
# • Matplotlib imports: 0.3s - good candidate for lazy loading
# • Focus optimization on imports >0.5s for maximum impact

# %%
# ------- 💽 CONFIGURE THE DEFAULT DATA DIRECTORY 💽 -------//
# This must be set before pyspedas is imported/run, as pyspedas caches configuration at import time.

config.data_dir = '../data'  # Go up one level to Plotbot/data/

import os
print(f"📁 Data directory absolute path: {os.path.abspath(config.data_dir)}")

# ------- 📡 CONFIGURE THE DEFAULT DATA SERVER 📡 -------//

config.data_server = 'berkeley'
# config.data_server = 'spdf'
# config.data_server = 'dynamic' #Will attempt to download from spdf first and then try berkeley

# ------- 🖨️ CONFIGURE PRINT MANAGER 🖨️ -------//
print_manager.show_status = True
# pm.show_debug = True      # Optional: uncomment for maximum detail
# pm.show_processing = True # Optional: uncomment for processing steps
# pm.show_datacubby = True  # Optional: uncomment for data caching steps
# Out:
# 📁 Plotbot data directory changed: data → ../data
# 🔧 SPEDAS_DATA_DIR updated for pyspedas compatibility
# 📁 Data directory absolute path: /Users/robertalexander/GitHub/Plotbot/data

# %%
print_manager.show_data_snapshot= True  # Status prints, useful for status updates

data_snapshot.load_data_snapshot('full_mission_mag_rtn_4sa.pkl') 
from plotbot.data_tracker import global_tracker
print("Calculated Ranges:", global_tracker.calculated_ranges)
# Out:
# DEBUG_LOAD_SNAPSHOT: Entered function load_data_snapshot
# Snapshot file not found in data_snapshots/ or root: full_mission_mag_rtn_4sa.pkl
# DEBUG_LOAD_SNAPSHOT: Returning False - file not found in data_snapshots/ or root
# Calculated Ranges: {}

# %%
config.data_server = 'berkeley'

# %%
#######-----📈📈📈📈📈 MULTIPLOTTING MAGIC 📉📉📉📉📉📉-----#######

rainbow_encounters = [
    {'perihelion': '2018/11/06 03:27:00.000'}, #Enc 1
    {'perihelion': '2019/04/04 22:39:00.000'}, #Enc 2
    {'perihelion': '2019/09/01 17:50:00.000'}, #Enc 3
    {'perihelion': '2020/01/29 09:37:00.000'}, #Enc 4
    {'perihelion': '2020/06/07 08:23:00.000'}, #Enc 5
    {'perihelion': '2020/09/27 09:16:00.000'}, #Enc 6
    {'perihelion': '2021/01/17 17:40:00.000'}, #Enc 7
    {'perihelion': '2021/04/29 08:48:00.000'}, #Enc 8
    {'perihelion': '2021/08/09 19:11:00.000'}, #Enc 9
    {'perihelion': '2021/11/21 08:23:00.000'}, #Enc 10
    {'perihelion': '2022/02/25 15:38:00.000'}, #Enc 11
    {'perihelion': '2022/06/01 22:51:00.000'}, #Enc 12
    {'perihelion': '2022/09/06 06:04:00.000'}, #Enc 13
    {'perihelion': '2022/12/11 13:16:00.000'}, #Enc 14
    {'perihelion': '2023/03/17 20:30:00.000'}, #Enc 15
    {'perihelion': '2023/06/22 03:46:00.000'}, #Enc 16
    {'perihelion': '2023/09/27 23:28:00.000'}, #Enc 17
    {'perihelion': '2023/12/29 00:56:00.000'}, #Enc 18
    {'perihelion': '2024/03/30 02:21:00.000'}, #Enc 19 
    {'perihelion': '2024/06/30 03:47:00.000'}, #Enc 20 
    {'perihelion': '2024/09/30 05:15:00.000'}, #Enc 21 
    {'perihelion': '2024/12/24 11:53:00.000'}, #Enc 22 Not yet publicly available
    {'perihelion': '2025/03/22 22:42:00.000'}, #Enc 23 Not yet publicly available
    {'perihelion': '2025/06/19 09:31:00.000'}, #Enc 24 
]

#====================================================================
# CONFIGURE PRINT MANAGER AND SERVER ACCESS
#====================================================================
print_manager.show_status = True  # Status prints, useful for status updates
# print_manager.show_debug = False  # Debug prints, helpful for debugging

server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.

# RESET PLOTTING OPTIONS (safe practice!)
#====================================================================
plt.options.reset() # Resetting options to ensure a clean slate

# ✨ ACTIVATE r_sunAXIS! ✨
#====================================================================
# plt.options.x_axis_r_sun = True  # Use radial distance (R_sun)
# plt.options.use_longitude_x_axis = False
# plt.options.x_axis_carrington_lon = False

plt.options.use_single_x_axis = True
plt.options.use_custom_x_axis_label = False
plt.options.custom_x_axis_label = None

plt.options.x_axis_positional_range = None

# CONFIGURE GENERAL PLOT OPTIONS
#====================================================================

plt.options.constrained_layout = False  # True or False
plt.options.save_bbox_inches = 'tight' #options are 'none' and 'tight', this setting overrides the margin settings

# Plot Sizing
plt.options.width = 20
plt.options.height_per_panel = 1.3
plt.options.hspace = .15

# TITLE handling
plt.options.margin_top = 0.85 
plt.options.margin_bottom = 0.05
plt.options.title_font_size = 20
plt.options.title_y_position = 1.05
plt.options.title_pad = 10

# Font Sizes and Padding
plt.options.y_axis_label_font_size = 22
plt.options.x_axis_label_font_size = 22
plt.options.x_tick_label_font_size = 17
plt.options.y_tick_label_font_size = 17
plt.options.y_label_pad = 8
plt.options.x_label_pad = 7

plt.options.y_label_uses_encounter = True
plt.options.y_label_includes_time = False

# CONFIGURE Title
#====================================================================

plt.options.use_single_title = True
plt.options.single_title_text = "PSP FIELDS Br Component Around Perihelion for Multiple Encounters"

# CONFIGURE Vertical Line
#====================================================================

plt.options.draw_vertical_line = True
plt.options.vertical_line_width = 1
plt.options.vertical_line_color = 'red'
plt.options.vertical_line_style = '--'

# CONFIGURE Relative x-axis time handling
#====================================================================
plt.options.use_relative_time = True
plt.options.relative_time_step_units = 'days'
plt.options.relative_time_step = 1

# Rainbow Plot 🌈 -- Uncomment the second set for a single color plot!
#====================================================================
plt.options.color_mode = 'rainbow'  # Options: 'default', 'rainbow', 'single'
plt.options.single_color = None     # Used when color_mode = 'single'

# DATA SELECTION FOR PLOTTING
#====================================================================

plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!

# Check current window setting
# print(f"Current window setting: {plt.options.window}")

plt.options.window = '144:00:00.000'  # ← 6 days total = ±3 days around perihelion
# plt.options.window = '96:00:00.000'   # ← 4 days total = ±2 days around perihelion  
# plt.options.window = '12:00:00.000'   # ← 12 hours total = ±6 hours around perihelion
plt.options.position = 'around'  # Position options for multiplot: 'before', 'after', 'around'

# print(f"Set window to: {plt.options.window}")
# plt.options.custom_x_axis_label

# Create the plot data list using list comprehension
plot_data = [(encounter['perihelion'], plot_variable) for encounter in rainbow_encounters]

DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E24: Variable contains 2928593 data points
# Using constrained_layout=False - applying manual margins.
# Set margins (top=0.85, bottom=0.05, left=0.1, right=0.9) and hspace=0.15
# 🎨 PLOTTING ENCOUNTER E1 (Panel 1) - Center time: 2018/11/06 03:27:00.000
# ✅ ENCOUNTER E1: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E2 (Panel 2) - Center time: 2019/04/04 22:39:00.000
# ✅ ENCOUNTER E2: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E3 (Panel 3) - Center time: 2019/09/01 17:50:00.000
# ✅ ENCOUNTER E3: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E4 (Panel 4) - Center time: 2020/01/29 09:37:00.000
# ✅ ENCOUNTER E4: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E5 (Panel 5) - Center time: 2020/06/07 08:23:00.000
# ✅ ENCOUNTER E5: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E6 (Panel 6) - Center time: 2020/09/27 09:16:00.000
# ✅ ENCOUNTER E6: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E7 (Panel 7) - Center time: 2021/01/17 17:40:00.000
# ✅ ENCOUNTER E7: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E8 (Panel 8) - Center time: 2021/04/29 08:48:00.000
# ✅ ENCOUNTER E8: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E9 (Panel 9) - Center time: 2021/08/09 19:11:00.000
# ✅ ENCOUNTER E9: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E10 (Panel 10) - Center time: 2021/11/21 08:23:00.000
# ✅ ENCOUNTER E10: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E11 (Panel 11) - Center time: 2022/02/25 15:38:00.000
# ✅ ENCOUNTER E11: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E12 (Panel 12) - Center time: 2022/06/01 22:51:00.000
# ✅ ENCOUNTER E12: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E13 (Panel 13) - Center time: 2022/09/06 06:04:00.000
# ✅ ENCOUNTER E13: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E14 (Panel 14) - Center time: 2022/12/11 13:16:00.000
# ✅ ENCOUNTER E14: Ready to plot with 2928593 data points
# 🔍 DEBUG E14: Found 2373031 time indices
# 🔍 DEBUG E14: Data shape: (57506849,)
# 🔍 DEBUG E14: Time range: 2022-12-08T13:16:00.172889088 to 2022-12-14T13:15:59.995070720
# 🎨 PLOTTING ENCOUNTER E15 (Panel 15) - Center time: 2023/03/17 20:30:00.000
# ✅ ENCOUNTER E15: Ready to plot with 2928593 data points
# 🔍 DEBUG E15: Found 2373032 time indices
# 🔍 DEBUG E15: Data shape: (57506849,)
# 🔍 DEBUG E15: Time range: 2023-03-14T20:30:00.027689728 to 2023-03-20T20:29:59.895298176
# 🎨 PLOTTING ENCOUNTER E16 (Panel 16) - Center time: 2023/06/22 03:46:00.000
# ✅ ENCOUNTER E16: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E17 (Panel 17) - Center time: 2023/09/27 23:28:00.000
# ✅ ENCOUNTER E17: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E18 (Panel 18) - Center time: 2023/12/29 00:56:00.000
# ✅ ENCOUNTER E18: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E19 (Panel 19) - Center time: 2024/03/30 02:21:00.000
# ✅ ENCOUNTER E19: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E20 (Panel 20) - Center time: 2024/06/30 03:47:00.000
# ✅ ENCOUNTER E20: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E21 (Panel 21) - Center time: 2024/09/30 05:15:00.000
# ✅ ENCOUNTER E21: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E22 (Panel 22) - Center time: 2024/12/24 11:53:00.000
# ✅ ENCOUNTER E22: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E23 (Panel 23) - Center time: 2025/03/22 22:42:00.000
# ✅ ENCOUNTER E23: Ready to plot with 2928593 data points
# 🎨 PLOTTING ENCOUNTER E24 (Panel 24) - Center time: 2025/06/19 09:31:00.000
# ✅ ENCOUNTER E24: Ready to plot with 2928593 data points
# Generating multiplot...
