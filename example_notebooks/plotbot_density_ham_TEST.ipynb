# %%
# Import plotbot
import sys
sys.path.insert(0, '..')

from plotbot import *
# Out:
# initialized server_access
# initialized global_tracker
# initialized plot_config
# initialized data_cubby.
# initialized plot_manager
# CDF classes added to data_cubby type map.
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized proton_fits class
# initialized alpha_fits class
# initialized ham_class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# 🎛️ initialized ploptions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# ✅ Deferred heavy data libraries (cdflib, requests, bs4) - loaded when needed.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#
# 🤖 Plotbot Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_10_28_v3.73
#    Commit: v3.73 Bugfix: Fixed WIND data local file detection and x-axis time formatting for short time ranges at midnight
#
# Import timing is disabled.

# %%
print_manager.show_status = True
print_manager.show_debug = True
print_manager.show_data_cubby = True

# %%
trange = ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']

# %%
# Create 2-panel plot: density (top, panel 1) and hamogram_30s (bottom, panel 2)
plotbot(trange, proton.density, 1, ham.hamogram_30s, 2)
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🕒 TimeRangeTracker: Cleared trange
# 🛰️ ham - acquiring variables: hamogram_30s
# 🛰️ spi_sf00_l3_mom - acquiring variables: density
# [CUBBY]
# === Retrieving proton from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/example_notebooks/../plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved proton with type <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6300109040 for key 'proton'. dt_len: 49374, min: 2025-03-20T00:00:02.896410240, max: 2025-03-20T23:59:58.803132288
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(49374,), range=2025-03-20T00:00:02.896410 to 2025-03-20T23:59:58.803132
# [CUBBY] GRAB OUTPUT - raw_data keys=['vr', 'vt', 'vn', 't_par', 't_perp', 'anisotropy', 'v_alfven', 'beta_ppar', 'beta_pperp', 'pressure_ppar', 'pressure_pperp', 'energy_flux', 'theta_flux', 'phi_flux', 'v_sw', 'm_alfven', 'temperature', 'pressure', 'density', 'bmag', 'sun_dist_rsun', 'ENERGY_VALS', 'THETA_VALS', 'PHI_VALS'] | vr: type=ndarray, shape=(49374,) | vt: type=ndarray, shape=(49374,) | vn: type=ndarray, shape=(49374,) | t_par: type=ndarray, shape=(49374,) | t_perp: type=ndarray, shape=(49374,) | anisotropy: type=ndarray, shape=(49374,) | v_alfven: type=ndarray, shape=(49374,) | beta_ppar: type=ndarray, shape=(49374,) | beta_pperp: type=ndarray, shape=(49374,) | pressure_ppar: type=ndarray, shape=(49374,) | pressure_pperp: type=ndarray, shape=(49374,) | energy_flux: type=ndarray, shape=(49374, 32) | theta_flux: type=ndarray, shape=(49374, 8) | phi_flux: type=ndarray, shape=(49374, 8) | v_sw: type=ndarray, shape=(49374,) | m_alfven: type=ndarray, shape=(49374,) | temperature: type=ndarray, shape=(49374,) | pressure: type=ndarray, shape=(49374,) | density: type=ndarray, shape=(49374,) | bmag: type=ndarray, shape=(49374,) | sun_dist_rsun: type=ndarray, shape=(49374,) | ENERGY_VALS: type=ndarray, shape=(49374, 32) | THETA_VALS: type=ndarray, shape=(49374, 8) | PHI_VALS: type=ndarray, shape=(49374, 8)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
# [CUBBY]
# === Retrieving ham from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/example_notebooks/../plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved ham with type <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6300337936 for key 'ham'. dt_len: 24687, min: 2025-03-20T00:00:02.896000000, max: 2025-03-20T23:59:58.803000000
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(24687,), range=2025-03-20T00:00:02.896 to 2025-03-20T23:59:58.803
# [CUBBY] GRAB OUTPUT - raw_data keys=['hamstring', 'hamstring_og', 'hamstring_dt', 'N_core', 'N_core_og', 'N_neck', 'N_neck_og', 'N_ham', 'N_ham_og', 'hamogram_30s', 'hamogram_og_30s', 'hamogram_1m', 'hamogram_og_1m', 'hamogram_2m', 'hamogram_og_2m', 'hamogram_20m', 'hamogram_og_20m', 'hamogram_90m', 'hamogram_og_90m', 'hamogram_4h', 'hamogram_og_4h', 'hamogram_12h', 'hamogram_og_12h', 'trat_ham', 'trat_ham_og', 'ham_core_drift', 'ham_core_drift_va', 'Nham_div_Ncore', 'Nham_div_Ncore_og', 'Nham_div_Ntot', 'Nham_div_Ntot_og', 'Tperp_ham_div_core', 'Tperp_ham_div_core_og', 'Tperprat_driftva_hc', 'Tperprat_driftva_hc_og'] | hamstring: type=NoneType, shape=N/A | hamstring_og: type=NoneType, shape=N/A | hamstring_dt: type=NoneType, shape=N/A | N_core: type=NoneType, shape=N/A | N_core_og: type=NoneType, shape=N/A | N_neck: type=NoneType, shape=N/A | N_neck_og: type=NoneType, shape=N/A | N_ham: type=NoneType, shape=N/A | N_ham_og: type=NoneType, shape=N/A | hamogram_30s: type=ndarray, shape=(24687,) | hamogram_og_30s: type=ndarray, shape=(24687,) | hamogram_1m: type=NoneType, shape=N/A | hamogram_og_1m: type=NoneType, shape=N/A | hamogram_2m: type=ndarray, shape=(24687,) | hamogram_og_2m: type=ndarray, shape=(24687,) | hamogram_20m: type=ndarray, shape=(24687,) | hamogram_og_20m: type=NoneType, shape=N/A | hamogram_90m: type=ndarray, shape=(24687,) | hamogram_og_90m: type=NoneType, shape=N/A | hamogram_4h: type=ndarray, shape=(24687,) | hamogram_og_4h: type=ndarray, shape=(24687,) | hamogram_12h: type=NoneType, shape=N/A | hamogram_og_12h: type=NoneType, shape=N/A | trat_ham: type=ndarray, shape=(24687,) | trat_ham_og: type=ndarray, shape=(24687,) | ham_core_drift: type=ndarray, shape=(24687,) | ham_core_drift_va: type=ndarray, shape=(24687,) | Nham_div_Ncore: type=ndarray, shape=(24687,) | Nham_div_Ncore_og: type=ndarray, shape=(24687,) | Nham_div_Ntot: type=ndarray, shape=(24687,) | Nham_div_Ntot_og: type=ndarray, shape=(24687,) | Tperp_ham_div_core: type=ndarray, shape=(24687,) | Tperp_ham_div_core_og: type=ndarray, shape=(24687,) | Tperprat_driftva_hc: type=ndarray, shape=(24687,) | Tperprat_driftva_hc_og: type=ndarray, shape=(24687,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
#
# 📥 Acquiring data for 2 variables...
# 🕒 TimeRangeTracker: Stored trange ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
# 🛰️ ham - acquiring variables: hamogram_30s
# 🛰️ spi_sf00_l3_mom - acquiring variables: density
# 📋 Required data types: {'ham', 'spi_sf00_l3_mom'}
# 🔄 Processing: ham
# [CUBBY]
# === Retrieving ham from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/example_notebooks/../plotbot/get_data.py:425
# [CUBBY] GRAB SUCCESS - Retrieved ham with type <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6300337936 for key 'ham'. dt_len: 24687, min: 2025-03-20T00:00:02.896000000, max: 2025-03-20T23:59:58.803000000
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(24687,), range=2025-03-20T00:00:02.896 to 2025-03-20T23:59:58.803
# [CUBBY] GRAB OUTPUT - raw_data keys=['hamstring', 'hamstring_og', 'hamstring_dt', 'N_core', 'N_core_og', 'N_neck', 'N_neck_og', 'N_ham', 'N_ham_og', 'hamogram_30s', 'hamogram_og_30s', 'hamogram_1m', 'hamogram_og_1m', 'hamogram_2m', 'hamogram_og_2m', 'hamogram_20m', 'hamogram_og_20m', 'hamogram_90m', 'hamogram_og_90m', 'hamogram_4h', 'hamogram_og_4h', 'hamogram_12h', 'hamogram_og_12h', 'trat_ham', 'trat_ham_og', 'ham_core_drift', 'ham_core_drift_va', 'Nham_div_Ncore', 'Nham_div_Ncore_og', 'Nham_div_Ntot', 'Nham_div_Ntot_og', 'Tperp_ham_div_core', 'Tperp_ham_div_core_og', 'Tperprat_driftva_hc', 'Tperprat_driftva_hc_og'] | hamstring: type=NoneType, shape=N/A | hamstring_og: type=NoneType, shape=N/A | hamstring_dt: type=NoneType, shape=N/A | N_core: type=NoneType, shape=N/A | N_core_og: type=NoneType, shape=N/A | N_neck: type=NoneType, shape=N/A | N_neck_og: type=NoneType, shape=N/A | N_ham: type=NoneType, shape=N/A | N_ham_og: type=NoneType, shape=N/A | hamogram_30s: type=ndarray, shape=(24687,) | hamogram_og_30s: type=ndarray, shape=(24687,) | hamogram_1m: type=NoneType, shape=N/A | hamogram_og_1m: type=NoneType, shape=N/A | hamogram_2m: type=ndarray, shape=(24687,) | hamogram_og_2m: type=ndarray, shape=(24687,) | hamogram_20m: type=ndarray, shape=(24687,) | hamogram_og_20m: type=NoneType, shape=N/A | hamogram_90m: type=ndarray, shape=(24687,) | hamogram_og_90m: type=NoneType, shape=N/A | hamogram_4h: type=ndarray, shape=(24687,) | hamogram_og_4h: type=ndarray, shape=(24687,) | hamogram_12h: type=NoneType, shape=N/A | hamogram_og_12h: type=NoneType, shape=N/A | trat_ham: type=ndarray, shape=(24687,) | trat_ham_og: type=ndarray, shape=(24687,) | ham_core_drift: type=ndarray, shape=(24687,) | ham_core_drift_va: type=ndarray, shape=(24687,) | Nham_div_Ncore: type=ndarray, shape=(24687,) | Nham_div_Ncore_og: type=ndarray, shape=(24687,) | Nham_div_Ntot: type=ndarray, shape=(24687,) | Nham_div_Ntot_og: type=ndarray, shape=(24687,) | Tperp_ham_div_core: type=ndarray, shape=(24687,) | Tperp_ham_div_core_og: type=ndarray, shape=(24687,) | Tperprat_driftva_hc: type=ndarray, shape=(24687,) | Tperprat_driftva_hc_og: type=ndarray, shape=(24687,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Import data function called
# Input trange: ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
#
# Importing data for UTC time range: ['2025-03-20/00:00:00', '2025-03-22/00:00:00']
#
# === Starting Hammerhead CSV Data Import for ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000'] ===
# daterange called with start_date=2025-03-20 00:00:00+00:00, end_date=2025-03-22 00:00:00+00:00
# End date is midnight, adjusting to previous day: 2025-03-21
# Converted start_date to date: 2025-03-20
# Will generate 2 dates
# Yielding date: 2025-03-20
# Searching for Hammerhead CSV for date: 20250320
#  Searching ham in: /Users/robertalexander/GitHub/Plotbot/data/psp/Hamstrings with patterns: ['*_v*.csv']
# Searching for CSVs in '/Users/robertalexander/GitHub/Plotbot/data/psp/Hamstrings' for patterns ['*_v*.csv'] and dates ['20250320', '2025-03-20']
#   Found matching file: /Users/robertalexander/GitHub/Plotbot/data/psp/Hamstrings/2025/03/2025-03-20_v00.csv
#   Found ham file: '2025-03-20_v00.csv'
# Converted HAM 'time' to TT2000 (Length: 24687)
# Yielding date: 2025-03-21
# Searching for Hammerhead CSV for date: 20250321
#  Searching ham in: /Users/robertalexander/GitHub/Plotbot/data/psp/Hamstrings with patterns: ['*_v*.csv']
# Searching for CSVs in '/Users/robertalexander/GitHub/Plotbot/data/psp/Hamstrings' for patterns ['*_v*.csv'] and dates ['20250321', '2025-03-21']
#   Found matching file: /Users/robertalexander/GitHub/Plotbot/data/psp/Hamstrings/2025/03/2025-03-21_v00.csv
#   Found ham file: '2025-03-21_v00.csv'
# Converted HAM 'time' to TT2000 (Length: 26032)
# Successfully loaded Hammerhead data with 50719 time points
# *** IMPORT_DATA_DEBUG (HAM Path) for data_type 'ham' (originally requested: 'ham') ***
# 📥 Requesting DataCubby to update/merge global instance for ham...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'ham' -> 'ham' -> <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Searching for instance of type <class 'plotbot.data_classes.psp_ham_classes.ham_class'> in class_registry with 33 entries
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_auto' -> <class 'plotbot.data_classes.custom_classes.psp_waves_auto.psp_waves_auto_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.demo_spectral_waves.demo_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_wave_power' -> <class 'plotbot.data_classes.custom_classes.demo_wave_power.demo_wave_power_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_real_test' -> <class 'plotbot.data_classes.custom_classes.psp_waves_real_test.psp_waves_real_test_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.psp_spectral_waves.psp_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'alpha_fits' -> <class 'plotbot.data_classes.psp_alpha_fits_classes.alpha_fits_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn' -> <class 'plotbot.data_classes.psp_mag_rtn.mag_rtn_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_sc_4sa' -> <class 'plotbot.data_classes.psp_mag_sc_4sa.mag_sc_4sa_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_sc' -> <class 'plotbot.data_classes.psp_mag_sc.mag_sc_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'epad' -> <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'epad_hr' -> <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_high_res_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'proton' -> <class 'plotbot.data_classes.psp_proton.proton_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'proton_hr' -> <class 'plotbot.data_classes.psp_proton_hr.proton_hr_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'proton_fits' -> <class 'plotbot.data_classes.psp_proton_fits_classes.proton_fits_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'ham' -> <class 'plotbot.data_classes.psp_ham_classes.ham_class'> vs target <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] ✅ MATCH FOUND by type lookup
# 🔍 PATH ANALYSIS for 'ham' (class: ham_class)
#    📊 datetime_array_exists: True, not_none: True, length: 24687
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'ham'
# [CUBBY] Global instance has existing data. Attempting merge...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'ham' -> 'ham' -> <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] Processing new imported data into temporary instance...
# Ham class: No data provided; initialized with empty attributes.
# Successfully converted 50719 TT2000 timestamps to datetime objects.
# Assigned data for key: hamogram_30s, shape: (50719,)
# Assigned data for key: hamogram_og_30s, shape: (50719,)
# Assigned data for key: hamogram_2m, shape: (50719,)
# Assigned data for key: hamogram_og_2m, shape: (50719,)
# Assigned data for key: hamogram_20m, shape: (50719,)
# Assigned data for key: hamogram_90m, shape: (50719,)
# Assigned data for key: hamogram_4h, shape: (50719,)
# Assigned data for key: hamogram_og_4h, shape: (50719,)
# Assigned data for key: trat_ham, shape: (50719,)
# Assigned data for key: trat_ham_og, shape: (50719,)
# Assigned data for key: ham_core_drift, shape: (50719,)
# Assigned data for key: ham_core_drift_va, shape: (50719,)
# Assigned data for key: Nham_div_Ncore, shape: (50719,)
# Assigned data for key: Nham_div_Ncore_og, shape: (50719,)
# Assigned data for key: Nham_div_Ntot, shape: (50719,)
# Assigned data for key: Nham_div_Ntot_og, shape: (50719,)
# Assigned data for key: Tperp_ham_div_core, shape: (50719,)
# Assigned data for key: Tperp_ham_div_core_og, shape: (50719,)
# Assigned data for key: Tperprat_driftva_hc, shape: (50719,)
# Assigned data for key: Tperprat_driftva_hc_og, shape: (50719,)
# [CUBBY] ✅ New data processed.
# [CUBBY] Calling _merge_arrays...
# [CUBBY]
# 🔥 ULTIMATE MERGE ENGINE ACTIVATED 🔥
# [CUBBY] 📊 MERGE STATS:
# [CUBBY]    Existing: 24,687 records
# [CUBBY]    New: 50,719 records
# [CUBBY]    Potential total: 75,406 records
# [CUBBY] 🔄 OVERLAP DETECTED - Full merge required
# [CUBBY] ⚡ Computing unique merged times...
# [CUBBY] ✅ Unique times: 50,719 records (24,687 duplicates removed)
# [CUBBY] 🏎️ SPEED MODE: Using vectorized processing
# [CUBBY] ⚠️ Skipping key 'hamogram_og_90m' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'N_core' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'hamstring_og' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'hamstring' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'hamogram_og_1m' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'hamstring_dt' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'N_ham_og' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'hamogram_og_20m' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'N_neck' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'hamogram_1m' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'N_core_og' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'hamogram_12h' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'hamogram_og_12h' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'N_ham' - both arrays are None
# [CUBBY] ⚠️ Skipping key 'N_neck_og' - both arrays are None
# [CUBBY] 🏁 MERGE COMPLETE!
# [CUBBY]    Final records: 50,719
# [CUBBY]    Duration: 0.15s
# [CUBBY]    Speed: 333,254 records/sec
# [CUBBY]    Session total: 50,719 records
# [CUBBY]    Session avg: 333,254 records/sec
# ✅ DataCubby processed update for ham.
# Updated and merged ranges for ham: [(datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 3, 22, 0, 0, tzinfo=datetime.timezone.utc))]
# 🔄 Processing: spi_sf00_l3_mom
# [CUBBY]
# === Retrieving spi_sf00_l3_mom from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/example_notebooks/../plotbot/get_data.py:425
# [CUBBY] GRAB FAIL - Failed to retrieve spi_sf00_l3_mom
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Attempting SPDF acquisition path (dynamic mode) for spi_sf00_l3_mom...
# [DOWNLOAD_SPDF_ENTRY] Received trange: ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000'], data_type: spi_sf00_l3_mom
# Attempting SPDF download for spi_sf00_l3_mom in range ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
# ✅ Smart check found 6 local spi_sf00_l3_mom file(s):
#    📁 /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250320_v00.cdf
#    📁 /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250320_v04.cdf
#    📁 /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250321_v04.cdf
#    📁 /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250321_v00.cdf
#    📁 /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250322_v04.cdf
#    📁 /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250322_v00.cdf
# ✅ Using local spi_sf00_l3_mom files (skipping pyspedas)
# Import data function called
# Input trange: ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
#
# Importing data for UTC time range: ['2025-03-20/00:00:00', '2025-03-22/00:00:00']
#   Requested datetime range (from TT2000 conversion): 2025-03-20T00:00:00.000000000 to 2025-03-22T00:00:00.000000000
# daterange called with start_date=2025-03-20 00:00:00+00:00, end_date=2025-03-22 00:00:00+00:00
# End date is midnight, adjusting to previous day: 2025-03-21
# Converted start_date to date: 2025-03-20
# Will generate 2 dates
# Yielding date: 2025-03-20
#     Searching for DAILY pattern: 'psp_swp_spi_sf00_L3_mom_20250320_v*.cdf' in dir: '/Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025'
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20250320_v00.cdf with pattern psp_swp_spi_sf00_L3_mom_20250320_v.*.cdf
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20250320_v04.cdf with pattern psp_swp_spi_sf00_L3_mom_20250320_v.*.cdf
# Yielding date: 2025-03-21
#     Searching for DAILY pattern: 'psp_swp_spi_sf00_L3_mom_20250321_v*.cdf' in dir: '/Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025'
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20250321_v04.cdf with pattern psp_swp_spi_sf00_L3_mom_20250321_v.*.cdf
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20250321_v00.cdf with pattern psp_swp_spi_sf00_L3_mom_20250321_v.*.cdf
# Found 4 unique CDF files to process.
#
# Processing CDF file: /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250320_v00.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 795700872080410240 (2025-03-20T00:00:02.896410240) to 795787267987132288 (2025-03-20T23:59:58.803132288)
#     Comparison: File ends before request starts? False (FileEnd: 795787267987132288 < ReqStart: 795700869184000000)
#     Comparison: File starts after request ends? False (FileStart: 795700872080410240 > ReqEnd: 795873669184000000)
# Reading full time data array...
# Read 24687 time points
# Time indices: 0 to 24687
# Extracted 24687 time points within requested range
#
# Reading variable: VEL_RTN_SUN
# Raw data shape: (24687, 3)
# Successfully stored data slice for VEL_RTN_SUN
#
# Reading variable: DENS
# Raw data shape: (24687,)
# Successfully stored data slice for DENS
#
# Reading variable: TEMP
# Raw data shape: (24687,)
# Successfully stored data slice for TEMP
#
# Reading variable: MAGF_INST
# Raw data shape: (24687, 3)
# Successfully stored data slice for MAGF_INST
#
# Reading variable: T_TENSOR_INST
# Raw data shape: (24687, 6)
# Successfully stored data slice for T_TENSOR_INST
#
# Reading variable: EFLUX_VS_ENERGY
# Raw data shape: (24687, 32)
# Successfully stored data slice for EFLUX_VS_ENERGY
#
# Reading variable: EFLUX_VS_THETA
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Raw data shape: (24687, 8)
# Successfully stored data slice for EFLUX_VS_THETA
#
# Reading variable: EFLUX_VS_PHI
# Raw data shape: (24687, 8)
# Successfully stored data slice for EFLUX_VS_PHI
#
# Reading variable: ENERGY_VALS
# Raw data shape: (24687, 32)
# Successfully stored data slice for ENERGY_VALS
#
# Reading variable: THETA_VALS
# Raw data shape: (24687, 8)
# Successfully stored data slice for THETA_VALS
#
# Reading variable: PHI_VALS
# Raw data shape: (24687, 8)
# Successfully stored data slice for PHI_VALS
#
# Reading variable: SUN_DIST
# Raw data shape: (24687,)
# Successfully stored data slice for SUN_DIST
#
# Processing CDF file: /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250320_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 795700872080410240 (2025-03-20T00:00:02.896410240) to 795787267987132288 (2025-03-20T23:59:58.803132288)
#     Comparison: File ends before request starts? False (FileEnd: 795787267987132288 < ReqStart: 795700869184000000)
#     Comparison: File starts after request ends? False (FileStart: 795700872080410240 > ReqEnd: 795873669184000000)
# Reading full time data array...
# Read 24687 time points
# Time indices: 0 to 24687
# Extracted 24687 time points within requested range
#
# Reading variable: VEL_RTN_SUN
# Raw data shape: (24687, 3)
# Successfully stored data slice for VEL_RTN_SUN
#
# Reading variable: DENS
# Raw data shape: (24687,)
# Successfully stored data slice for DENS
#
# Reading variable: TEMP
# Raw data shape: (24687,)
# Successfully stored data slice for TEMP
#
# Reading variable: MAGF_INST
# Raw data shape: (24687, 3)
# Successfully stored data slice for MAGF_INST
#
# Reading variable: T_TENSOR_INST
# Raw data shape: (24687, 6)
# Successfully stored data slice for T_TENSOR_INST
#
# Reading variable: EFLUX_VS_ENERGY
# Raw data shape: (24687, 32)
# Successfully stored data slice for EFLUX_VS_ENERGY
#
# Reading variable: EFLUX_VS_THETA
# Raw data shape: (24687, 8)
# Successfully stored data slice for EFLUX_VS_THETA
#
# Reading variable: EFLUX_VS_PHI
# Raw data shape: (24687, 8)
# Successfully stored data slice for EFLUX_VS_PHI
#
# Reading variable: ENERGY_VALS
# Raw data shape: (24687, 32)
# Successfully stored data slice for ENERGY_VALS
#
# Reading variable: THETA_VALS
# Raw data shape: (24687, 8)
# Successfully stored data slice for THETA_VALS
#
# Reading variable: PHI_VALS
# Raw data shape: (24687, 8)
# Successfully stored data slice for PHI_VALS
#
# Reading variable: SUN_DIST
# Raw data shape: (24687,)
# Successfully stored data slice for SUN_DIST
#
# Processing CDF file: /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250321_v00.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 795787271482432896 (2025-03-21T00:00:02.298432896) to 795873667413194624 (2025-03-21T23:59:58.229194624)
#     Comparison: File ends before request starts? False (FileEnd: 795873667413194624 < ReqStart: 795700869184000000)
#     Comparison: File starts after request ends? False (FileStart: 795787271482432896 > ReqEnd: 795873669184000000)
# Reading full time data array...
# Read 26032 time points
# Time indices: 0 to 26032
# Extracted 26032 time points within requested range
#
# Reading variable: VEL_RTN_SUN
# Raw data shape: (26032, 3)
# Successfully stored data slice for VEL_RTN_SUN
#
# Reading variable: DENS
# Raw data shape: (26032,)
# Successfully stored data slice for DENS
#
# Reading variable: TEMP
# Raw data shape: (26032,)
# Successfully stored data slice for TEMP
#
# Reading variable: MAGF_INST
# Raw data shape: (26032, 3)
# Successfully stored data slice for MAGF_INST
#
# Reading variable: T_TENSOR_INST
# Raw data shape: (26032, 6)
# Successfully stored data slice for T_TENSOR_INST
#
# Reading variable: EFLUX_VS_ENERGY
# Raw data shape: (26032, 32)
# Successfully stored data slice for EFLUX_VS_ENERGY
#
# Reading variable: EFLUX_VS_THETA
# Raw data shape: (26032, 8)
# Successfully stored data slice for EFLUX_VS_THETA
#
# Reading variable: EFLUX_VS_PHI
# Raw data shape: (26032, 8)
# Successfully stored data slice for EFLUX_VS_PHI
#
# Reading variable: ENERGY_VALS
# Raw data shape: (26032, 32)
# Successfully stored data slice for ENERGY_VALS
#
# Reading variable: THETA_VALS
# Raw data shape: (26032, 8)
# Successfully stored data slice for THETA_VALS
#
# Reading variable: PHI_VALS
# Raw data shape: (26032, 8)
# Successfully stored data slice for PHI_VALS
#
# Reading variable: SUN_DIST
# Raw data shape: (26032,)
# Successfully stored data slice for SUN_DIST
#
# Processing CDF file: /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250321_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 795787271482432896 (2025-03-21T00:00:02.298432896) to 795873667413194624 (2025-03-21T23:59:58.229194624)
#     Comparison: File ends before request starts? False (FileEnd: 795873667413194624 < ReqStart: 795700869184000000)
#     Comparison: File starts after request ends? False (FileStart: 795787271482432896 > ReqEnd: 795873669184000000)
# Reading full time data array...
# Read 26032 time points
# Time indices: 0 to 26032
# Extracted 26032 time points within requested range
#
# Reading variable: VEL_RTN_SUN
# Raw data shape: (26032, 3)
# Successfully stored data slice for VEL_RTN_SUN
#
# Reading variable: DENS
# Raw data shape: (26032,)
# Successfully stored data slice for DENS
#
# Reading variable: TEMP
# Raw data shape: (26032,)
# Successfully stored data slice for TEMP
#
# Reading variable: MAGF_INST
# Raw data shape: (26032, 3)
# Successfully stored data slice for MAGF_INST
#
# Reading variable: T_TENSOR_INST
# Raw data shape: (26032, 6)
# Successfully stored data slice for T_TENSOR_INST
#
# Reading variable: EFLUX_VS_ENERGY
# Raw data shape: (26032, 32)
# Successfully stored data slice for EFLUX_VS_ENERGY
#
# Reading variable: EFLUX_VS_THETA
# Raw data shape: (26032, 8)
# Successfully stored data slice for EFLUX_VS_THETA
#
# Reading variable: EFLUX_VS_PHI
# Raw data shape: (26032, 8)
# Successfully stored data slice for EFLUX_VS_PHI
#
# Reading variable: ENERGY_VALS
# Raw data shape: (26032, 32)
# Successfully stored data slice for ENERGY_VALS
#
# Reading variable: THETA_VALS
# Raw data shape: (26032, 8)
# Successfully stored data slice for THETA_VALS
#
# Reading variable: PHI_VALS
# Raw data shape: (26032, 8)
# Successfully stored data slice for PHI_VALS
#
# Reading variable: SUN_DIST
# Raw data shape: (26032,)
# Successfully stored data slice for SUN_DIST
#
# Concatenating CDF data...
#   Concatenated VEL_RTN_SUN (Shape: (101438, 3))
#   Concatenated DENS (Shape: (101438,))
#   Concatenated TEMP (Shape: (101438,))
#   Concatenated MAGF_INST (Shape: (101438, 3))
#   Concatenated T_TENSOR_INST (Shape: (101438, 6))
#   Concatenated EFLUX_VS_ENERGY (Shape: (101438, 32))
#   Concatenated EFLUX_VS_THETA (Shape: (101438, 8))
#   Concatenated EFLUX_VS_PHI (Shape: (101438, 8))
#   Concatenated ENERGY_VALS (Shape: (101438, 32))
#   Concatenated THETA_VALS (Shape: (101438, 8))
#   Concatenated PHI_VALS (Shape: (101438, 8))
#   Concatenated SUN_DIST (Shape: (101438,))
#
# Total CDF data points after concatenation: 101438
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2025-03-20/00:00:00', '2025-03-22/00:00:00'].
#
# *** IMPORT_DATA_DEBUG (CDF Path) for data_type 'spi_sf00_l3_mom' (originally requested: 'spi_sf00_l3_mom') ***
# [CUBBY]     data_object ID: 13064971328
# [CUBBY]     DataObject.times length: 101438, dtype: int64
# [CUBBY]     data_object.data ID: 6299848320
# [CUBBY]     DataObject.data keys: ['VEL_RTN_SUN', 'DENS', 'TEMP', 'MAGF_INST', 'T_TENSOR_INST', 'EFLUX_VS_ENERGY', 'EFLUX_VS_THETA', 'EFLUX_VS_PHI', 'ENERGY_VALS', 'THETA_VALS', 'PHI_VALS', 'SUN_DIST']
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# [CUBBY] [CLASS_TYPE_DEBUG] Resolved legacy alias 'spi_sf00_l3_mom' -> 'proton'
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'spi_sf00_l3_mom' -> 'proton' -> <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Searching for instance of type <class 'plotbot.data_classes.psp_proton.proton_class'> in class_registry with 33 entries
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_auto' -> <class 'plotbot.data_classes.custom_classes.psp_waves_auto.psp_waves_auto_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.demo_spectral_waves.demo_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_wave_power' -> <class 'plotbot.data_classes.custom_classes.demo_wave_power.demo_wave_power_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_real_test' -> <class 'plotbot.data_classes.custom_classes.psp_waves_real_test.psp_waves_real_test_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.psp_spectral_waves.psp_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'alpha_fits' -> <class 'plotbot.data_classes.psp_alpha_fits_classes.alpha_fits_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn' -> <class 'plotbot.data_classes.psp_mag_rtn.mag_rtn_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_sc_4sa' -> <class 'plotbot.data_classes.psp_mag_sc_4sa.mag_sc_4sa_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_sc' -> <class 'plotbot.data_classes.psp_mag_sc.mag_sc_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'epad' -> <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'epad_hr' -> <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_high_res_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'proton' -> <class 'plotbot.data_classes.psp_proton.proton_class'> vs target <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] ✅ MATCH FOUND by type lookup
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 49374
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# [CUBBY] Global instance has existing data. Attempting merge...
# [CUBBY] [CLASS_TYPE_DEBUG] Resolved legacy alias 'spi_sf00_l3_mom' -> 'proton'
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'spi_sf00_l3_mom' -> 'proton' -> <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] Processing new imported data into temporary instance...
# No data provided; initialized with empty attributes.
# [CUBBY] ✅ New data processed.
# [CUBBY] Calling _merge_arrays...
# [CUBBY]
# 🔥 ULTIMATE MERGE ENGINE ACTIVATED 🔥
# [CUBBY] 📊 MERGE STATS:
# [CUBBY]    Existing: 49,374 records
# [CUBBY]    New: 101,438 records
# [CUBBY]    Potential total: 150,812 records
# [CUBBY] 🔄 OVERLAP DETECTED - Full merge required
# [CUBBY] ⚡ Computing unique merged times...
# [CUBBY] ✅ Unique times: 101,438 records (49,374 duplicates removed)
# [CUBBY] 🏎️ SPEED MODE: Using vectorized processing
# [CUBBY] 🏁 MERGE COMPLETE!
# [CUBBY]    Final records: 101,438
# [CUBBY]    Duration: 0.02s
# [CUBBY]    Speed: 5,639,138 records/sec
# [CUBBY]    Session total: 152,157 records
# [CUBBY]    Session avg: 894,086 records/sec
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# Updated and merged ranges for spi_sf00_l3_mom: [(datetime.datetime(2025, 3, 20, 0, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2025, 3, 22, 0, 0, tzinfo=datetime.timezone.utc))]
# [CUBBY]
# === Retrieving proton from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/example_notebooks/../plotbot/plotbot_main.py:380
# [CUBBY] GRAB SUCCESS - Retrieved proton with type <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6300109040 for key 'proton'. dt_len: 101438, min: 2025-03-20T00:00:02.896410240, max: 2025-03-21T23:59:58.229194624
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(101438,), range=2025-03-20T00:00:02.896410 to 2025-03-21T23:59:58.229194
# [CUBBY] GRAB OUTPUT - raw_data keys=['beta_pperp', 'vn', 'anisotropy', 'vr', 'pressure', 'beta_ppar', 'v_alfven', 'phi_flux', 'sun_dist_rsun', 'PHI_VALS', 't_perp', 'pressure_pperp', 't_par', 'energy_flux', 'density', 'temperature', 'v_sw', 'bmag', 'THETA_VALS', 'vt', 'theta_flux', 'm_alfven', 'ENERGY_VALS', 'pressure_ppar'] | beta_pperp: type=ndarray, shape=(101438,) | vn: type=ndarray, shape=(101438,) | anisotropy: type=ndarray, shape=(101438,) | vr: type=ndarray, shape=(101438,) | pressure: type=ndarray, shape=(101438,) | beta_ppar: type=ndarray, shape=(101438,) | v_alfven: type=ndarray, shape=(101438,) | phi_flux: type=ndarray, shape=(101438, 8) | sun_dist_rsun: type=ndarray, shape=(101438,) | PHI_VALS: type=ndarray, shape=(101438, 8) | t_perp: type=ndarray, shape=(101438,) | pressure_pperp: type=ndarray, shape=(101438,) | t_par: type=ndarray, shape=(101438,) | energy_flux: type=ndarray, shape=(101438, 32) | density: type=ndarray, shape=(101438,) | temperature: type=ndarray, shape=(101438,) | v_sw: type=ndarray, shape=(101438,) | bmag: type=ndarray, shape=(101438,) | THETA_VALS: type=ndarray, shape=(101438, 8) | vt: type=ndarray, shape=(101438,) | theta_flux: type=ndarray, shape=(101438, 8) | m_alfven: type=ndarray, shape=(101438,) | ENERGY_VALS: type=ndarray, shape=(101438, 32) | pressure_ppar: type=ndarray, shape=(101438,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
# ⚡ [CLIP_ONCE] Clipping data ONCE for trange: ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
# 🔍 [DEBUG] clip_to_original_trange called with trange: ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
# 🔍 [DEBUG] Clipping 101438 points to 101438 points in range
#
# DEBUG:
# var: [ 139.38263        nan  126.89838 ...        nan 3708.2295         nan]
# var type: <class 'plotbot.plot_manager.plot_manager'>
# var.datetime_array type: <class 'numpy.ndarray'>
# First element type: <class 'numpy.datetime64'>
# First element: 2025-03-20T00:00:02.896410240
# Time range: 2025-03-20T00:00:02.896410240 to 2025-03-21T23:59:58.229194624
# var.data type: <class 'numpy.ndarray'>
# var.data shape: (101438,)
#
# Variable verification for proton.density:
# Plot attributes example:
# - Color: blue
# - Y-label: Dens
# (cm$^{-3}$)
# - Legend: n$_{SPI}$
# [CUBBY]
# === Retrieving ham from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/example_notebooks/../plotbot/plotbot_main.py:380
# [CUBBY] GRAB SUCCESS - Retrieved ham with type <class 'plotbot.data_classes.psp_ham_classes.ham_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6300337936 for key 'ham'. dt_len: 50719, min: 2025-03-20T00:00:02.896000000, max: 2025-03-21T23:59:58.229000000
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(50719,), range=2025-03-20T00:00:02.896 to 2025-03-21T23:59:58.229
# [CUBBY] GRAB OUTPUT - raw_data keys=['Tperprat_driftva_hc', 'hamogram_og_30s', 'hamogram_90m', 'Nham_div_Ntot_og', 'hamogram_og_2m', 'Nham_div_Ncore', 'ham_core_drift_va', 'Tperprat_driftva_hc_og', 'Tperp_ham_div_core', 'hamogram_20m', 'hamogram_2m', 'hamogram_og_4h', 'Tperp_ham_div_core_og', 'hamogram_4h', 'ham_core_drift', 'Nham_div_Ntot', 'trat_ham_og', 'Nham_div_Ncore_og', 'trat_ham', 'hamogram_30s'] | Tperprat_driftva_hc: type=ndarray, shape=(50719,) | hamogram_og_30s: type=ndarray, shape=(50719,) | hamogram_90m: type=ndarray, shape=(50719,) | Nham_div_Ntot_og: type=ndarray, shape=(50719,) | hamogram_og_2m: type=ndarray, shape=(50719,) | Nham_div_Ncore: type=ndarray, shape=(50719,) | ham_core_drift_va: type=ndarray, shape=(50719,) | Tperprat_driftva_hc_og: type=ndarray, shape=(50719,) | Tperp_ham_div_core: type=ndarray, shape=(50719,) | hamogram_20m: type=ndarray, shape=(50719,) | hamogram_2m: type=ndarray, shape=(50719,) | hamogram_og_4h: type=ndarray, shape=(50719,) | Tperp_ham_div_core_og: type=ndarray, shape=(50719,) | hamogram_4h: type=ndarray, shape=(50719,) | ham_core_drift: type=ndarray, shape=(50719,) | Nham_div_Ntot: type=ndarray, shape=(50719,) | trat_ham_og: type=ndarray, shape=(50719,) | Nham_div_Ncore_og: type=ndarray, shape=(50719,) | trat_ham: type=ndarray, shape=(50719,) | hamogram_30s: type=ndarray, shape=(50719,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
# ⚡ [CLIP_ONCE] Clipping data ONCE for trange: ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
# 🔍 [DEBUG] clip_to_original_trange called with trange: ['2025-03-20/00:00:00.000', '2025-03-22/00:00:00.000']
# 🔍 [DEBUG] Clipping 50719 points to 50719 points in range
#
# DEBUG:
# var: [0.5 0.5 0.5 ... 0.5 0.5 0.5]
# var type: <class 'plotbot.plot_manager.plot_manager'>
# var.datetime_array type: <class 'numpy.ndarray'>
# First element type: <class 'numpy.datetime64'>
# First element: 2025-03-20T00:00:02.896000000
# Time range: 2025-03-20T00:00:02.896000000 to 2025-03-21T23:59:58.229000000
# var.data type: <class 'numpy.ndarray'>
# var.data shape: (50719,)
#
# Variable verification for ham.hamogram_30s:
# Plot attributes example:
# - Color: palevioletred
# - Y-label: Hamogram
# - Legend: Hamogram_30s
# 📈 Plotting proton.density
# 🔍 TIME_CLIP_DEBUG for proton.density:
#    raw_datetime_array: len=101438, range=2025-03-20T00:00:02.896410240 to 2025-03-21T23:59:58.229194624
#    requested trange: 2025-03-20/00:00:00.000 to 2025-03-22/00:00:00.000
#    time_clip returned 101438 indices
# 📈 Plotting ham.hamogram_30s
# 🔍 TIME_CLIP_DEBUG for ham.hamogram_30s:
#    raw_datetime_array: len=50719, range=2025-03-20T00:00:02.896000000 to 2025-03-21T23:59:58.229000000
#    requested trange: 2025-03-20/00:00:00.000 to 2025-03-22/00:00:00.000
#    time_clip returned 50719 indices
