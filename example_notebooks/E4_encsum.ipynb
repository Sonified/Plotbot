# %%
#Remember to select the Plotbot Environment!
from plotbot import *
# Out:
# 🕒 Starting import timing session: plotbot_full_initialization
#   ✅ matplotlib.pyplot: 0.325s
#   ✅ numpy: 0.000s
#   🔧 Starting block: core_components
# initialized server_access
# initialized global_tracker
# initialized ploptions
# initialized plot_manager
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized ham_class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# initialized data_cubby.
# CDF classes added to data_cubby type map.
#   ✅ Block 'core_components' completed in 1.032s
#   🔧 Starting block: psp_data_classes
# initialized proton_fits class
# initialized alpha_fits class
#   ✅ Block 'psp_data_classes' completed in 0.002s
#   🔧 Starting block: wind_data_classes
#   ✅ Block 'wind_data_classes' completed in 0.000s
#   🔧 Starting block: data_cubby_registration
#   ✅ Block 'data_cubby_registration' completed in 0.001s
# ...

# %%
print_manager.show_status = True
print_manager.show_debug = True

# %%
# trange = ['2020-01-25/00:00','2020-02-04/00:00']
trange = ['2020-01-25/00:00','2020-01-26/00:00']
plotbot(trange,
        mag_rtn_4sa.bmag, 1, mag_rtn_4sa.br, '1r',
        mag_rtn_4sa.bt, 2, mag_rtn_4sa.bn, 2,
        epad.strahl, 3,
        proton.t_perp, 4, proton.t_par, 4
        )
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🕒 TimeRangeTracker: Cleared trange
# 🛰️ spi_sf00_l3_mom - acquiring variables: t_perp, t_par
# 🛰️ spe_sf0_pad - acquiring variables: strahl
# 🛰️ mag_RTN_4sa - acquiring variables: bmag, br, bt, bn
#
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:290
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 4528537280 for key 'mag_rtn_4sa'. dt_len: 395507, min: 2020-01-25T00:00:00.028174080, max: 2020-01-25T23:59:59.888271488
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(395507,), range=2020-01-25T00:00:00.028174 to 2020-01-25T23:59:59.888271
# ...

# %%
# trange = ['2023-06-22/00:00','2023-06-23/00:00']
plotbot(trange,
        mag_rtn_4sa.bmag, 1, mag_rtn_4sa.br, '1r',
        mag_rtn_4sa.bt, 2, mag_rtn_4sa.bn, 2,
        epad.strahl, 3,
        proton.t_perp, 4, proton.t_par, 4
        )
