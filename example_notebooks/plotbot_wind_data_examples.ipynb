# %% [markdown]
# # Plotbot WIND Data Examples
#
# This notebook demonstrates all five integrated WIND data types in Plotbot. Each section shows how to plot the key variables for each instrument, providing both examples and validation of the WIND integration.
#
# **Integrated WIND Data Types:**
# 1. **WIND MFI** - Magnetic Field Investigation (Bx, By, Bz, |B|)
# 2. **WIND SWE H1** - Solar Wind Experiment: Proton/Alpha thermal speeds
# 3. **WIND SWE H5** - Solar Wind Experiment: Electron temperature
# 4. **WIND 3DP ELPD** - 3D Plasma Analyzer: Electron pitch-angle distributions
# 5. **WIND 3DP PM** - 3D Plasma Analyzer: Ion plasma moments

# %%
from plotbot import *
# Out:
# 🕒 Starting import timing session: plotbot_full_initialization
#   ✅ matplotlib.pyplot: 0.250s
#   ✅ numpy: 0.000s
#   🔧 Starting block: core_components
# initialized server_access
# initialized global_tracker
# initialized ploptions
# initialized plot_manager
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized ham_class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# initialized data_cubby.
# CDF classes added to data_cubby type map.
#   ✅ Block 'core_components' completed in 0.686s
#   🔧 Starting block: psp_data_classes
# initialized proton_fits class
# initialized alpha_fits class
#   ✅ Block 'psp_data_classes' completed in 0.001s
#   🔧 Starting block: wind_data_classes
#   ✅ Block 'wind_data_classes' completed in 0.000s
#   🔧 Starting block: data_cubby_registration
#   ✅ Block 'data_cubby_registration' completed in 0.001s
#   🔧 Starting block: auto_register_custom_classes
#   ✅ Block 'auto_register_custom_classes' completed in 0.002s
#   🔧 Starting block: custom_variables
#   ✅ Block 'custom_variables' completed in 0.000s
# 🔉 initialized audifier
#   ✅ from plotbot import audifier: 0.106s
#   🔧 Starting block: enhanced_plt
#   ✅ Block 'enhanced_plt' completed in 0.000s
#   🔧 Starting block: main_plotting_functions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# ✅ Imported cdflib, BeautifulSoup, requests, dateutil, and datetime libraries.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#   ✅ Block 'main_plotting_functions' completed in 0.411s
#   🔧 Starting block: cdf_functions
#   ✅ Block 'cdf_functions' completed in 0.001s
#
# 🤖 Plotbot Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_09_10_v3.29
#    Commit: v3.29 Config: Set default data directory to 'default' in Plotbot.ipynb
#
#
# 🏁 Session 'plotbot_full_initialization' completed in 1.458s
#
# ============================================================
# 📊 IMPORT TIMING REPORT - plotbot_full_initialization
# ============================================================
# Total session time: 1.458s
#
# 🐌 SLOWEST IMPORTS (Top 3):
# --------------------------------------------------
#  1. matplotlib.pyplot               0.250s (70.3%)
#  2. from plotbot import audifier    0.106s (29.7%)
#  3. numpy                           0.000s ( 0.0%)
#
# 🔧 BLOCK TIMING SUMMARY:
# --------------------------------------------------
# core_components                 0.686s (avg: 0.686s, runs: 1)
# psp_data_classes                0.001s (avg: 0.001s, runs: 1)
# wind_data_classes               0.000s (avg: 0.000s, runs: 1)
# data_cubby_registration         0.001s (avg: 0.001s, runs: 1)
# auto_register_custom_classes    0.002s (avg: 0.002s, runs: 1)
# custom_variables                0.000s (avg: 0.000s, runs: 1)
# enhanced_plt                    0.000s (avg: 0.000s, runs: 1)
# main_plotting_functions         0.411s (avg: 0.411s, runs: 1)
# cdf_functions                   0.001s (avg: 0.001s, runs: 1)
#
# ⏰ IMPORT TIMELINE:
# --------------------------------------------------
#  0.000s: matplotlib.pyplot              (+0.250s)
#  0.250s: numpy                          (+0.000s)
#  0.940s: from plotbot import audifier   (+0.106s)
#
# 💡 OPTIMIZATION SUGGESTIONS:
# --------------------------------------------------
# • Matplotlib imports: 0.3s - good candidate for lazy loading
# • Focus optimization on imports >0.5s for maximum impact

# %%
# -------CONFIGURE THE DEFAULT DATA DIRECTORY-------//
# This must be set before pyspedas is imported/run, as pyspedas caches configuration at import time.

config.data_dir = '../data'  # Go up one level to Plotbot/data/

import os
print(f"📁 Data directory absolute path: {os.path.abspath(config.data_dir)}")

# -------CONFIGURE THE DEFAULT DATA SERVER-------//

config.data_server = 'spdf'
# config.data_server = 'berkeley'
# config.data_server = 'dynamic' #Will attempt to download from spdf first and then try berkeley

# -------CONFIGURE PRINT MANAGER-------//
print_manager.show_status = True
# print_manager.show_debug = True      # Optional: uncomment for maximum detail
# print_manager.show_processing = True # Optional: uncomment for processing steps
# print_manager.show_datacubby = True  # Optional: uncomment for data caching steps
# Out:
# 📁 Plotbot data directory changed: data → ../data
# 🔧 SPEDAS_DATA_DIR updated for pyspedas compatibility
# 📁 Data directory absolute path: /Users/robertalexander/GitHub/Plotbot/data

# %% [markdown]
# ## 1. WIND MFI (Magnetic Field Investigation)
#
# The WIND Magnetic Field Investigation (MFI) provides high-resolution magnetic field measurements. This example plots all magnetic field components in GSE coordinates plus the total field magnitude.

# %%
# Define a consistent time range for all plots.
trange = ['2022-06-01 20:00:00', '2022-06-02 02:00:00']

# %%
print("Plotting WIND MFI: Magnetic Field components (Bx, By, Bz) and magnitude...")
plotbot(trange,
        wind_mfi_h2.bx, 1,
        wind_mfi_h2.by, 2,
        wind_mfi_h2.bz, 3,
        wind_mfi_h2.bmag, 4)
# Out:
# Plotting WIND MFI: Magnetic Field components (Bx, By, Bz) and magnitude...
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ wind_mfi_h2 - acquiring variables: bx, by, bz, bmag
#
# 📥 Acquiring data for 4 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2022-06-01 20:00:00', '2022-06-02 02:00:00']
# 🛰️ wind_mfi_h2 - acquiring variables: bx, by, bz, bmag
# Attempting SPDF acquisition path for wind_mfi_h2...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# ☑️ - CDF Data import complete for wind_mfi_h2 range ['2022-06-01 20:00:00', '2022-06-02 02:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for wind_mfi_h2...
# ✅ DataCubby processed update for wind_mfi_h2.
# ✅ Complete
# 📈 Plotting wind_mfi_h2.bx
# 📈 Plotting wind_mfi_h2.by
# 📈 Plotting wind_mfi_h2.bz
# 📈 Plotting wind_mfi_h2.bmag

# %% [markdown]
# ## 2. WIND SWE H1 (Proton & Alpha Thermal Speeds)
#
# The Solar Wind Experiment (SWE) H1 data product provides thermal speed measurements for protons and alpha particles, including temperature anisotropy calculations and data quality flags.

# %%
#Note: Filtering is currently being implemented within the class itself and needs to be refined
#       based on best practices. And should be made available as a parameter to the plotbot function.
#       All the alpha thermal speed data are NAN for this region.

print("Plotting WIND SWE H1: Proton/Alpha thermal speeds, anisotropy, and quality flag...")
plotbot(trange,
        wind_swe_h1.proton_wpar, 1,
        wind_swe_h1.proton_wperp, 2,
        wind_swe_h1.proton_anisotropy, 3,
        wind_swe_h1.alpha_w, 4,
        wind_swe_h1.fit_flag, 5)
# Out:
# Plotting WIND SWE H1: Proton/Alpha thermal speeds, anisotropy, and quality flag...
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ wind_swe_h1 - acquiring variables: proton_wpar, proton_wperp, proton_anisotropy, alpha_w, fit_flag
#
# 📥 Acquiring data for 5 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2022-06-01 20:00:00', '2022-06-02 02:00:00']
# 🛰️ wind_swe_h1 - acquiring variables: proton_wpar, proton_wperp, proton_anisotropy, alpha_w, fit_flag
# Attempting SPDF acquisition path for wind_swe_h1...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for wind_swe_h1 range ['2022-06-01 20:00:00', '2022-06-02 02:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for wind_swe_h1...
# ✅ DataCubby processed update for wind_swe_h1.
# ✅ Complete
# 📈 Plotting wind_swe_h1.proton_wpar
# 📈 Plotting wind_swe_h1.proton_wperp
# 📈 Plotting wind_swe_h1.proton_anisotropy
# 📈 Plotting wind_swe_h1.alpha_w
# 📈 Plotting wind_swe_h1.fit_flag

# %% [markdown]
# ## 3. WIND SWE H5 (Electron Temperature)
#
# The SWE H5 data product provides electron temperature measurements derived from quadrature analysis of the electron distribution functions.

# %%
#Note: Filtering is not being implemented and we have one value that's wildly negative.
print("Plotting WIND SWE H5: Electron Temperature...")
plotbot(trange, wind_swe_h5.t_elec, 1)
# Out:
# Plotting WIND SWE H5: Electron Temperature...
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ wind_swe_h5 - acquiring variables: t_elec
#
# 📥 Acquiring data for 1 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2022-06-01 20:00:00', '2022-06-02 02:00:00']
# 🛰️ wind_swe_h5 - acquiring variables: t_elec
# Attempting SPDF acquisition path for wind_swe_h5...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for wind_swe_h5 range ['2022-06-01 20:00:00', '2022-06-02 02:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for wind_swe_h5...
# ✅ DataCubby processed update for wind_swe_h5.
# ✅ Complete
# 📈 Plotting wind_swe_h5.t_elec

# %% [markdown]
# ## 4. WIND 3DP ELPD (Electron Pitch-Angle Distributions)
#
# The 3D Plasma Analyzer (3DP) ELPD data product provides electron pitch-angle distributions, showing how electron fluxes vary with angle relative to the magnetic field direction.

# %%
print("Plotting WIND 3DP ELPD: Electron pitch-angle flux and centroids...")
print("Energy bin 4 corresponding to 255 eV...")
plotbot(trange,
        wind_3dp_elpd.flux_selected_energy, 1,
        wind_3dp_elpd.centroids, 2)
# Out:
# Plotting WIND 3DP ELPD: Electron pitch-angle flux and centroids...
# Energy bin 4 corresponding to 255 eV...
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ wind_3dp_elpd - acquiring variables: flux_selected_energy, centroids
#
# 📥 Acquiring data for 2 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2022-06-01 20:00:00', '2022-06-02 02:00:00']
# 🛰️ wind_3dp_elpd - acquiring variables: flux_selected_energy, centroids
# Attempting SPDF acquisition path for wind_3dp_elpd...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# 18-Sep-25 16:47:02: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:658: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax.pcolormesh(  # Create 2D color plot
# ☑️ - CDF Data import complete for wind_3dp_elpd range ['2022-06-01 20:00:00', '2022-06-02 02:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for wind_3dp_elpd...
# ✅ DataCubby processed update for wind_3dp_elpd.
# ✅ Complete
# 📈 Plotting wind_3dp_elpd.flux_selected_energy
# 📈 Plotting wind_3dp_elpd.centroids

# %% [markdown]
# ## 5. WIND 3DP PM (Ion Plasma Moments)
#
# The 3DP PM data product provides comprehensive ion plasma moment measurements including velocity vectors, densities, and temperatures for both protons and alpha particles, along with data quality flags.

# %%
print("Plotting WIND 3DP PM: Ion plasma moments (velocity, density, temperature) and quality flag...")
plotbot(trange,
        wind_3dp_pm.all_v, 1,
        wind_3dp_pm.v_mag, 2,
        wind_3dp_pm.p_dens, 3,
        wind_3dp_pm.p_temp, 4,
        wind_3dp_pm.a_dens, 5,
        wind_3dp_pm.a_temp, 6,
        wind_3dp_pm.valid, 7)
# Out:
# Plotting WIND 3DP PM: Ion plasma moments (velocity, density, temperature) and quality flag...
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ wind_3dp_pm - acquiring variables: all_v, v_mag, p_dens, p_temp, a_dens, a_temp, valid
#
# 📥 Acquiring data for 7 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2022-06-01 20:00:00', '2022-06-02 02:00:00']
# 🛰️ wind_3dp_pm - acquiring variables: all_v, v_mag, p_dens, p_temp, a_dens, a_temp, valid
# Attempting SPDF acquisition path for wind_3dp_pm...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for wind_3dp_pm range ['2022-06-01 20:00:00', '2022-06-02 02:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for wind_3dp_pm...
# ✅ DataCubby processed update for wind_3dp_pm.
# ✅ Complete
# 📈 Plotting wind_3dp_pm.all_v
# 📈 Plotting wind_3dp_pm.v_mag
# 📈 Plotting wind_3dp_pm.p_dens
# 📈 Plotting wind_3dp_pm.p_temp
# 📈 Plotting wind_3dp_pm.a_dens
# 📈 Plotting wind_3dp_pm.a_temp
# 📈 Plotting wind_3dp_pm.valid

# %% [markdown]
# ## Summary
#
# This notebook demonstrates the successful integration of all five WIND data types into Plotbot:
#
# - ✅ **WIND MFI H2**: Magnetic field components and magnitude
# - ✅ **WIND SWE H1**: Proton/alpha thermal speeds and anisotropy
# - ✅ **WIND SWE H5**: Electron temperature
# - ✅ **WIND 3DP ELPD**: Electron pitch-angle distributions
# - ✅ **WIND 3DP PM**: Ion plasma moments (proton/alpha velocity, density, temperature)
#
# All data types support the standard Plotbot interface and can be combined with PSP data for comparative studies.
