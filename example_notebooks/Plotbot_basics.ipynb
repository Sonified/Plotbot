# %% [markdown]
# ## Welcome to Plotbot!

# %% [markdown]
# 👋 Welcome to Plotbot! A your class-oriented workflow optimizer for downloading and plotting data from the Parker Solar Probe. Created by Dr. Jaye Verniero and Dr. Robert Alexander. Note: this is a work in progress.

# %% [markdown]
# ⚡️Plotbot utilizes active calculation caching⚡️
#    ⚡️Calculate once and forget about it⚡️

# %% [markdown]
# First, click in the upper right hand corner of this window to select the plotbot environment. It should be named plotbot_env (Python 3.12.4). Alternatively, you'll be prompted to select the environment when you run the first cell below.

# %% [markdown]
# ### Plotbot

# %% [markdown]
# Let's get started by importing plotbot:

# %%
#Remember to select the Plotbot Environment!
from plotbot import *
# Out:
# 🕒 Starting import timing session: plotbot_full_initialization
#   ✅ matplotlib.pyplot: 0.405s
#   ✅ numpy: 0.000s
#   🔧 Starting block: core_components
# initialized server_access
# initialized global_tracker
# initialized plot_config
# initialized plot_manager
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized ham_class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# initialized data_cubby.
# CDF classes added to data_cubby type map.
#   ✅ Block 'core_components' completed in 0.743s
#   🔧 Starting block: psp_data_classes
# initialized proton_fits class
# initialized alpha_fits class
#   ✅ Block 'psp_data_classes' completed in 0.001s
#   🔧 Starting block: wind_data_classes
#   ✅ Block 'wind_data_classes' completed in 0.000s
#   🔧 Starting block: data_cubby_registration
#   ✅ Block 'data_cubby_registration' completed in 0.001s
#   🔧 Starting block: auto_register_custom_classes
#   ✅ Block 'auto_register_custom_classes' completed in 0.002s
#   🔧 Starting block: custom_variables
#   ✅ Block 'custom_variables' completed in 0.000s
# 🔉 initialized audifier
#   ✅ from plotbot import audifier: 0.062s
# 🎛️ initialized ploptions
#   🔧 Starting block: enhanced_plt
#   ✅ Block 'enhanced_plt' completed in 0.000s
#   🔧 Starting block: main_plotting_functions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# ✅ Imported cdflib, BeautifulSoup, requests, dateutil, and datetime libraries.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#   ✅ Block 'main_plotting_functions' completed in 0.478s
#   🔧 Starting block: cdf_functions
#   ✅ Block 'cdf_functions' completed in 0.001s
#
# 🤖 Plotbot Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_09_24_v3.45
#    Commit: v3.45 Performance Enhancement: Smart file checking across all pyspedas downloads - preserves server config while eliminating unnecessary network calls
#
#
# 🏁 Session 'plotbot_full_initialization' completed in 1.694s
#
# ============================================================
# 📊 IMPORT TIMING REPORT - plotbot_full_initialization
# ============================================================
# Total session time: 1.694s
#
# 🐌 SLOWEST IMPORTS (Top 3):
# --------------------------------------------------
#  1. matplotlib.pyplot               0.405s (86.7%)
#  2. from plotbot import audifier    0.062s (13.3%)
#  3. numpy                           0.000s ( 0.0%)
#
# 🔧 BLOCK TIMING SUMMARY:
# --------------------------------------------------
# core_components                 0.743s (avg: 0.743s, runs: 1)
# psp_data_classes                0.001s (avg: 0.001s, runs: 1)
# wind_data_classes               0.000s (avg: 0.000s, runs: 1)
# data_cubby_registration         0.001s (avg: 0.001s, runs: 1)
# auto_register_custom_classes    0.002s (avg: 0.002s, runs: 1)
# custom_variables                0.000s (avg: 0.000s, runs: 1)
# enhanced_plt                    0.000s (avg: 0.000s, runs: 1)
# main_plotting_functions         0.478s (avg: 0.478s, runs: 1)
# cdf_functions                   0.001s (avg: 0.001s, runs: 1)
#
# ⏰ IMPORT TIMELINE:
# --------------------------------------------------
#  0.000s: matplotlib.pyplot              (+0.405s)
#  0.405s: numpy                          (+0.000s)
#  1.153s: from plotbot import audifier   (+0.062s)
#
# 💡 OPTIMIZATION SUGGESTIONS:
# --------------------------------------------------
# • Matplotlib imports: 0.4s - good candidate for lazy loading
# • Focus optimization on imports >0.5s for maximum impact

# %%
# -------CONFIGURE THE DEFAULT DATA DIRECTORY-------//
# This must be set before pyspedas is imported/run, as pyspedas caches configuration at import time.

config.data_dir = '../data'  # Go up one level to Plotbot/data/

import os
print(f"📁 Data directory absolute path: {os.path.abspath(config.data_dir)}")

# -------CONFIGURE THE DEFAULT DATA SERVER-------//

config.data_server = 'spdf'
# config.data_server = 'berkeley'
# config.data_server = 'dynamic' #Will attempt to download from spdf first and then try berkeley

# -------CONFIGURE PRINT MANAGER-------//
print_manager.show_status = True
# print_manager.show_debug = True      # Optional: uncomment for maximum detail
# print_manager.show_processing = True # Optional: uncomment for processing steps
# print_manager.show_datacubby = True  # Optional: uncomment for data caching steps
# Out:
# 📁 Plotbot data directory changed: /Users/robertalexander/GitHub/Plotbot/data → ../data
# 🔧 SPEDAS_DATA_DIR updated for pyspedas compatibility
# 📁 Data directory absolute path: /Users/robertalexander/GitHub/Plotbot/data

# %% [markdown]
# #### ✨ The Data Snapshot! Save All Current Calculations to .pkl✨

# %%
# #Uncomment to explore the data snapshot!

# #Never wait for calculations again!
# #At the end of your session, save your cache'd calculations to a .pkl file:
# save_simple_snapshot('my_calculated_data.pkl') 

# # Load the cache at the beginning of your next session like this: 
# load_simple_snapshot('my_calculated_data.pkl') 

# # And the best part? Any new calculations will automatically be
# # merged with your import, and you can just save again at the
# # end of your next session!

# %% [markdown]
# #### ✨Diving In✨

# %%
import os
print(f"Working directory: {os.getcwd()}")
print(f"SPEDAS_DATA_DIR: {os.environ.get('SPEDAS_DATA_DIR', 'NOT_SET')}")
print(f"config.data_dir: {config.data_dir}")
# Out:
# Working directory: /Users/robertalexander/GitHub/Plotbot/example_notebooks
# SPEDAS_DATA_DIR: /Users/robertalexander/GitHub/Plotbot/data
# config.data_dir: ../data

# %%
plt.options.reset()

trange = ['2021/04/26 00:00:00.000', '2021/04/27 00:00:00.000']

mag_sc_4sa.bx.y_limit = [0, 100]

plotbot(trange, mag_sc_4sa.bx, 1)

print("Shape of mag_sc_4sa.bx.data:", getattr(mag_sc_4sa.bx, 'data', None).shape if hasattr(mag_sc_4sa.bx, 'data') and mag_sc_4sa.bx.data is not None else "Attribute 'data' not found or is None")
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ mag_SC_4sa - acquiring variables: bx
#
# 📥 Acquiring data for 1 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2021/04/26 00:00:00.000', '2021/04/27 00:00:00.000']
# 🛰️ mag_SC_4sa - acquiring variables: bx
# Attempting SPDF acquisition path for mag_SC_4sa...
# 📡 Smart check: mag_SC_4sa files not found locally, will download
# 📡 Local files not found, proceeding with pyspedas download for mag_SC_4sa
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for mag_SC_4sa range ['2021/04/26 00:00:00', '2021/04/27 00:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_sc_4sa...
# ✅ DataCubby processed update for mag_sc_4sa.
# ✅ Complete
# 📈 Plotting mag_sc_4sa.bx
# Shape of mag_sc_4sa.bx.data: (395507,)

# %%
#--------//

trange = ['2018-10-22 12:00:00', '2018-10-27 13:00:00']

epad.strahl.colorbar_limits = [8, 11]
epad.strahl.colorbar_scale = 'log'

plotbot(trange, mag_rtn_4sa.br, 1, epad.strahl, 2, proton.energy_flux, 3)

print("Shape of mag_rtn_4sa.br.data:", getattr(mag_rtn_4sa.br, 'data', None).shape if hasattr(mag_rtn_4sa.br, 'data') and mag_rtn_4sa.br.data is not None else "Attribute 'data' not found or is None")

print("Shape of epad.strahl.data:", getattr(epad.strahl, 'data', None).shape if hasattr(epad.strahl, 'data') and epad.strahl.data is not None else "Attribute 'data' not found or is None")
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ spe_sf0_pad - acquiring variables: strahl
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 🛰️ spi_sf00_l3_mom - acquiring variables: energy_flux
#
# 📥 Acquiring data for 3 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
# 🛰️ spe_sf0_pad - acquiring variables: strahl
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 🛰️ spi_sf00_l3_mom - acquiring variables: energy_flux
# Attempting SPDF acquisition path for spe_sf0_pad...
# 📡 Smart check: spe_sf0_pad files not found locally, will download
# 📡 Local files not found, proceeding with pyspedas download for spe_sf0_pad
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for spe_sf0_pad range ['2018-10-22 12:00:00', '2018-10-27 13:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for epad...
# Date 2018-10-22 does not fall within any defined encounter period.
# ✅ DataCubby processed update for epad.
# Attempting SPDF acquisition path for mag_RTN_4sa...
# 📡 Smart check: mag_RTN_4sa files not found locally, will download
# 📡 Local files not found, proceeding with pyspedas download for mag_RTN_4sa
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       5 epad.strahl.colorbar_limits = [8, 11]
#       6 epad.strahl.colorbar_scale = 'log'
# ----> 8 plotbot(trange, mag_rtn_4sa.br, 1, epad.strahl, 2, proton.energy_flux, 3)
#      10 print("Shape of mag_rtn_4sa.br.data:", getattr(mag_rtn_4sa.br, 'data', None).shape if hasattr(mag_rtn_4sa.br, 'data') and mag_rtn_4sa.br.data is not None else "Attribute 'data' not found or is None")
#      12 print("Shape of epad.strahl.data:", getattr(epad.strahl, 'data', None).shape if hasattr(epad.strahl, 'data') and epad.strahl.data is not None else "Attribute 'data' not found or is None")
#
# File ~/GitHub/Plotbot/plotbot/plotbot_main.py:11, in timer_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#       8 @wraps(func)
#       9 def wrapper(*args, **kwargs):
#      10     start_time = timer.perf_counter()
# ---> 11     result = func(*args, **kwargs)
#      12     end_time = timer.perf_counter()
#      13     duration_ms = (end_time - start_time) * 1000
#
# File ~/GitHub/Plotbot/plotbot/plotbot_main.py:419, in plotbot(trange, *args)
#     417 TimeRangeTracker.set_current_trange(trange)
#     418 timer_start = timer.perf_counter()
# --> 419 get_data(trange, *regular_vars)
#     420 timer_end = timer.perf_counter()
#     421 duration_ms = (timer_end - timer_start) * 1000
#
# File ~/GitHub/Plotbot/plotbot/get_data.py:18, in timer_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      15 @wraps(func)
#      16 def wrapper(*args, **kwargs):
#      17     start_time = timer.perf_counter()
# ---> 18     result = func(*args, **kwargs)
#      19     end_time = timer.perf_counter()
#      20     duration_ms = (end_time - start_time) * 1000
#
# File ~/GitHub/Plotbot/plotbot/get_data.py:409, in get_data(trange, skip_refresh_check, *variables)
#     407 if server_mode == 'spdf':
#     408     print_manager.status(f"Attempting SPDF acquisition path for {data_type}...")
# --> 409     download_spdf_data(trange, data_type) # download_successful = download_spdf_data(trange, data_type)
#     410 elif server_mode == 'berkeley' or server_mode == 'berkley':
#     411     print_manager.status(f"Attempting Berkeley acquisition path for {data_type}...")
#
# File ~/GitHub/Plotbot/plotbot/data_download_pyspedas.py:541, in download_spdf_data(trange, plotbot_key)
#     523 try:
#     524     # 1. Check locally ONLY (reliable offline) - REMOVED
#     525     # print_manager.debug(f"Checking SPDF locally (no_update=True) for {pyspedas_datatype}...") # Old debug message
#    (...)    538     # 2. If not found locally, attempt download (only if online) - NOW THE ONLY STEP
#     539     # if not file_path: # Condition removed as this is the only step now
#     540     print_manager.debug(f"Attempting SPDF check/download (no_update=False) for {pyspedas_datatype}...")
# --> 541     returned_data = pyspedas_func(
#     542         trange=trange,
#     543         datatype=pyspedas_datatype,
#     544         # CRITICAL: no_update=False is required!
#     545         # no_update=True ignores level/datatype parameters and returns ANY matching files
#     546         no_update=False, # Must be False to respect level and datatype specifications!
#     547         downloadonly=True,
#     548         notplot=True,
#     549         **kwargs
#     550     )
#     551     # Removed redundant assignment to file_path
#     552     # if returned_data and isinstance(returned_data, list) and len(returned_data) > 0:
#     553     #     file_path = returned_data[0]
#     554     #     # TODO: Add this file path to a cleanup list?
#     555     # else:
#     556     #     print_manager.warning(f"SPDF download attempt for {plotbot_key} did not return a file path.")
#     558 except Exception as e:
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/projects/psp/fields.py:153, in fields(trange, datatype, level, suffix, prefix, get_support_data, varformat, varnames, downloadonly, notplot, no_update, time_clip, username, password, last_version, force_download)
#     148         else:
#     149             spec_types = ['SCMdlfhg_SCMelfhg','SCMdlfhg_SCMflfhg','SCMelfhg_SCMflfhg',
#     150                 'SCMulfhg_SCMvlfhg','SCMulfhg_SCMwlfhg','SCMvlfhg_SCMwlfhg',
#     151                 'dV12hg_dV34hg']
# --> 153 loaded_vars = load(
#     154     instrument='fields', trange=trange, datatype=datatype, spec_types=spec_types, level=level,
#     155     suffix=suffix, prefix=prefix, get_support_data=get_support_data, varformat=varformat, varnames=varnames,
#     156     downloadonly=downloadonly, notplot=notplot, time_clip=time_clip, no_update=no_update,
#     157     username=username, password=password,last_version=last_version, force_download=force_download
#     158 )
#     160 if loaded_vars is None or notplot or downloadonly:
#     161     return loaded_vars
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/projects/psp/load.py:274, in load(trange, instrument, datatype, spec_types, level, suffix, prefix, get_support_data, varformat, varnames, downloadonly, notplot, no_update, time_clip, username, password, last_version, force_download)
#     271 out_files = []
#     273 if username is None:
# --> 274     files = download(remote_file=remote_names, remote_path=CONFIG['remote_data_dir'],
#     275                     local_path=CONFIG['local_data_dir'], no_download=no_update,last_version=last_version, force_download=force_download)
#     276 else:
#     277     if instrument == 'fields':
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/utilities/download.py:762, in download(remote_path, remote_file, local_path, local_file, headers, username, password, verify, session, no_download, last_version, basic_auth, regex, no_wildcards, text_only, force_download)
#     758     remote_path = url_base
#     760 # download the files
#     761 # Add a small delay between requesting the index and requesting the files
# --> 762 sleep(1)
#     764 for new_link in new_links:
#     765     resp_data = download(
#     766         remote_path=remote_path,
#     767         remote_file=short_path + new_link,
#    (...)    776         force_download=force_download
#     777     )
#
# KeyboardInterrupt:

# %%
print_manager.show_status = False
print_manager.show_debug = False
# TRANGE = ['2023-09-28/00:00:00.000', '2023-09-29/00:00:00.000'] # 1 day
# plotbot(TRANGE, mag_rtn_4sa.br, 1, proton.anisotropy, 2, mag_rtn_4sa.br_norm, 3, epad.strahl, 4)
# plotbot(TRANGE, mag_rtn.br, 1, proton.anisotropy, 2, mag_rtn.br_norm, 3, epad.strahl, 4)

# %%
plt.options.reset()
#----Print manager----/// ✨ Two levels of print manager verbosity
print_manager.show_status = False
print_manager.show_debug = False

#an example for how to use the pb.config to change the data server setting
config.data_server = 'berkeley' #<--default to SPDF with Berkeley as a secondary choice
# Server options are 'dynamic', 'spdf' or 'berkeley'

print_manager.show_status = False

Jaye_epad_trange = ['2021/04/26 00:00:00.000', '2021/05/2 00:00:00.000']
plotbot(Jaye_epad_trange, mag_rtn_4sa.br, 1, epad.strahl, 2)

# %%
TRANGE = ['2023-09-28/00:00:00.000', '2023-09-29/00:00:00.000'] # 1 day
plotbot(TRANGE, mag_rtn_4sa.br, 1)

# %%
TRANGE = ['2023-09-28/00:00:00.000', '2023-09-29/00:00:00.000'] # 1 day
plotbot(TRANGE, proton.sun_dist_rsun, 1, mag_rtn_4sa.br_norm, 2)

# %%
# # ✨ Using the original import style for the remainder of the notebook 
# import plotbot
# from plotbot import *

# %%
config.data_server = 'dynamic' # Berkeley is generally the faster way to go!

# %%
#----Print manager----/// ✨ All the available print manager options 

print_manager.show_status = False  # Status prints ⭐️ useful for basic status updates

print_manager.show_debug = False  # Debug prints, helpful for debugging (will print a LOT of information)

print_manager.pyspedas_verbose = False

print_manager.show_processing = False # e.g. Processing mag_RTN_4sa...

print_manager.show_custom_debug = False  # Custom variable operations debugging

print_manager.show_time_tracking = False  # For tracking datetime array inputs and outputs
print_manager.show_warning = False     # Turn off warning messages
print_manager.show_variable_testing = False
print_manager.show_test = False  # Turn off test-specific output

print_manager.show_module_prefix = False  # Show/Hide [print_manager]
print_manager.show_category_prefix = False  # Show/Hide [PROCESS], [TIME], etc.

# %% [markdown]
# ## Proton Fits! (Local CSV required)

# %%
## Example of new proton fits naming convention!

print_manager.show_status = True
fits_trange = ['2024-09-30/11:45:00.000', '2024-09-30/12:45:00.000']

# data_snapshot.save_data_snapshot('project_data.pkl')

plotbot(fits_trange, proton_fits.abs_qz_p, 1, proton_fits.vdrift_va_pfits, 2, proton_fits.valfven_pfits, 3, proton_fits.beta_ppar_pfits, 4, proton_fits.beta_pperp_pfits, 5)
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ proton_fits - acquiring variables: abs_qz_p, vdrift_va_pfits, valfven_pfits, beta_ppar_pfits, beta_pperp_pfits
#
# 📥 Acquiring data for 5 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2024-09-30/11:45:00.000', '2024-09-30/12:45:00.000']
# 🛰️ proton_fits - calculation may be needed
# ✅ Complete
# ⚠️ No datetime array available, returning full data
# ⚠️ No datetime array available, returning full data
# ⚠️ No datetime array available, returning full data
# ⚠️ No datetime array available, returning full data
# ⚠️ No datetime array available, returning full data
# 📈 Plotting proton_fits.abs_qz_p
# 📈 Plotting proton_fits.vdrift_va_pfits
# 📈 Plotting proton_fits.valfven_pfits
# 📈 Plotting proton_fits.beta_ppar_pfits
# 📈 Plotting proton_fits.beta_pperp_pfits

# %% [markdown]
# ## Generate Plots from HAM Files (Local CSV required)

# %%
#Example HAM 🍖 and fits plotbot calls!
plt.options.reset() 

print_manager.show_status = True  # Status prints, ⭐️ useful for basic status updates
print_manager.show_debug = False  # Debug prints, helpful for debugging (will print LOTS of lines)

# %matplotlib inline 
# %matplotlib widget

# ham_trange = ['2025-03-23 11:00:00.000', '2025-03-23 12:00:00.000']

#server_access.username = 'your_username_here'

# ham.trat_ham.y_limit = [0, 50]

# plotbot(ham_trange, ham.trat_ham, 1)

fits_trange = ['2024-09-30/11:45:00.000', '2024-09-30/12:45:00.000']

plotbot(fits_trange, proton_fits.np1, 1, proton_fits.ham_param, 2, proton_fits.Tperp1, 3, proton_fits.vdrift_va_pfits, 4)
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ proton_fits - acquiring variables: np1, ham_param, Tperp1, vdrift_va_pfits
#
# 📥 Acquiring data for 4 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2024-09-30/11:45:00.000', '2024-09-30/12:45:00.000']
# 🛰️ proton_fits - calculation may be needed
# ✅ Complete
# ⚠️ No datetime array available, returning full data
# ⚠️ No datetime array available, returning full data
# ⚠️ No datetime array available, returning full data
# 📈 Plotting proton_fits.np1
# 📈 Plotting proton_fits.ham_param
# 📈 Plotting proton_fits.Tperp1
# 📈 Plotting proton_fits.vdrift_va_pfits

# %%
print_manager.show_status = True
print_manager.show_debug = False
trange = ['2025-03-19 00:00:00.000', '2025-03-27 23:59:59.000']
plotbot(trange,
        ham.hamogram_30s, 1,
        proton.m_alfven, 2,
        proton.density,3,
        proton.bmag,4,
        proton.sun_dist_rsun, 5)
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ spi_sf00_l3_mom - acquiring variables: m_alfven, density, bmag, sun_dist_rsun
# 🛰️ ham - acquiring variables: hamogram_30s
#
# 📥 Acquiring data for 5 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2025-03-19 00:00:00.000', '2025-03-27 23:59:59.000']
# 🛰️ spi_sf00_l3_mom - acquiring variables: m_alfven, density, bmag, sun_dist_rsun
# 🛰️ ham - acquiring variables: hamogram_30s
# Attempting SPDF acquisition path (dynamic mode) for spi_sf00_l3_mom...
# 📡 Smart check: spi_sf00_l3_mom files not found locally, will download
# 📡 Local files not found, proceeding with pyspedas download for spi_sf00_l3_mom
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 4
#       2 print_manager.show_debug = False
#       3 trange = ['2025-03-19 00:00:00.000', '2025-03-27 23:59:59.000']
# ----> 4 plotbot(trange,
#       5         ham.hamogram_30s, 1,
#       6         proton.m_alfven, 2,
#       7         proton.density,3,
#       8         proton.bmag,4,
#       9         proton.sun_dist_rsun, 5)
#
# File ~/GitHub/Plotbot/plotbot/plotbot_main.py:11, in timer_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#       8 @wraps(func)
#       9 def wrapper(*args, **kwargs):
#      10     start_time = timer.perf_counter()
# ---> 11     result = func(*args, **kwargs)
#      12     end_time = timer.perf_counter()
#      13     duration_ms = (end_time - start_time) * 1000
#
# File ~/GitHub/Plotbot/plotbot/plotbot_main.py:419, in plotbot(trange, *args)
#     417 TimeRangeTracker.set_current_trange(trange)
#     418 timer_start = timer.perf_counter()
# --> 419 get_data(trange, *regular_vars)
#     420 timer_end = timer.perf_counter()
#     421 duration_ms = (timer_end - timer_start) * 1000
#
# File ~/GitHub/Plotbot/plotbot/get_data.py:18, in timer_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      15 @wraps(func)
#      16 def wrapper(*args, **kwargs):
#      17     start_time = timer.perf_counter()
# ---> 18     result = func(*args, **kwargs)
#      19     end_time = timer.perf_counter()
#      20     duration_ms = (end_time - start_time) * 1000
#
# File ~/GitHub/Plotbot/plotbot/get_data.py:415, in get_data(trange, skip_refresh_check, *variables)
#     413 elif server_mode == 'dynamic':
#     414     print_manager.status(f"Attempting SPDF acquisition path (dynamic mode) for {data_type}...")
# --> 415     dl_success_spdf = download_spdf_data(trange, data_type)
#     416     if not dl_success_spdf:
#     417         print_manager.status(f"SPDF acquisition path failed/incomplete for {data_type}, falling back to Berkeley...")
#
# File ~/GitHub/Plotbot/plotbot/data_download_pyspedas.py:541, in download_spdf_data(trange, plotbot_key)
#     523 try:
#     524     # 1. Check locally ONLY (reliable offline) - REMOVED
#     525     # print_manager.debug(f"Checking SPDF locally (no_update=True) for {pyspedas_datatype}...") # Old debug message
#    (...)    538     # 2. If not found locally, attempt download (only if online) - NOW THE ONLY STEP
#     539     # if not file_path: # Condition removed as this is the only step now
#     540     print_manager.debug(f"Attempting SPDF check/download (no_update=False) for {pyspedas_datatype}...")
# --> 541     returned_data = pyspedas_func(
#     542         trange=trange,
#     543         datatype=pyspedas_datatype,
#     544         # CRITICAL: no_update=False is required!
#     545         # no_update=True ignores level/datatype parameters and returns ANY matching files
#     546         no_update=False, # Must be False to respect level and datatype specifications!
#     547         downloadonly=True,
#     548         notplot=True,
#     549         **kwargs
#     550     )
#     551     # Removed redundant assignment to file_path
#     552     # if returned_data and isinstance(returned_data, list) and len(returned_data) > 0:
#     553     #     file_path = returned_data[0]
#     554     #     # TODO: Add this file path to a cleanup list?
#     555     # else:
#     556     #     print_manager.warning(f"SPDF download attempt for {plotbot_key} did not return a file path.")
#     558 except Exception as e:
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/projects/psp/spi.py:105, in spi(trange, datatype, level, suffix, prefix, get_support_data, varformat, varnames, downloadonly, notplot, no_update, time_clip, username, password, last_version, force_download)
#     102     level = 'l3'
#     103     print("Using LEVEL=L3")
# --> 105 return load(instrument='spi', trange=trange, datatype=datatype, level=level,
#     106     suffix=suffix, prefix=prefix, get_support_data=get_support_data, varformat=varformat, varnames=varnames,
#     107     downloadonly=downloadonly, notplot=notplot, time_clip=time_clip, no_update=no_update,
#     108     username=username, password=password,last_version=last_version, force_download=force_download
#     109     )
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/projects/psp/load.py:274, in load(trange, instrument, datatype, spec_types, level, suffix, prefix, get_support_data, varformat, varnames, downloadonly, notplot, no_update, time_clip, username, password, last_version, force_download)
#     271 out_files = []
#     273 if username is None:
# --> 274     files = download(remote_file=remote_names, remote_path=CONFIG['remote_data_dir'],
#     275                     local_path=CONFIG['local_data_dir'], no_download=no_update,last_version=last_version, force_download=force_download)
#     276 else:
#     277     if instrument == 'fields':
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/utilities/download.py:762, in download(remote_path, remote_file, local_path, local_file, headers, username, password, verify, session, no_download, last_version, basic_auth, regex, no_wildcards, text_only, force_download)
#     758     remote_path = url_base
#     760 # download the files
#     761 # Add a small delay between requesting the index and requesting the files
# --> 762 sleep(1)
#     764 for new_link in new_links:
#     765     resp_data = download(
#     766         remote_path=remote_path,
#     767         remote_file=short_path + new_link,
#    (...)    776         force_download=force_download
#     777     )
#
# KeyboardInterrupt:

# %% [markdown]
# ## Interactive Plotting

# %%
print_manager.show_status = False # Status prints, ⭐️ useful for basic status updates

#Use inline for static plots and widget for interactive plots
#The panel at the left has options for moving and zooming the plot
# %matplotlib inline 
# %matplotlib widget

#E17 HCS Crossing

server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.

epad.strahl.colorbar_limits = 'default'
epad.strahl.colorbar_scale = 'log'

trange = ['2023-09-28/06:00:00.000', '2023-09-28/07:30:00.000']  # Enc 17 HCS Crossing


plotbot(trange, mag_rtn_4sa.br, 1, mag_rtn_4sa.bmag, 1, mag_rtn_4sa.bt, 2, mag_rtn_4sa.bn, 2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot Hodograms with Custom Variables and Showdahodo

print_manager.show_status = False  # Status prints, ⭐️ useful for basic status updates

#Use inline for static plots and widget for interactive plots
# %matplotlib inline 
# %matplotlib widget

# Define a time range
trange = ['2023-09-28/06:00:00.000', '2023-09-28/07:30:00.000']
# trange = ['2023-10-28/06:00:00.000', '2023-10-28/07:30:00.000']

# Create a custom variable with our elegant syntax
TAplusBmag = custom_variable('TAplusBmag', proton.anisotropy + mag_rtn_4sa.bmag)

# Then use showdahodo with proton.beta_ppar on x-axis and proton.anisotropy on y-axis
# showdahodo(trange, TAplusBmag, proton.anisotropy, brazil=True);
showdahodo(trange, TAplusBmag, proton.anisotropy);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 18
#      14 TAplusBmag = custom_variable('TAplusBmag', proton.anisotropy + mag_rtn_4sa.bmag)
#      16 # Then use showdahodo with proton.beta_ppar on x-axis and proton.anisotropy on y-axis
#      17 # showdahodo(trange, TAplusBmag, proton.anisotropy, brazil=True);
# ---> 18 showdahodo(trange, TAplusBmag, proton.anisotropy);
#
# File ~/GitHub/Plotbot/plotbot/showdahodo.py:459, in showdahodo(trange, var1, var2, var3, color_var, norm_, xlim_, ylim_, zlim_, s_, alpha_, xlabel_, ylabel_, zlabel_, clabel_, xlog_, ylog_, zlog_, cmap_, elev, azi, roll, sort, invsort, lumsort, brazil, corr, wvpow, rsun, noshow, face_c, face_a, fname)
#     457 else:
#     458     ax = fig.add_subplot()
# --> 459     s = ax.scatter(values1, values2, c=colors, cmap=cmap_, norm=norm_, s=s_, alpha=alpha_)
#     460     cbar = plt.colorbar(s, label=color_label)
#     462 #set colorbar to no transparency
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4787, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4785 y = np.ma.ravel(y)
#    4786 if x.size != y.size:
# -> 4787     raise ValueError("x and y must be the same size")
#    4789 if s is None:
#    4790     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4791          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
# #An example with password protected data

# #E21 Glory Region! 
# print_manager.show_status = False  # Status prints, useful for status updates
# print_manager.show_debug = False   # Debug prints, helpful for debugging

# server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.

# epad.strahl.colorbar_limits = [10.4, 11]
# epad.strahl.colorbar_scale = 'log'

# trange = ['2024-09-30/12:10:00.000', '2024-09-30/12:20:00.000']
# # plotbot(trange, mag_rtn_4sa.all, 1, mag_rtn_4sa.bmag, 1, 
# #         epad_hr.strahl, 2, 
# #         proton_hr.energy_flux, 3, 
# #         proton_hr.t_perp, 4, 
# #         proton_hr.t_par, 4, proton_hr.anisotropy, '4r', 
# #         proton_hr.v_sw, 5, proton_hr.v_alfven, '5r')

# plotbot(trange, mag_rtn_4sa.br, 1, mag_rtn_4sa.bmag, 1, 
#         mag_rtn_4sa.bt, 2, mag_rtn_4sa.bn, 2, 
#         epad.strahl, 3, 
#         proton.energy_flux, 4, 
#         proton.theta_flux, 5, 
#         proton.phi_flux, 6, 
#         proton.t_perp, 7, 
#         proton.t_par, 7, proton.anisotropy, '7r', 
#         proton.v_sw, 8, proton.v_alfven, 8)

# %% [markdown]
# ## Math with Plotbot.data

# %%
#Working with Plotbot.data!! (the format is actually "mag_rtn_4sa.bmag.data " but you know what I mean...)

# Statistical Analysis of Magnetic Field Data
print("=== Magnetic Field Data Analysis ===\n")

trange = ['2023-09-28/06:00:00.000', '2023-09-28/07:30:00.000']  # Enc 17 HCS Crossing

plotbot(trange, mag_rtn_4sa.bmag, 1)

# Convert plot_manager objects to numpy arrays for analysis
bmag_data = mag_rtn_4sa.bmag.data  
br_data = mag_rtn_4sa.br.data
bt_data = mag_rtn_4sa.bt.data
bn_data = mag_rtn_4sa.bn.data

# Basic checks
print("1. Data Structure Checks:")
print(f"Data type: {type(mag_rtn_4sa.bmag)}")
print(f"Shape: {np.shape(bmag_data)}")
print(f"Number of points: {len(bmag_data)}")
print(f"Memory usage: {bmag_data.nbytes / 1e6:.2f} MB\n")

# Basic statistics
print("2. Basic Statistics:")
print(f"Mean |B|: {np.nanmean(bmag_data):.2f} nT")
print(f"Median |B|: {np.nanmedian(bmag_data):.2f} nT")
print(f"Standard deviation: {np.nanstd(bmag_data):.2f} nT")
print(f"Min |B|: {np.nanmin(bmag_data):.2f} nT")
print(f"Max |B|: {np.nanmax(bmag_data):.2f} nT\n")

# Component analysis
print("3. Component Analysis:")
print("Mean values:")
print(f"⟨Br⟩: {np.nanmean(br_data):.2f} nT")
print(f"⟨Bt⟩: {np.nanmean(bt_data):.2f} nT")
print(f"⟨Bn⟩: {np.nanmean(bn_data):.2f} nT\n")

# Calculate field angles
theta = np.arctan2(np.sqrt(bt_data**2 + bn_data**2), br_data)
phi = np.arctan2(bn_data, bt_data)

print("4. Field Orientation:")
print(f"Mean θ (from radial): {np.degrees(np.nanmean(theta)):.2f}°")
print(f"Mean φ (azimuthal): {np.degrees(np.nanmean(phi)):.2f}°\n")

# Power and energy density
mu0 = 4 * np.pi * 1e-7  # permeability of free space
B_squared = bmag_data**2
energy_density = B_squared / (2 * mu0) * 1e-9  # Convert to J/m^3

print("5. Energy Analysis:")
print(f"Mean B²: {np.nanmean(B_squared):.2f} nT²")
print(f"Mean magnetic energy density: {np.nanmean(energy_density):.2e} J/m³\n")

# Time series analysis
if hasattr(mag_rtn_4sa, 'datetime_array'):
    print("6. Time Series Properties:")
    # Convert datetime array to numeric values for time difference calculation
    time_array = np.array(mag_rtn_4sa.datetime_array, dtype='datetime64[ns]')
    time_diffs = np.diff(time_array)
    mean_cadence_ns = np.mean(time_diffs)
    mean_cadence_s = mean_cadence_ns / np.timedelta64(1, 's')  # Convert to seconds
    print(f"Mean sampling cadence: {mean_cadence_s:.6f} seconds")
    
    # Calculate power spectrum using sampling frequency in Hz
    from scipy import signal
    fs = 1.0 / mean_cadence_s
    # Remove NaN values for spectrum calculation
    valid_data = bmag_data[~np.isnan(bmag_data)]
    if len(valid_data) > 0:
        f, Pxx = signal.welch(valid_data - np.mean(valid_data), fs=fs)
        peak_freq = f[np.argmax(Pxx)]
        print(f"Dominant frequency in power spectrum: {peak_freq:.2e} Hz\n")

# Data quality checks
print("7. Data Quality Metrics:")
print(f"Number of NaN values: {np.sum(np.isnan(bmag_data))}")
print(f"Number of zeros: {np.sum(bmag_data == 0)}")
print(f"Number of values > 3σ: {np.sum(np.abs(bmag_data - np.nanmean(bmag_data)) > 3*np.nanstd(bmag_data))}\n")

# Visualization
plt.figure(figsize=(12, 8))

# Plot 1: Histogram of |B|
plt.subplot(221)
plt.hist(bmag_data[~np.isnan(bmag_data)], bins=50, density=True)
plt.title('|B| Distribution')
plt.xlabel('|B| (nT)')
plt.ylabel('Density')

# Plot 2: Component correlations
plt.subplot(222)
mask = ~np.isnan(br_data) & ~np.isnan(bt_data)
plt.scatter(br_data[mask], bt_data[mask], alpha=0.1)
plt.xlabel('Br (nT)')
plt.ylabel('Bt (nT)')
plt.title('Br vs Bt')

# Plot 3: Field angle distribution
plt.subplot(223)
mask = ~np.isnan(theta) & ~np.isnan(phi)
plt.hist2d(np.degrees(theta[mask]), np.degrees(phi[mask]), bins=50)
plt.xlabel('θ (degrees)')
plt.ylabel('φ (degrees)')
plt.title('Field Angle Distribution')
plt.colorbar()

# Plot 4: Power spectrum
plt.subplot(224)
if hasattr(mag_rtn_4sa, 'datetime_array'):
    valid_data = bmag_data[~np.isnan(bmag_data)]
    if len(valid_data) > 0:
        plt.loglog(f, Pxx)
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('Power Spectral Density')
        plt.title('Power Spectrum')

plt.tight_layout()
plt.show()
# Out:
# === Magnetic Field Data Analysis ===
#
# UPDATE GLOBAL ERROR - Error calling update() on instance: name 'np' is not defined
# [mag_rtn_4sa getattr] 'np' is not a recognized attribute, friend!
# [mag_rtn_4sa getattr] Try one of these: all, br, bt, bn, bmag, pmag, br_norm
# Traceback (most recent call last):
#   File "/Users/robertalexander/GitHub/Plotbot/plotbot/data_cubby.py", line 954, in update_global_instance
#     global_instance.update(imported_data_obj, original_requested_trange=original_requested_trange)
#   File "/Users/robertalexander/GitHub/Plotbot/plotbot/data_classes/psp_mag_rtn_4sa.py", line 90, in update
#     self.calculate_variables(imported_data)                                # Update raw data arrays
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/robertalexander/GitHub/Plotbot/plotbot/data_classes/psp_mag_rtn_4sa.py", line 295, in calculate_variables
#     self.time = np.asarray(imported_data.times)
#                 ^^
# NameError: name 'np' is not defined. Did you mean: 'self.np'?
# 1. Data Structure Checks:
# Data type: <class 'plotbot.plot_manager.plot_manager'>
# Shape: ()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 20
#      18 print(f"Data type: {type(mag_rtn_4sa.bmag)}")
#      19 print(f"Shape: {np.shape(bmag_data)}")
# ---> 20 print(f"Number of points: {len(bmag_data)}")
#      21 print(f"Memory usage: {bmag_data.nbytes / 1e6:.2f} MB\n")
#      23 # Basic statistics
#
# TypeError: len() of unsized object
