# %% [markdown]
# ## Welcome to Plotbot!

# %% [markdown]
# 👋 Welcome to Plotbot! A your class-oriented workflow optimizer for downloading and plotting data from the Parker Solar Probe. Created by Dr. Jaye Verniero and Dr. Robert Alexander. Note: this is a work in progress.

# %% [markdown]
# ⚡️Plotbot utilizes active calculation caching⚡️
#    ⚡️Calculate once and forget about it⚡️

# %% [markdown]
# First, click in the upper right hand corner of this window to select the plotbot environment. It should be named plotbot_env (Python 3.12.4). Alternatively, you'll be prompted to select the environment when you run the first cell below.

# %% [markdown]
# ### Plotbot

# %% [markdown]
# Let's get started by importing plotbot:

# %%
#Remember to select the Plotbot Environment!
from plotbot import *
# Out:
# initialized server_access
# initialized global_tracker
# initialized plot_config
# initialized data_cubby.
# initialized plot_manager
# CDF classes added to data_cubby type map.
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized proton_fits class
# initialized alpha_fits class
# initialized ham_class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# 🎛️ initialized ploptions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# ✅ Deferred heavy data libraries (cdflib, requests, bs4) - loaded when needed.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#
# 🤖 Plotbot Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_10_28_v3.73
#    Commit: v3.73 Bugfix: Fixed WIND data local file detection and x-axis time formatting for short time ranges at midnight
#
# Import timing is disabled.

# %%
# -------CONFIGURE THE DEFAULT DATA DIRECTORY-------//
# This must be set before pyspedas is imported/run, as pyspedas caches configuration at import time.

config.data_dir = '../data'  # Go up one level to Plotbot/data/

import os
print(f"📁 Data directory absolute path: {os.path.abspath(config.data_dir)}")

# -------CONFIGURE THE DEFAULT DATA SERVER-------//

config.data_server = 'spdf'
# config.data_server = 'berkeley'
# config.data_server = 'dynamic' #Will attempt to download from spdf first and then try berkeley

# -------CONFIGURE PRINT MANAGER-------//
print_manager.show_status = True
# print_manager.show_debug = True      # Optional: uncomment for maximum detail
# print_manager.show_processing = True # Optional: uncomment for processing steps
# print_manager.show_datacubby = True  # Optional: uncomment for data caching steps
# Out:
# 📁 Plotbot data directory changed: /Users/robertalexander/GitHub/Plotbot/data → ../data
# 🔧 SPEDAS_DATA_DIR updated for pyspedas compatibility
# 📁 Data directory absolute path: /Users/robertalexander/GitHub/Plotbot/data

# %% [markdown]
# #### ✨ The Data Snapshot! Save All Current Calculations to .pkl✨

# %%
# #Uncomment to explore the data snapshot!

# #Never wait for calculations again!
# #At the end of your session, save your cache'd calculations to a .pkl file:
# save_simple_snapshot('my_calculated_data.pkl') 

# # Load the cache at the beginning of your next session like this: 
# load_simple_snapshot('my_calculated_data.pkl') 

# # And the best part? Any new calculations will automatically be
# # merged with your import, and you can just save again at the
# # end of your next session!

# %% [markdown]
# #### ✨Diving In✨

# %%
import os
print(f"Working directory: {os.getcwd()}")
print(f"SPEDAS_DATA_DIR: {os.environ.get('SPEDAS_DATA_DIR', 'NOT_SET')}")
print(f"config.data_dir: {config.data_dir}")
# Out:
# Working directory: /Users/robertalexander/GitHub/Plotbot/example_notebooks
# SPEDAS_DATA_DIR: /Users/robertalexander/GitHub/Plotbot/data
# config.data_dir: ../data

# %%
print_manager.show_status = True
print_manager.show_debug = True
print_manager.show_data_cubby = True

# %%
plt.options.reset()

trange = ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']

mag_sc_4sa.bx.y_limit = [0, 100]

# plotbot(trange, mag_sc_4sa.bx, 1)
plotbot(trange, mag_rtn_4sa.br, 1, mag_rtn_4sa.bt, 2, mag_rtn_4sa.bn, 3)

print("Shape of mag_sc_4sa.bx.data:", getattr(mag_sc_4sa.bx, 'data', None).shape if hasattr(mag_sc_4sa.bx, 'data') and mag_sc_4sa.bx.data is not None else "Attribute 'data' not found or is None")
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🕒 TimeRangeTracker: Cleared trange
# 🛰️ mag_RTN_4sa - acquiring variables: br, bt, bn
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077750096 for key 'mag_rtn_4sa'. dt_len: 395507, min: 2021-04-26T00:00:00.131039232, max: 2021-04-26T23:59:59.999815936
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(395507,), range=2021-04-26T00:00:00.131039 to 2021-04-26T23:59:59.999815
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all(list): len=3, elem_shape=(395507,) | br: type=ndarray, shape=(395507,) | bt: type=ndarray, shape=(395507,) | bn: type=ndarray, shape=(395507,) | bmag: type=ndarray, shape=(395507,) | pmag: type=ndarray, shape=(395507,) | b_phi: type=ndarray, shape=(395507,) | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077750096 for key 'mag_rtn_4sa'. dt_len: 395507, min: 2021-04-26T00:00:00.131039232, max: 2021-04-26T23:59:59.999815936
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(395507,), range=2021-04-26T00:00:00.131039 to 2021-04-26T23:59:59.999815
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all(list): len=3, elem_shape=(395507,) | br: type=ndarray, shape=(395507,) | bt: type=ndarray, shape=(395507,) | bn: type=ndarray, shape=(395507,) | bmag: type=ndarray, shape=(395507,) | pmag: type=ndarray, shape=(395507,) | b_phi: type=ndarray, shape=(395507,) | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077750096 for key 'mag_rtn_4sa'. dt_len: 395507, min: 2021-04-26T00:00:00.131039232, max: 2021-04-26T23:59:59.999815936
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(395507,), range=2021-04-26T00:00:00.131039 to 2021-04-26T23:59:59.999815
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all(list): len=3, elem_shape=(395507,) | br: type=ndarray, shape=(395507,) | bt: type=ndarray, shape=(395507,) | bn: type=ndarray, shape=(395507,) | bmag: type=ndarray, shape=(395507,) | pmag: type=ndarray, shape=(395507,) | b_phi: type=ndarray, shape=(395507,) | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
#
# 📥 Acquiring data for 3 variables...
# 🕒 TimeRangeTracker: Stored trange ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# 🛰️ mag_RTN_4sa - acquiring variables: br, bt, bn
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/get_data.py:425
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077750096 for key 'mag_rtn_4sa'. dt_len: 395507, min: 2021-04-26T00:00:00.131039232, max: 2021-04-26T23:59:59.999815936
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(395507,), range=2021-04-26T00:00:00.131039 to 2021-04-26T23:59:59.999815
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all(list): len=3, elem_shape=(395507,) | br: type=ndarray, shape=(395507,) | bt: type=ndarray, shape=(395507,) | bn: type=ndarray, shape=(395507,) | bmag: type=ndarray, shape=(395507,) | pmag: type=ndarray, shape=(395507,) | b_phi: type=ndarray, shape=(395507,) | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Attempting SPDF acquisition path for mag_RTN_4sa...
# [DOWNLOAD_SPDF_ENTRY] Received trange: ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000'], data_type: mag_RTN_4sa
# Attempting SPDF download for mag_RTN_4sa in range ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# ✅ Smart check found 3 local mag_RTN_4sa file(s):
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210426_v02.cdf
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210427_v02.cdf
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210428_v02.cdf
# ✅ Using local mag_RTN_4sa files (skipping pyspedas)
# Import data function called
# Input trange: ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
#
# Importing data for UTC time range: ['2021/04/26 00:00:00', '2021/04/28 00:00:00']
#   Requested datetime range (from TT2000 conversion): 2021-04-26T00:00:00.000000000 to 2021-04-28T00:00:00.000000000
# daterange called with start_date=2021-04-26 00:00:00+00:00, end_date=2021-04-28 00:00:00+00:00
# End date is midnight, adjusting to previous day: 2021-04-27
# Converted start_date to date: 2021-04-26
# Will generate 2 dates
# Yielding date: 2021-04-26
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210426_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2021'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20210426_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210426_v.*.cdf
# Yielding date: 2021-04-27
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210427_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2021'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20210427_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210427_v.*.cdf
# Found 2 unique CDF files to process.
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210426_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 672667269315039232 (2021-04-26T00:00:00.131039232) to 672753669183815936 (2021-04-26T23:59:59.999815936)
#     Comparison: File ends before request starts? False (FileEnd: 672753669183815936 < ReqStart: 672667269184000000)
#     Comparison: File starts after request ends? False (FileStart: 672667269315039232 > ReqEnd: 672840069184000000)
# Reading full time data array...
# Read 395507 time points
# Time indices: 0 to 395507
# Extracted 395507 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (395507, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210427_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 672753669402269440 (2021-04-27T00:00:00.218269440) to 672840069078715136 (2021-04-27T23:59:59.894715136)
#     Comparison: File ends before request starts? False (FileEnd: 672840069078715136 < ReqStart: 672667269184000000)
#     Comparison: File starts after request ends? False (FileStart: 672753669402269440 > ReqEnd: 672840069184000000)
# Reading full time data array...
# Read 395506 time points
# Time indices: 0 to 395506
# Extracted 395506 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (395506, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Concatenating CDF data...
#   Concatenated psp_fld_l2_mag_RTN_4_Sa_per_Cyc (Shape: (791013, 3))
#
# Total CDF data points after concatenation: 791013
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2021/04/26 00:00:00', '2021/04/28 00:00:00'].
#
# *** IMPORT_DATA_DEBUG (CDF Path) for data_type 'mag_RTN_4sa' (originally requested: 'mag_RTN_4sa') ***
# [CUBBY]     data_object ID: 13281958784
# [CUBBY]     DataObject.times length: 791013, dtype: int64
# [CUBBY]     data_object.data ID: 13300454144
# [CUBBY]     DataObject.data keys: ['psp_fld_l2_mag_RTN_4_Sa_per_Cyc']
# [CUBBY]         'psp_fld_l2_mag_RTN_4_Sa_per_Cyc' is PRESENT. Type: <class 'numpy.ndarray'>, Shape: (791013, 3), Len: 791013
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'mag_rtn_4sa' -> 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Searching for instance of type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> in class_registry with 33 entries
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_auto' -> <class 'plotbot.data_classes.custom_classes.psp_waves_auto.psp_waves_auto_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.demo_spectral_waves.demo_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_wave_power' -> <class 'plotbot.data_classes.custom_classes.demo_wave_power.demo_wave_power_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_real_test' -> <class 'plotbot.data_classes.custom_classes.psp_waves_real_test.psp_waves_real_test_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.psp_spectral_waves.psp_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'alpha_fits' -> <class 'plotbot.data_classes.psp_alpha_fits_classes.alpha_fits_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] ✅ MATCH FOUND by type lookup
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 395507
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# [CUBBY] Global instance has existing data. Attempting merge...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'mag_rtn_4sa' -> 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] Processing new imported data into temporary instance...
# [CUBBY] ✅ New data processed.
# [CUBBY] Calling _merge_arrays...
# [CUBBY]
# 🔥 ULTIMATE MERGE ENGINE ACTIVATED 🔥
# [CUBBY] 📊 MERGE STATS:
# [CUBBY]    Existing: 395,507 records
# [CUBBY]    New: 791,013 records
# [CUBBY]    Potential total: 1,186,520 records
# [CUBBY] 🔄 OVERLAP DETECTED - Full merge required
# [CUBBY] ⚡ Computing unique merged times...
# [CUBBY] ✅ Unique times: 791,013 records (395,507 duplicates removed)
# [CUBBY] 🏎️ SPEED MODE: Using vectorized processing
# [CUBBY] ⚠️ Skipping key 'br_norm' - both arrays are None
# [CUBBY] 🏁 MERGE COMPLETE!
# [CUBBY]    Final records: 791,013
# [CUBBY]    Duration: 0.04s
# [CUBBY]    Speed: 21,636,516 records/sec
# [CUBBY]    Session total: 791,013 records
# [CUBBY]    Session avg: 21,636,516 records/sec
# ✅ DataCubby processed update for mag_rtn_4sa.
# Updated and merged ranges for mag_RTN_4sa: [(datetime.datetime(2021, 4, 26, 0, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2021, 4, 28, 0, 0, tzinfo=datetime.timezone.utc))]
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:380
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077750096 for key 'mag_rtn_4sa'. dt_len: 791013, min: 2021-04-26T00:00:00.131039232, max: 2021-04-27T23:59:59.894715136
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(791013,), range=2021-04-26T00:00:00.131039 to 2021-04-27T23:59:59.894715
# [CUBBY] GRAB OUTPUT - raw_data keys=['pmag', 'bmag', 'bt', 'bn', 'br', 'b_phi', 'all'] | pmag: type=ndarray, shape=(791013,) | bmag: type=ndarray, shape=(791013,) | bt: type=ndarray, shape=(791013,) | bn: type=ndarray, shape=(791013,) | br: type=ndarray, shape=(791013,) | b_phi: type=ndarray, shape=(791013,) | all(list): len=3, elem_shape=(791013,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# ⚡ [CLIP_ONCE] Clipping data ONCE for trange: ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# 🔍 [DEBUG] clip_to_original_trange called with trange: ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# 🔍 [DEBUG] Clipping 791013 points to 791013 points in range
#
# DEBUG:
# var: [ -87.1162    -87.110115  -87.16895  ... -197.3873   -196.39766
#  -199.65724 ]
# var type: <class 'plotbot.plot_manager.plot_manager'>
# var.datetime_array type: <class 'numpy.ndarray'>
# First element type: <class 'numpy.datetime64'>
# First element: 2021-04-26T00:00:00.131039232
# Time range: 2021-04-26T00:00:00.131039232 to 2021-04-27T23:59:59.894715136
# var.data type: <class 'numpy.ndarray'>
# var.data shape: (791013,)
#
# Variable verification for mag_rtn_4sa.br:
# Plot attributes example:
# - Color: forestgreen
# - Y-label: B (nT)
# - Legend: $B_R$
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:380
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077750096 for key 'mag_rtn_4sa'. dt_len: 791013, min: 2021-04-26T00:00:00.131039232, max: 2021-04-27T23:59:59.894715136
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(791013,), range=2021-04-26T00:00:00.131039 to 2021-04-27T23:59:59.894715
# [CUBBY] GRAB OUTPUT - raw_data keys=['pmag', 'bmag', 'bt', 'bn', 'br', 'b_phi', 'all'] | pmag: type=ndarray, shape=(791013,) | bmag: type=ndarray, shape=(791013,) | bt: type=ndarray, shape=(791013,) | bn: type=ndarray, shape=(791013,) | br: type=ndarray, shape=(791013,) | b_phi: type=ndarray, shape=(791013,) | all(list): len=3, elem_shape=(791013,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# ⚡ [CLIP_ONCE] Clipping data ONCE for trange: ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# 🔍 [DEBUG] clip_to_original_trange called with trange: ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# 🔍 [DEBUG] Clipping 791013 points to 791013 points in range
#
# DEBUG:
# var: [24.218842 24.36187  24.648514 ... 69.85576  68.064644 64.54213 ]
# var type: <class 'plotbot.plot_manager.plot_manager'>
# var.datetime_array type: <class 'numpy.ndarray'>
# First element type: <class 'numpy.datetime64'>
# First element: 2021-04-26T00:00:00.131039232
# Time range: 2021-04-26T00:00:00.131039232 to 2021-04-27T23:59:59.894715136
# var.data type: <class 'numpy.ndarray'>
# var.data shape: (791013,)
#
# Variable verification for mag_rtn_4sa.bt:
# Plot attributes example:
# - Color: orange
# - Y-label: B (nT)
# - Legend: $B_T$
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:380
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077750096 for key 'mag_rtn_4sa'. dt_len: 791013, min: 2021-04-26T00:00:00.131039232, max: 2021-04-27T23:59:59.894715136
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(791013,), range=2021-04-26T00:00:00.131039 to 2021-04-27T23:59:59.894715
# [CUBBY] GRAB OUTPUT - raw_data keys=['pmag', 'bmag', 'bt', 'bn', 'br', 'b_phi', 'all'] | pmag: type=ndarray, shape=(791013,) | bmag: type=ndarray, shape=(791013,) | bt: type=ndarray, shape=(791013,) | bn: type=ndarray, shape=(791013,) | br: type=ndarray, shape=(791013,) | b_phi: type=ndarray, shape=(791013,) | all(list): len=3, elem_shape=(791013,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# ⚡ [CLIP_ONCE] Clipping data ONCE for trange: ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# 🔍 [DEBUG] clip_to_original_trange called with trange: ['2021/04/26 00:00:00.000', '2021/04/28 00:00:00.000']
# 🔍 [DEBUG] Clipping 791013 points to 791013 points in range
#
# DEBUG:
# var: [ 3.6780324  2.081369   2.587941  ... 70.800415  68.54426   67.616455 ]
# var type: <class 'plotbot.plot_manager.plot_manager'>
# var.datetime_array type: <class 'numpy.ndarray'>
# First element type: <class 'numpy.datetime64'>
# First element: 2021-04-26T00:00:00.131039232
# Time range: 2021-04-26T00:00:00.131039232 to 2021-04-27T23:59:59.894715136
# var.data type: <class 'numpy.ndarray'>
# var.data shape: (791013,)
#
# Variable verification for mag_rtn_4sa.bn:
# Plot attributes example:
# - Color: dodgerblue
# - Y-label: B (nT)
# - Legend: $B_N$
# 📈 Plotting mag_rtn_4sa.br
# 🔍 TIME_CLIP_DEBUG for mag_rtn_4sa.br:
#    raw_datetime_array: len=791013, range=2021-04-26T00:00:00.131039232 to 2021-04-27T23:59:59.894715136
#    requested trange: 2021/04/26 00:00:00.000 to 2021/04/28 00:00:00.000
#    time_clip returned 791013 indices
# 🔍 DATA_CLIP_DEBUG for mag_rtn_4sa.br:
#    data.shape=(791013,), time_indices.shape=(791013,)
#    data_clipped.shape=(791013,), has_nans=False, all_nans=False
# 📈 Plotting mag_rtn_4sa.bt
# 🔍 TIME_CLIP_DEBUG for mag_rtn_4sa.bt:
#    raw_datetime_array: len=791013, range=2021-04-26T00:00:00.131039232 to 2021-04-27T23:59:59.894715136
#    requested trange: 2021/04/26 00:00:00.000 to 2021/04/28 00:00:00.000
#    time_clip returned 791013 indices
# 🔍 DATA_CLIP_DEBUG for mag_rtn_4sa.bt:
#    data.shape=(791013,), time_indices.shape=(791013,)
#    data_clipped.shape=(791013,), has_nans=False, all_nans=False
# 📈 Plotting mag_rtn_4sa.bn
# 🔍 TIME_CLIP_DEBUG for mag_rtn_4sa.bn:
#    raw_datetime_array: len=791013, range=2021-04-26T00:00:00.131039232 to 2021-04-27T23:59:59.894715136
#    requested trange: 2021/04/26 00:00:00.000 to 2021/04/28 00:00:00.000
#    time_clip returned 791013 indices
# 🔍 DATA_CLIP_DEBUG for mag_rtn_4sa.bn:
#    data.shape=(791013,), time_indices.shape=(791013,)
#    data_clipped.shape=(791013,), has_nans=False, all_nans=False
# Shape of mag_sc_4sa.bx.data: (0,)

# %%
from plotbot import *

trange = ['2021/04/26 00:00:00.000', '2021/04/26 00:01:00.000']

mag_rtn_4sa.b_phi.marker_size = 1  # Make it bigger or smaller

# PSP
plotbot(trange, mag_rtn_4sa.b_phi, 1, mag_rtn.b_phi, 2, wind_mfi_h2.b_phi, 3)
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🕒 TimeRangeTracker: Cleared trange
# 🛰️ wind_mfi_h2 - acquiring variables: b_phi
# 🛰️ mag_RTN - acquiring variables: b_phi
# 🛰️ mag_RTN_4sa - acquiring variables: b_phi
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077750096 for key 'mag_rtn_4sa'. dt_len: 395507, min: 2021-04-26T00:00:00.131039232, max: 2021-04-26T23:59:59.999815936
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(395507,), range=2021-04-26T00:00:00.131039 to 2021-04-26T23:59:59.999815
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all(list): len=3, elem_shape=(395507,) | br: type=ndarray, shape=(395507,) | bt: type=ndarray, shape=(395507,) | bn: type=ndarray, shape=(395507,) | bmag: type=ndarray, shape=(395507,) | pmag: type=ndarray, shape=(395507,) | b_phi: type=ndarray, shape=(395507,) | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
# [CUBBY]
# === Retrieving mag_rtn from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn with type <class 'plotbot.data_classes.psp_mag_rtn.mag_rtn_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077752304 for key 'mag_rtn'. dt_len: None_or_NoAttr, min: N/A, max: N/A
# [CUBBY] GRAB OUTPUT - No datetime_array attribute found
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all: type=NoneType, shape=N/A | br: type=NoneType, shape=N/A | bt: type=NoneType, shape=N/A | bn: type=NoneType, shape=N/A | bmag: type=NoneType, shape=N/A | pmag: type=NoneType, shape=N/A | b_phi: type=NoneType, shape=N/A | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
# [CUBBY]
# === Retrieving wind_mfi_h2 from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved wind_mfi_h2 with type <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6078175792 for key 'wind_mfi_h2'. dt_len: None_or_NoAttr, min: N/A, max: N/A
# [CUBBY] GRAB OUTPUT - No datetime_array attribute found
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'bx', 'by', 'bz', 'bmag', 'b_phi', 'bgse'] | all: type=NoneType, shape=N/A | bx: type=NoneType, shape=N/A | by: type=NoneType, shape=N/A | bz: type=NoneType, shape=N/A | bmag: type=NoneType, shape=N/A | b_phi: type=NoneType, shape=N/A | bgse: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
#
# mag_RTN_4sa already calculated for the time range: 2021/04/26 00:00:00.000 to 2021/04/26 00:01:00.000
# 📥 Acquiring data for 3 variables...
# 🕒 TimeRangeTracker: Stored trange ['2021/04/26 00:00:00.000', '2021/04/26 00:01:00.000']
# 🛰️ wind_mfi_h2 - acquiring variables: b_phi
# 🛰️ mag_RTN - acquiring variables: b_phi
# 🛰️ mag_RTN_4sa - acquiring variables: b_phi
# 📋 Required data types: {'wind_mfi_h2', 'mag_RTN', 'mag_RTN_4sa'}
# 🔄 Processing: wind_mfi_h2
# [CUBBY]
# === Retrieving wind_mfi_h2 from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/get_data.py:425
# [CUBBY] GRAB SUCCESS - Retrieved wind_mfi_h2 with type <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6078175792 for key 'wind_mfi_h2'. dt_len: None_or_NoAttr, min: N/A, max: N/A
# [CUBBY] GRAB OUTPUT - No datetime_array attribute found
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'bx', 'by', 'bz', 'bmag', 'b_phi', 'bgse'] | all: type=NoneType, shape=N/A | bx: type=NoneType, shape=N/A | by: type=NoneType, shape=N/A | bz: type=NoneType, shape=N/A | bmag: type=NoneType, shape=N/A | b_phi: type=NoneType, shape=N/A | bgse: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Attempting SPDF acquisition path for wind_mfi_h2...
# [DOWNLOAD_SPDF_ENTRY] Received trange: ['2021/04/26 00:00:00.000', '2021/04/26 00:01:00.000'], data_type: wind_mfi_h2
# Attempting SPDF download for wind_mfi_h2 in range ['2021/04/26 00:00:00.000', '2021/04/26 00:01:00.000']
# ✅ Smart check found 1 local wind_mfi_h2 file(s):
#    📁 ../data/wind/mfi/mfi_h2/2021/wi_h2_mfi_20210426_v05.cdf
# ✅ Using local wind_mfi_h2 files (skipping pyspedas)
# Import data function called
# Input trange: ['2021/04/26 00:00:00.000', '2021/04/26 00:01:00.000']
#
# Importing data for UTC time range: ['2021/04/26 00:00:00', '2021/04/26 00:01:00']
#   Requested datetime range (from TT2000 conversion): 2021-04-26T00:00:00.000000000 to 2021-04-26T00:01:00.000000000
# daterange called with start_date=2021-04-26 00:00:00+00:00, end_date=2021-04-26 00:01:00+00:00
# End date has time component, using full day: 2021-04-26
# Converted start_date to date: 2021-04-26
# Will generate 1 dates
# Yielding date: 2021-04-26
#     Searching for DAILY pattern: 'wi_h2_mfi_20210426_v*.cdf' in dir: '../data/wind/mfi/mfi_h2/2021'
#       MATCHED file: wi_h2_mfi_20210426_v05.cdf with pattern wi_h2_mfi_20210426_v.*.cdf
# Found 1 unique CDF files to process.
#
# Processing CDF file: ../data/wind/mfi/mfi_h2/2021/wi_h2_mfi_20210426_v05.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_EPOCH
#   Converting CDF_EPOCH to TT2000 for WIND compatibility (boundary check)
#   Converting 2 CDF_EPOCH values to TT2000 using optimized Numba method
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
#   Numba conversion completed: 2 values converted in 0.368 seconds
#   File actual TT2000 range: 672667269194996224 (2021-04-26T00:00:00.010996224) to 672753669145996160 (2021-04-26T23:59:59.961996160)
#     Comparison: File ends before request starts? False (FileEnd: 672753669145996160 < ReqStart: 672667269184000000)
#     Comparison: File starts after request ends? False (FileStart: 672667269194996224 > ReqEnd: 672667329184000000)
# Reading full time data array...
# Read 934712 time points
#   Converting full time array from CDF_EPOCH to TT2000 using vectorized method
#   Converting 934712 CDF_EPOCH values to TT2000 using optimized Numba method
#   Numba conversion completed: 934712 values converted in 0.001 seconds
#   Conversion rate: 1579559339 values/second
#   Vectorized conversion completed: 934712 time points converted to TT2000
# Time indices: 0 to 653
# Extracted 653 time points within requested range
#
# Reading variable: Epoch
# Raw data shape: (653,)
# Successfully stored data slice for Epoch
#
# Reading variable: BGSE
# Raw data shape: (653, 3)
# Successfully stored data slice for BGSE
#
# Reading variable: BF1
# Raw data shape: (653,)
# Successfully stored data slice for BF1
#
# Concatenating CDF data...
#   Concatenated Epoch (Shape: (653,))
#   Concatenated BGSE (Shape: (653, 3))
#   Concatenated BF1 (Shape: (653,))
#
# Total CDF data points after concatenation: 653
# ☑️ - CDF Data import complete for wind_mfi_h2 range ['2021/04/26 00:00:00', '2021/04/26 00:01:00'].
#
# *** IMPORT_DATA_DEBUG (CDF Path) for data_type 'wind_mfi_h2' (originally requested: 'wind_mfi_h2') ***
# [CUBBY]     data_object ID: 6416542784
# [CUBBY]     DataObject.times length: 653, dtype: int64
# [CUBBY]     data_object.data ID: 12983722752
# [CUBBY]     DataObject.data keys: ['Epoch', 'BGSE', 'BF1']
# 📥 Requesting DataCubby to update/merge global instance for wind_mfi_h2...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'wind_mfi_h2' -> 'wind_mfi_h2' -> <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Searching for instance of type <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'> in class_registry with 33 entries
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_auto' -> <class 'plotbot.data_classes.custom_classes.psp_waves_auto.psp_waves_auto_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.demo_spectral_waves.demo_spectral_waves_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_wave_power' -> <class 'plotbot.data_classes.custom_classes.demo_wave_power.demo_wave_power_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_real_test' -> <class 'plotbot.data_classes.custom_classes.psp_waves_real_test.psp_waves_real_test_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.psp_spectral_waves.psp_spectral_waves_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'alpha_fits' -> <class 'plotbot.data_classes.psp_alpha_fits_classes.alpha_fits_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn' -> <class 'plotbot.data_classes.psp_mag_rtn.mag_rtn_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_sc_4sa' -> <class 'plotbot.data_classes.psp_mag_sc_4sa.mag_sc_4sa_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_sc' -> <class 'plotbot.data_classes.psp_mag_sc.mag_sc_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'epad' -> <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'epad_hr' -> <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_high_res_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'proton' -> <class 'plotbot.data_classes.psp_proton.proton_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'proton_hr' -> <class 'plotbot.data_classes.psp_proton_hr.proton_hr_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'proton_fits' -> <class 'plotbot.data_classes.psp_proton_fits_classes.proton_fits_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'ham' -> <class 'plotbot.data_classes.psp_ham_classes.ham_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'wind_mfi_h2' -> <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'> vs target <class 'plotbot.data_classes.wind_mfi_classes.wind_mfi_h2_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] ✅ MATCH FOUND by type lookup
# 🔍 PATH ANALYSIS for 'wind_mfi_h2' (class: wind_mfi_h2_class)
#    📊 datetime_array_exists: True, not_none: False, length: 0
#    ⚡ RESULT: has_existing_data = False
#    🔄 Taking UPDATE PATH for 'wind_mfi_h2'
# [CUBBY] Global instance for wind_mfi_h2 is empty. Populating with new data via update()...
# [CUBBY] Calling update() on global instance of wind_mfi_h2 (ID: 6078175792). is_segment_merge=False
# [CUBBY]
# === Update Debug ===
# [CUBBY] Starting wind_mfi_h2_class update...
# [CUBBY] Stored all state: {}
# [CUBBY] Stored bx state: {}
# [CUBBY] Stored by state: {}
# [CUBBY] Stored bz state: {}
# [CUBBY] Stored bmag state: {}
# [CUBBY] Stored b_phi state: {}
# [CUBBY] Stored bgse state: {}
# [CUBBY] Restoring saved state...
# [CUBBY] Restored all state: {}
# [CUBBY] Restored bx state: {}
# [CUBBY] Restored by state: {}
# [CUBBY] Restored bz state: {}
# [CUBBY] Restored bmag state: {}
# [CUBBY] Restored b_phi state: {}
# [CUBBY] Restored bgse state: {}
# [CUBBY] === End Update Debug ===
#
# [CUBBY] Successfully called update() with original_requested_trange on global instance of wind_mfi_h2
# [CUBBY] ✅ Instance updated successfully via .update() method.
# [CUBBY] === End Global Instance Update ===
#
# ✅ DataCubby processed update for wind_mfi_h2.
# Updated and merged ranges for wind_mfi_h2: [(datetime.datetime(2021, 4, 26, 0, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2021, 4, 26, 0, 1, tzinfo=datetime.timezone.utc))]
# 🔄 Processing: mag_RTN
# [CUBBY]
# === Retrieving mag_rtn from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/get_data.py:425
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn with type <class 'plotbot.data_classes.psp_mag_rtn.mag_rtn_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6077752304 for key 'mag_rtn'. dt_len: None_or_NoAttr, min: N/A, max: N/A
# [CUBBY] GRAB OUTPUT - No datetime_array attribute found
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all: type=NoneType, shape=N/A | br: type=NoneType, shape=N/A | bt: type=NoneType, shape=N/A | bn: type=NoneType, shape=N/A | bmag: type=NoneType, shape=N/A | pmag: type=NoneType, shape=N/A | b_phi: type=NoneType, shape=N/A | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Attempting SPDF acquisition path for mag_RTN...
# [DOWNLOAD_SPDF_ENTRY] Received trange: ['2021/04/26 00:00:00.000', '2021/04/26 00:01:00.000'], data_type: mag_RTN
# Attempting SPDF download for mag_RTN in range ['2021/04/26 00:00:00.000', '2021/04/26 00:01:00.000']
# Smart file check failed for mag_RTN: get_needed_6hour_blocks() missing 1 required positional argument: 'end_time', falling back to pyspedas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       5 mag_rtn_4sa.b_phi.marker_size = 1  # Make it bigger or smaller
#       7 # PSP
# ----> 8 plotbot(trange, mag_rtn_4sa.b_phi, 1, mag_rtn.b_phi, 2, wind_mfi_h2.b_phi, 3)
#
# File ~/GitHub/Plotbot/plotbot/plotbot_main.py:11, in timer_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#       8 @wraps(func)
#       9 def wrapper(*args, **kwargs):
#      10     start_time = timer.perf_counter()
# ---> 11     result = func(*args, **kwargs)
#      12     end_time = timer.perf_counter()
#      13     duration_ms = (end_time - start_time) * 1000
#
# File ~/GitHub/Plotbot/plotbot/plotbot_main.py:358, in plotbot(trange, *args)
#     356 TimeRangeTracker.set_current_trange(trange)
#     357 timer_start = timer.perf_counter()
# --> 358 get_data(trange, *vars_to_load)  # ✨ ONE CALL - get_data handles everything!
#     359 timer_end = timer.perf_counter()
#     360 duration_ms = (timer_end - timer_start) * 1000
#
# File ~/GitHub/Plotbot/plotbot/get_data.py:18, in timer_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      15 @wraps(func)
#      16 def wrapper(*args, **kwargs):
#      17     start_time = timer.perf_counter()
# ---> 18     result = func(*args, **kwargs)
#      19     end_time = timer.perf_counter()
#      20     duration_ms = (end_time - start_time) * 1000
#
# File ~/GitHub/Plotbot/plotbot/get_data.py:465, in get_data(trange, skip_refresh_check, *variables)
#     463 if server_mode == 'spdf':
#     464     print_manager.status(f"Attempting SPDF acquisition path for {data_type}...")
# --> 465     download_spdf_data(trange, data_type) # download_successful = download_spdf_data(trange, data_type)
#     466 elif server_mode == 'berkeley' or server_mode == 'berkley':
#     467     print_manager.status(f"Attempting Berkeley acquisition path for {data_type}...")
#
# File ~/GitHub/Plotbot/plotbot/data_download_pyspedas.py:438, in download_spdf_data(trange, plotbot_key)
#     435     return local_files
#     437 # Import pyspedas here so it reads the environment variables AFTER config is set
# --> 438 import pyspedas
#     440 print_manager.status(f"📡 Local files not found, proceeding with pyspedas download for {plotbot_key}")
#     442 PYSPEDAS_MAP = _get_pyspedas_map()
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/__init__.py:46
#      43 from .hapi_tools.hapi import hapi
#      45 from .particles.moments import moments_3d, spd_pgs_moments, spd_pgs_moments_tplot
# ---> 46 from .particles.spd_part_products import spd_pgs_do_fac, spd_pgs_regrid, spd_pgs_v_shift
#      47 from .particles.spd_slice2d import slice1d_plot, slice2d, slice2d_plot
#      48 from .utilities.spice.time_ephemeris import time_ephemeris
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/particles/spd_part_products/__init__.py:1
# ----> 1 from .spd_pgs_do_fac import spd_pgs_do_fac
#       2 from .spd_pgs_regrid import spd_pgs_regrid
#       3 from .spd_pgs_v_shift import spd_pgs_v_shift
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/pyspedas/particles/spd_part_products/spd_pgs_do_fac.py:3
#       2 import numpy as np
# ----> 3 from astropy.coordinates import spherical_to_cartesian, cartesian_to_spherical
#       6 def spd_pgs_do_fac(data_in, mat):
#       7     """
#       8     Applies field aligned coordinate transformation to input data
#       9
#    (...)     21         Rotated particle data structure
#      22     """
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/astropy/coordinates/__init__.py:11
#       9 from .angles import *
#      10 from .attributes import *
# ---> 11 from .baseframe import *
#      12 from .builtin_frames import *
#      13 from .calculation import *
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/astropy/coordinates/baseframe.py:26
#      23 import numpy as np
#      25 from astropy import units as u
# ---> 26 from astropy.table import QTable
#      27 from astropy.utils import ShapedLikeNDArray
#      28 from astropy.utils.data_info import MixinInfo
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/astropy/table/__init__.py:119
#     116 with registry.delay_doc_updates(Table):
#     117     # Import routines that connect readers/writers to astropy.table
#     118     import astropy.io.ascii.connect
# --> 119     import astropy.io.fits.connect
#     120     import astropy.io.misc.connect
#     121     import astropy.io.misc.pandas.connect
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/astropy/io/fits/__init__.py:74
#      68 conf = Conf()
#      71 # Public API compatibility imports
#      72 # These need to come after the global config variables, as some of the
#      73 # submodules use them
# ---> 74 from . import card, column, convenience, hdu
#      75 from .card import *
#      76 from .column import *
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/astropy/io/fits/card.py:41
#      35         pass
#      38 UNDEFINED = Undefined()
# ---> 41 class Card(_Verify):
#      42     length = CARD_LENGTH
#      43     """The length of a Card image; should always be 80 for valid FITS files."""
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/site-packages/astropy/io/fits/card.py:145, in Card()
#     140 _rvkc_field_specifier_val_RE = re.compile(_rvkc_field_specifier_val + "$")
#     142 # regular expression to extract the key and the field specifier from a
#     143 # string that is being used to index into a card list that contains
#     144 # record value keyword cards (ex. 'DP1.AXIS.1')
# --> 145 _rvkc_keyword_name_RE = re.compile(
#     146     rf"(?P<keyword>{_rvkc_identifier})\.(?P<field_specifier>{_rvkc_field_specifier_s})$"
#     147 )
#     149 # regular expression to extract the field specifier and value and comment
#     150 # from the string value of a record value keyword card
#     151 # (ex "'AXIS.1: 1' / a comment")
#     152 _rvkc_keyword_val_comm_RE = re.compile(_rvkc_keyword_val_comm)
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/re/__init__.py:228, in compile(pattern, flags)
#     226 def compile(pattern, flags=0):
#     227     "Compile a regular expression pattern, returning a Pattern object."
# --> 228     return _compile(pattern, flags)
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/re/__init__.py:307, in _compile(pattern, flags)
#     301     import warnings
#     302     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     303             "as it is an undocumented flag "
#     304             "without an obvious purpose. "
#     305             "Don't use it.",
#     306             DeprecationWarning)
# --> 307 p = _compiler.compile(pattern, flags)
#     308 if flags & DEBUG:
#     309     return p
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/re/_compiler.py:749, in compile(p, flags)
#     746 else:
#     747     pattern = None
# --> 749 code = _code(p, flags)
#     751 if flags & SRE_FLAG_DEBUG:
#     752     print()
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/re/_compiler.py:582, in _code(p, flags)
#     579 _compile_info(code, p, flags)
#     581 # compile the pattern
# --> 582 _compile(code, p.data, flags)
#     584 code.append(SUCCESS)
#     586 return code
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/re/_compiler.py:128, in _compile(code, pattern, flags)
#     126     emit((group-1)*2)
#     127 # _compile_info(code, p, _combine_flags(flags, add_flags, del_flags))
# --> 128 _compile(code, p, _combine_flags(flags, add_flags, del_flags))
#     129 if group:
#     130     emit(MARK)
#
# File ~/micromamba/envs/plotbot_micromamba/lib/python3.12/re/_compiler.py:112, in _compile(code, pattern, flags)
#     110     emit(av[1])
#     111     _compile(code, av[2], flags)
# --> 112     emit(SUCCESS)
#     113     code[skip] = _len(code) - skip
#     114 else:
#
# KeyboardInterrupt:

# %%
from plotbot import *

trange = ['2020-01-29/18:00:00', '2020-01-29/20:00:00']

# Add vertical lines (dashed by default)
ploptions.ax1.add_vertical_line('2020-01-29/18:30:00', color='k', style='--')
ploptions.ax1.add_vertical_line('2020-01-29/19:15:00', color='red', style='-')

# Add horizontal lines
ploptions.ax2.add_horizontal_line(10.0, color='blue', style=':', width=2.0)
ploptions.ax2.add_horizontal_line(-5.0, color='green', style='--')

# Plot with your lines
plotbot(trange, mag_rtn_4sa.br, 1, mag_rtn_4sa.bt, 2)

# Clear lines for next plot
ploptions.ax1.clear_vertical_lines()
ploptions.ax2.clear_all_lines()  # Clears both vertical and horizontal

# Or reset everything
ploptions.reset()
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🕒 TimeRangeTracker: Cleared trange
# 🛰️ mag_RTN_4sa - acquiring variables: br, bt
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279732384 for key 'mag_rtn_4sa'. dt_len: 1186519, min: 2021-04-26T00:00:00.131039232, max: 2021-04-28T23:59:59.847719680
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(1186519,), range=2021-04-26T00:00:00.131039 to 2021-04-28T23:59:59.847719
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all(list): len=3, elem_shape=(1186519,) | br: type=ndarray, shape=(1186519,) | bt: type=ndarray, shape=(1186519,) | bn: type=ndarray, shape=(1186519,) | bmag: type=ndarray, shape=(1186519,) | pmag: type=ndarray, shape=(1186519,) | b_phi: type=ndarray, shape=(1186519,) | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279732384 for key 'mag_rtn_4sa'. dt_len: 1186519, min: 2021-04-26T00:00:00.131039232, max: 2021-04-28T23:59:59.847719680
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(1186519,), range=2021-04-26T00:00:00.131039 to 2021-04-28T23:59:59.847719
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all(list): len=3, elem_shape=(1186519,) | br: type=ndarray, shape=(1186519,) | bt: type=ndarray, shape=(1186519,) | bn: type=ndarray, shape=(1186519,) | bmag: type=ndarray, shape=(1186519,) | pmag: type=ndarray, shape=(1186519,) | b_phi: type=ndarray, shape=(1186519,) | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
#
# 📥 Acquiring data for 2 variables...
# 🕒 TimeRangeTracker: Stored trange ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# 🛰️ mag_RTN_4sa - acquiring variables: br, bt
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/get_data.py:425
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279732384 for key 'mag_rtn_4sa'. dt_len: 1186519, min: 2021-04-26T00:00:00.131039232, max: 2021-04-28T23:59:59.847719680
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(1186519,), range=2021-04-26T00:00:00.131039 to 2021-04-28T23:59:59.847719
# [CUBBY] GRAB OUTPUT - raw_data keys=['all', 'br', 'bt', 'bn', 'bmag', 'pmag', 'b_phi', 'br_norm'] | all(list): len=3, elem_shape=(1186519,) | br: type=ndarray, shape=(1186519,) | bt: type=ndarray, shape=(1186519,) | bn: type=ndarray, shape=(1186519,) | bmag: type=ndarray, shape=(1186519,) | pmag: type=ndarray, shape=(1186519,) | b_phi: type=ndarray, shape=(1186519,) | br_norm: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Attempting SPDF acquisition path for mag_RTN_4sa...
# [DOWNLOAD_SPDF_ENTRY] Received trange: ['2020-01-29/18:00:00', '2020-01-29/20:00:00'], data_type: mag_RTN_4sa
# Attempting SPDF download for mag_RTN_4sa in range ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# ✅ Smart check found 1 local mag_RTN_4sa file(s):
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_rtn_4_sa_per_cyc_20200129_v02.cdf
# ✅ Using local mag_RTN_4sa files (skipping pyspedas)
# Import data function called
# Input trange: ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
#
# Importing data for UTC time range: ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
#   Requested datetime range (from TT2000 conversion): 2020-01-29T18:00:00.000000000 to 2020-01-29T20:00:00.000000000
# daterange called with start_date=2020-01-29 18:00:00+00:00, end_date=2020-01-29 20:00:00+00:00
# End date has time component, using full day: 2020-01-29
# Converted start_date to date: 2020-01-29
# Will generate 1 dates
# Yielding date: 2020-01-29
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200129_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2020'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20200129_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200129_v.*.cdf
# Found 1 unique CDF files to process.
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_rtn_4_sa_per_cyc_20200129_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 633528069365727744 (2020-01-29T00:00:00.181727744) to 633614469041903104 (2020-01-29T23:59:59.857903104)
#     Comparison: File ends before request starts? False (FileEnd: 633614469041903104 < ReqStart: 633592869184000000)
#     Comparison: File starts after request ends? False (FileStart: 633528069365727744 > ReqEnd: 633600069184000000)
# Reading full time data array...
# Read 395506 time points
# Time indices: 296630 to 329588
# Extracted 32958 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (32958, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Concatenating CDF data...
#   Concatenated psp_fld_l2_mag_RTN_4_Sa_per_Cyc (Shape: (32958, 3))
#
# Total CDF data points after concatenation: 32958
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2020-01-29/18:00:00', '2020-01-29/20:00:00'].
#
# *** IMPORT_DATA_DEBUG (CDF Path) for data_type 'mag_RTN_4sa' (originally requested: 'mag_RTN_4sa') ***
# [CUBBY]     data_object ID: 13832030080
# [CUBBY]     DataObject.times length: 32958, dtype: int64
# [CUBBY]     data_object.data ID: 13909871296
# [CUBBY]     DataObject.data keys: ['psp_fld_l2_mag_RTN_4_Sa_per_Cyc']
# [CUBBY]         'psp_fld_l2_mag_RTN_4_Sa_per_Cyc' is PRESENT. Type: <class 'numpy.ndarray'>, Shape: (32958, 3), Len: 32958
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'mag_rtn_4sa' -> 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Searching for instance of type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> in class_registry with 33 entries
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_auto' -> <class 'plotbot.data_classes.custom_classes.psp_waves_auto.psp_waves_auto_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.demo_spectral_waves.demo_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_wave_power' -> <class 'plotbot.data_classes.custom_classes.demo_wave_power.demo_wave_power_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_real_test' -> <class 'plotbot.data_classes.custom_classes.psp_waves_real_test.psp_waves_real_test_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.psp_spectral_waves.psp_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'alpha_fits' -> <class 'plotbot.data_classes.psp_alpha_fits_classes.alpha_fits_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] ✅ MATCH FOUND by type lookup
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 1186519
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# [CUBBY] Global instance has existing data. Attempting merge...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'mag_rtn_4sa' -> 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] Processing new imported data into temporary instance...
# [CUBBY] ✅ New data processed.
# [CUBBY] Calling _merge_arrays...
# [CUBBY]
# 🔥 ULTIMATE MERGE ENGINE ACTIVATED 🔥
# [CUBBY] 📊 MERGE STATS:
# [CUBBY]    Existing: 1,186,519 records
# [CUBBY]    New: 32,958 records
# [CUBBY]    Potential total: 1,219,477 records
# [CUBBY] 🔄 OVERLAP DETECTED - Full merge required
# [CUBBY] ⚡ Computing unique merged times...
# [CUBBY] ✅ Unique times: 1,219,477 records (0 duplicates removed)
# [CUBBY] 🏎️ SPEED MODE: Using vectorized processing
# [CUBBY] ⚠️ Skipping key 'br_norm' - both arrays are None
# [CUBBY] 🏁 MERGE COMPLETE!
# [CUBBY]    Final records: 1,219,477
# [CUBBY]    Duration: 0.09s
# [CUBBY]    Speed: 13,173,086 records/sec
# [CUBBY]    Session total: 1,219,477 records
# [CUBBY]    Session avg: 13,173,086 records/sec
# ✅ DataCubby processed update for mag_rtn_4sa.
# Updated and merged ranges for mag_RTN_4sa: [(datetime.datetime(2020, 1, 29, 18, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2020, 1, 29, 20, 0, tzinfo=datetime.timezone.utc)), (datetime.datetime(2021, 4, 26, 0, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2021, 4, 29, 0, 0, tzinfo=datetime.timezone.utc))]
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:380
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279732384 for key 'mag_rtn_4sa'. dt_len: 1219477, min: 2020-01-29T18:00:00.212556160, max: 2021-04-28T23:59:59.847719680
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(1219477,), range=2020-01-29T18:00:00.212556 to 2021-04-28T23:59:59.847719
# [CUBBY] GRAB OUTPUT - raw_data keys=['bt', 'bmag', 'b_phi', 'br', 'pmag', 'bn', 'all'] | bt: type=ndarray, shape=(1219477,) | bmag: type=ndarray, shape=(1219477,) | b_phi: type=ndarray, shape=(1219477,) | br: type=ndarray, shape=(1219477,) | pmag: type=ndarray, shape=(1219477,) | bn: type=ndarray, shape=(1219477,) | all(list): len=3, elem_shape=(1219477,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# ⚡ [CLIP_ONCE] Clipping data ONCE for trange: ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# 🔍 [DEBUG] clip_to_original_trange called with trange: ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# 🔍 [DEBUG] Clipping 1219477 points to 32958 points in range
#
# DEBUG:
# var: [ -89.11286  -89.73542  -89.27849 ... -291.57822 -291.23    -290.632  ]
# var type: <class 'plotbot.plot_manager.plot_manager'>
# var.datetime_array type: <class 'numpy.ndarray'>
# First element type: <class 'numpy.datetime64'>
# First element: 2020-01-29T18:00:00.212556160
# Time range: 2020-01-29T18:00:00.212556160 to 2020-01-29T19:59:59.803320832
# var.data type: <class 'numpy.ndarray'>
# var.data shape: (32958,)
#
# Variable verification for mag_rtn_4sa.br:
# Plot attributes example:
# - Color: forestgreen
# - Y-label: B (nT)
# - Legend: $B_R$
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:380
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279732384 for key 'mag_rtn_4sa'. dt_len: 1219477, min: 2020-01-29T18:00:00.212556160, max: 2021-04-28T23:59:59.847719680
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(1219477,), range=2020-01-29T18:00:00.212556 to 2021-04-28T23:59:59.847719
# [CUBBY] GRAB OUTPUT - raw_data keys=['bt', 'bmag', 'b_phi', 'br', 'pmag', 'bn', 'all'] | bt: type=ndarray, shape=(1219477,) | bmag: type=ndarray, shape=(1219477,) | b_phi: type=ndarray, shape=(1219477,) | br: type=ndarray, shape=(1219477,) | pmag: type=ndarray, shape=(1219477,) | bn: type=ndarray, shape=(1219477,) | all(list): len=3, elem_shape=(1219477,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# ⚡ [CLIP_ONCE] Clipping data ONCE for trange: ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# 🔍 [DEBUG] clip_to_original_trange called with trange: ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# 🔍 [DEBUG] Clipping 1219477 points to 32958 points in range
#
# DEBUG:
# var: [75.96785  75.204475 75.451675 ... 96.30716  96.36994  97.11422 ]
# var type: <class 'plotbot.plot_manager.plot_manager'>
# var.datetime_array type: <class 'numpy.ndarray'>
# First element type: <class 'numpy.datetime64'>
# First element: 2020-01-29T18:00:00.212556160
# Time range: 2020-01-29T18:00:00.212556160 to 2020-01-29T19:59:59.803320832
# var.data type: <class 'numpy.ndarray'>
# var.data shape: (32958,)
#
# Variable verification for mag_rtn_4sa.bt:
# Plot attributes example:
# - Color: orange
# - Y-label: B (nT)
# - Legend: $B_T$
# 📈 Plotting mag_rtn_4sa.br
# 🔍 TIME_CLIP_DEBUG for mag_rtn_4sa.br:
#    raw_datetime_array: len=1219477, range=2020-01-29T18:00:00.212556160 to 2021-04-28T23:59:59.847719680
#    requested trange: 2020-01-29/18:00:00 to 2020-01-29/20:00:00
#    time_clip returned 32958 indices
# 🔍 DATA_CLIP_DEBUG for mag_rtn_4sa.br:
#    data.shape=(1219477,), time_indices.shape=(32958,)
#    data_clipped.shape=(32958,), has_nans=False, all_nans=False
# 📈 Plotting mag_rtn_4sa.bt
# 🔍 TIME_CLIP_DEBUG for mag_rtn_4sa.bt:
#    raw_datetime_array: len=1219477, range=2020-01-29T18:00:00.212556160 to 2021-04-28T23:59:59.847719680
#    requested trange: 2020-01-29/18:00:00 to 2020-01-29/20:00:00
#    time_clip returned 32958 indices
# 🔍 DATA_CLIP_DEBUG for mag_rtn_4sa.bt:
#    data.shape=(1219477,), time_indices.shape=(32958,)
#    data_clipped.shape=(32958,), has_nans=False, all_nans=False
# Drew vertical line at 2020-01-29/18:30:00 on axis 1
# Drew vertical line at 2020-01-29/19:15:00 on axis 1
# Drew horizontal line at y=10.0 on axis 2
# Drew horizontal line at y=-5.0 on axis 2

# %%
#--------//

trange = ['2018-10-22 12:00:00', '2018-10-27 13:00:00']

epad.strahl.colorbar_limits = [8, 11]
epad.strahl.colorbar_scale = 'log'

plotbot(trange, mag_rtn_4sa.br, 1, epad.strahl, 2, proton.energy_flux, 3)

print("Shape of mag_rtn_4sa.br.data:", getattr(mag_rtn_4sa.br, 'data', None).shape if hasattr(mag_rtn_4sa.br, 'data') and mag_rtn_4sa.br.data is not None else "Attribute 'data' not found or is None")

print("Shape of epad.strahl.data:", getattr(epad.strahl, 'data', None).shape if hasattr(epad.strahl, 'data') and epad.strahl.data is not None else "Attribute 'data' not found or is None")
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🕒 TimeRangeTracker: Cleared trange
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 🛰️ spe_sf0_pad - acquiring variables: strahl
# 🛰️ spi_sf00_l3_mom - acquiring variables: energy_flux
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279732384 for key 'mag_rtn_4sa'. dt_len: 1219477, min: 2020-01-29T18:00:00.212556160, max: 2021-04-28T23:59:59.847719680
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(1219477,), range=2020-01-29T18:00:00.212556 to 2021-04-28T23:59:59.847719
# [CUBBY] GRAB OUTPUT - raw_data keys=['bt', 'bmag', 'b_phi', 'br', 'pmag', 'bn', 'all'] | bt: type=ndarray, shape=(1219477,) | bmag: type=ndarray, shape=(1219477,) | b_phi: type=ndarray, shape=(1219477,) | br: type=ndarray, shape=(1219477,) | pmag: type=ndarray, shape=(1219477,) | bn: type=ndarray, shape=(1219477,) | all(list): len=3, elem_shape=(1219477,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
# [CUBBY]
# === Retrieving epad from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved epad with type <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279970992 for key 'epad'. dt_len: None_or_NoAttr, min: N/A, max: N/A
# [CUBBY] GRAB OUTPUT - No datetime_array attribute found
# [CUBBY] GRAB OUTPUT - raw_data keys=['strahl', 'centroids', 'pitch_angle_y_values'] | strahl: type=NoneType, shape=N/A | centroids: type=NoneType, shape=N/A | pitch_angle_y_values: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
# [CUBBY]
# === Retrieving proton from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/plotbot_main.py:311
# [CUBBY] GRAB SUCCESS - Retrieved proton with type <class 'plotbot.data_classes.psp_proton.proton_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279974832 for key 'proton'. dt_len: None_or_NoAttr, min: N/A, max: N/A
# [CUBBY] GRAB OUTPUT - No datetime_array attribute found
# [CUBBY] GRAB OUTPUT - raw_data keys=['vr', 'vt', 'vn', 't_par', 't_perp', 'anisotropy', 'v_alfven', 'beta_ppar', 'beta_pperp', 'pressure_ppar', 'pressure_pperp', 'energy_flux', 'theta_flux', 'phi_flux', 'v_sw', 'm_alfven', 'temperature', 'pressure', 'density', 'bmag', 'sun_dist_rsun', 'ENERGY_VALS', 'THETA_VALS', 'PHI_VALS'] | vr: type=NoneType, shape=N/A | vt: type=NoneType, shape=N/A | vn: type=NoneType, shape=N/A | t_par: type=NoneType, shape=N/A | t_perp: type=NoneType, shape=N/A | anisotropy: type=NoneType, shape=N/A | v_alfven: type=NoneType, shape=N/A | beta_ppar: type=NoneType, shape=N/A | beta_pperp: type=NoneType, shape=N/A | pressure_ppar: type=NoneType, shape=N/A | pressure_pperp: type=NoneType, shape=N/A | energy_flux: type=NoneType, shape=N/A | theta_flux: type=NoneType, shape=N/A | phi_flux: type=NoneType, shape=N/A | v_sw: type=NoneType, shape=N/A | m_alfven: type=NoneType, shape=N/A | temperature: type=NoneType, shape=N/A | pressure: type=NoneType, shape=N/A | density: type=NoneType, shape=N/A | bmag: type=NoneType, shape=N/A | sun_dist_rsun: type=NoneType, shape=N/A | ENERGY_VALS: type=NoneType, shape=N/A | THETA_VALS: type=NoneType, shape=N/A | PHI_VALS: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# 🕒 TimeRangeTracker: Retrieved trange None
#
# 📥 Acquiring data for 3 variables...
# 🕒 TimeRangeTracker: Stored trange ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 🛰️ spe_sf0_pad - acquiring variables: strahl
# 🛰️ spi_sf00_l3_mom - acquiring variables: energy_flux
# 📋 Required data types: {'mag_RTN_4sa', 'spe_sf0_pad', 'spi_sf00_l3_mom'}
# 🔄 Processing: mag_RTN_4sa
# [CUBBY]
# === Retrieving mag_rtn_4sa from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/get_data.py:425
# [CUBBY] GRAB SUCCESS - Retrieved mag_rtn_4sa with type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279732384 for key 'mag_rtn_4sa'. dt_len: 1219477, min: 2020-01-29T18:00:00.212556160, max: 2021-04-28T23:59:59.847719680
# [CUBBY] GRAB OUTPUT - datetime_array type=ndarray, elem_type=datetime64, shape=(1219477,), range=2020-01-29T18:00:00.212556 to 2021-04-28T23:59:59.847719
# [CUBBY] GRAB OUTPUT - raw_data keys=['bt', 'bmag', 'b_phi', 'br', 'pmag', 'bn', 'all'] | bt: type=ndarray, shape=(1219477,) | bmag: type=ndarray, shape=(1219477,) | b_phi: type=ndarray, shape=(1219477,) | br: type=ndarray, shape=(1219477,) | pmag: type=ndarray, shape=(1219477,) | bn: type=ndarray, shape=(1219477,) | all(list): len=3, elem_shape=(1219477,)
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Attempting SPDF acquisition path for mag_RTN_4sa...
# [DOWNLOAD_SPDF_ENTRY] Received trange: ['2018-10-22 12:00:00', '2018-10-27 13:00:00'], data_type: mag_RTN_4sa
# Attempting SPDF download for mag_RTN_4sa in range ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
# ✅ Smart check found 6 local mag_RTN_4sa file(s):
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181022_v02.cdf
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181023_v02.cdf
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181024_v02.cdf
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181025_v02.cdf
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181026_v02.cdf
#    📁 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181027_v02.cdf
# ✅ Using local mag_RTN_4sa files (skipping pyspedas)
# Import data function called
# Input trange: ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
#
# Importing data for UTC time range: ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
#   Requested datetime range (from TT2000 conversion): 2018-10-22T12:00:00.000000000 to 2018-10-27T13:00:00.000000000
# daterange called with start_date=2018-10-22 12:00:00+00:00, end_date=2018-10-27 13:00:00+00:00
# End date has time component, using full day: 2018-10-27
# Converted start_date to date: 2018-10-22
# Will generate 6 dates
# Yielding date: 2018-10-22
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181022_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2018'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20181022_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181022_v.*.cdf
# Yielding date: 2018-10-23
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181023_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2018'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20181023_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181023_v.*.cdf
# Yielding date: 2018-10-24
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181024_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2018'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20181024_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181024_v.*.cdf
# Yielding date: 2018-10-25
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181025_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2018'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20181025_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181025_v.*.cdf
# Yielding date: 2018-10-26
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181026_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2018'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20181026_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181026_v.*.cdf
# Yielding date: 2018-10-27
#     Searching for DAILY pattern: 'psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181027_v*.cdf' in dir: '../data/psp/fields/l2/mag_rtn_4_per_cycle/2018'
#       MATCHED file: psp_fld_l2_mag_rtn_4_sa_per_cyc_20181027_v02.cdf with pattern psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20181027_v.*.cdf
# Found 6 unique CDF files to process.
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181022_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593438469453188352 (2018-10-22T00:00:00.269188352) to 593524868788053376 (2018-10-22T23:59:59.604053376)
#     Comparison: File ends before request starts? False (FileEnd: 593524868788053376 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593438469453188352 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 197753 time points
# Time indices: 98877 to 197753
# Extracted 98876 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (98876, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181023_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593524869224960128 (2018-10-23T00:00:00.040960128) to 593611269005870080 (2018-10-23T23:59:59.821870080)
#     Comparison: File ends before request starts? False (FileEnd: 593611269005870080 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593524869224960128 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 197754 time points
# Time indices: 0 to 197754
# Extracted 197754 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (197754, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181024_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593611269442776576 (2018-10-24T00:00:00.258776576) to 593697668764601216 (2018-10-24T23:59:59.580601216)
#     Comparison: File ends before request starts? False (FileEnd: 593697668764601216 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593611269442776576 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 197753 time points
# Time indices: 0 to 197753
# Extracted 197753 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (197753, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181025_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593697669201507968 (2018-10-25T00:00:00.017507968) to 593784068951935744 (2018-10-25T23:59:59.767935744)
#     Comparison: File ends before request starts? False (FileEnd: 593784068951935744 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593697669201507968 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 197754 time points
# Time indices: 0 to 197754
# Extracted 197754 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (197754, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181026_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593784069388842624 (2018-10-26T00:00:00.204842624) to 593870469126030592 (2018-10-26T23:59:59.942030592)
#     Comparison: File ends before request starts? False (FileEnd: 593870469126030592 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593784069388842624 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 197754 time points
# Time indices: 0 to 197754
# Extracted 197754 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (197754, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Processing CDF file: ../data/psp/fields/l2/mag_rtn_4_per_cycle/2018/psp_fld_l2_mag_rtn_4_sa_per_cyc_20181027_v02.cdf
# Successfully opened CDF file
# Using time variable: epoch_mag_RTN_4_Sa_per_Cyc
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593870469562937088 (2018-10-27T00:00:00.378937088) to 593956868891948928 (2018-10-27T23:59:59.707948928)
#     Comparison: File ends before request starts? False (FileEnd: 593956868891948928 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593870469562937088 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 197753 time points
# Time indices: 0 to 107116
# Extracted 107116 time points within requested range
#
# Reading variable: psp_fld_l2_mag_RTN_4_Sa_per_Cyc
# Raw data shape: (107116, 3)
# Successfully stored data slice for psp_fld_l2_mag_RTN_4_Sa_per_Cyc
#
# Concatenating CDF data...
#   Concatenated psp_fld_l2_mag_RTN_4_Sa_per_Cyc (Shape: (997007, 3))
#
# Total CDF data points after concatenation: 997007
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2018-10-22 12:00:00', '2018-10-27 13:00:00'].
#
# *** IMPORT_DATA_DEBUG (CDF Path) for data_type 'mag_RTN_4sa' (originally requested: 'mag_RTN_4sa') ***
# [CUBBY]     data_object ID: 13911410240
# [CUBBY]     DataObject.times length: 997007, dtype: int64
# [CUBBY]     data_object.data ID: 13606710336
# [CUBBY]     DataObject.data keys: ['psp_fld_l2_mag_RTN_4_Sa_per_Cyc']
# [CUBBY]         'psp_fld_l2_mag_RTN_4_Sa_per_Cyc' is PRESENT. Type: <class 'numpy.ndarray'>, Shape: (997007, 3), Len: 997007
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'mag_rtn_4sa' -> 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Searching for instance of type <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> in class_registry with 33 entries
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_auto' -> <class 'plotbot.data_classes.custom_classes.psp_waves_auto.psp_waves_auto_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.demo_spectral_waves.demo_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_wave_power' -> <class 'plotbot.data_classes.custom_classes.demo_wave_power.demo_wave_power_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_real_test' -> <class 'plotbot.data_classes.custom_classes.psp_waves_real_test.psp_waves_real_test_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.psp_spectral_waves.psp_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'alpha_fits' -> <class 'plotbot.data_classes.psp_alpha_fits_classes.alpha_fits_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> vs target <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] ✅ MATCH FOUND by type lookup
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 1219477
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# [CUBBY] Global instance has existing data. Attempting merge...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'mag_rtn_4sa' -> 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'>
# [CUBBY] Processing new imported data into temporary instance...
# [CUBBY] ✅ New data processed.
# [CUBBY] Calling _merge_arrays...
# [CUBBY]
# 🔥 ULTIMATE MERGE ENGINE ACTIVATED 🔥
# [CUBBY] 📊 MERGE STATS:
# [CUBBY]    Existing: 1,219,477 records
# [CUBBY]    New: 997,007 records
# [CUBBY]    Potential total: 2,216,484 records
# [CUBBY] 🔄 OVERLAP DETECTED - Full merge required
# [CUBBY] ⚡ Computing unique merged times...
# [CUBBY] ✅ Unique times: 2,216,484 records (0 duplicates removed)
# [CUBBY] 🏎️ SPEED MODE: Using vectorized processing
# [CUBBY] ⚠️ Skipping key 'br_norm' - both arrays are None
# [CUBBY] 🏁 MERGE COMPLETE!
# [CUBBY]    Final records: 2,216,484
# [CUBBY]    Duration: 0.07s
# [CUBBY]    Speed: 30,677,378 records/sec
# [CUBBY]    Session total: 3,435,961 records
# [CUBBY]    Session avg: 20,846,142 records/sec
# ✅ DataCubby processed update for mag_rtn_4sa.
# Updated and merged ranges for mag_RTN_4sa: [(datetime.datetime(2018, 10, 22, 12, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2018, 10, 27, 13, 0, tzinfo=datetime.timezone.utc)), (datetime.datetime(2020, 1, 29, 18, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2020, 1, 29, 20, 0, tzinfo=datetime.timezone.utc)), (datetime.datetime(2021, 4, 26, 0, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2021, 4, 29, 0, 0, tzinfo=datetime.timezone.utc))]
# 🔄 Processing: spe_sf0_pad
# [CUBBY]
# === Retrieving epad from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/get_data.py:425
# [CUBBY] GRAB SUCCESS - Retrieved epad with type <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [CUBBY_GRAB_RETURN_STATE] Object ID 6279970992 for key 'epad'. dt_len: None_or_NoAttr, min: N/A, max: N/A
# [CUBBY] GRAB OUTPUT - No datetime_array attribute found
# [CUBBY] GRAB OUTPUT - raw_data keys=['strahl', 'centroids', 'pitch_angle_y_values'] | strahl: type=NoneType, shape=N/A | centroids: type=NoneType, shape=N/A | pitch_angle_y_values: type=NoneType, shape=N/A
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Attempting SPDF acquisition path for spe_sf0_pad...
# [DOWNLOAD_SPDF_ENTRY] Received trange: ['2018-10-22 12:00:00', '2018-10-27 13:00:00'], data_type: spe_sf0_pad
# Attempting SPDF download for spe_sf0_pad in range ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
# ✅ Smart check found 6 local spe_sf0_pad file(s):
#    📁 ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181022_v04.cdf
#    📁 ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181023_v04.cdf
#    📁 ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181024_v04.cdf
#    📁 ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181025_v04.cdf
#    📁 ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181026_v04.cdf
#    📁 ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181027_v04.cdf
# ✅ Using local spe_sf0_pad files (skipping pyspedas)
# Import data function called
# Input trange: ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
#
# Importing data for UTC time range: ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
#   Requested datetime range (from TT2000 conversion): 2018-10-22T12:00:00.000000000 to 2018-10-27T13:00:00.000000000
# daterange called with start_date=2018-10-22 12:00:00+00:00, end_date=2018-10-27 13:00:00+00:00
# End date has time component, using full day: 2018-10-27
# Converted start_date to date: 2018-10-22
# Will generate 6 dates
# Yielding date: 2018-10-22
#     Searching for DAILY pattern: 'psp_swp_spe_sf0_L3_pad_20181022_v*.cdf' in dir: '../data/psp/sweap/spe/l3/spe_sf0_pad/2018'
#       MATCHED file: psp_swp_spe_sf0_l3_pad_20181022_v04.cdf with pattern psp_swp_spe_sf0_L3_pad_20181022_v.*.cdf
# Yielding date: 2018-10-23
#     Searching for DAILY pattern: 'psp_swp_spe_sf0_L3_pad_20181023_v*.cdf' in dir: '../data/psp/sweap/spe/l3/spe_sf0_pad/2018'
#       MATCHED file: psp_swp_spe_sf0_l3_pad_20181023_v04.cdf with pattern psp_swp_spe_sf0_L3_pad_20181023_v.*.cdf
# Yielding date: 2018-10-24
#     Searching for DAILY pattern: 'psp_swp_spe_sf0_L3_pad_20181024_v*.cdf' in dir: '../data/psp/sweap/spe/l3/spe_sf0_pad/2018'
#       MATCHED file: psp_swp_spe_sf0_l3_pad_20181024_v04.cdf with pattern psp_swp_spe_sf0_L3_pad_20181024_v.*.cdf
# Yielding date: 2018-10-25
#     Searching for DAILY pattern: 'psp_swp_spe_sf0_L3_pad_20181025_v*.cdf' in dir: '../data/psp/sweap/spe/l3/spe_sf0_pad/2018'
#       MATCHED file: psp_swp_spe_sf0_l3_pad_20181025_v04.cdf with pattern psp_swp_spe_sf0_L3_pad_20181025_v.*.cdf
# Yielding date: 2018-10-26
#     Searching for DAILY pattern: 'psp_swp_spe_sf0_L3_pad_20181026_v*.cdf' in dir: '../data/psp/sweap/spe/l3/spe_sf0_pad/2018'
#       MATCHED file: psp_swp_spe_sf0_l3_pad_20181026_v04.cdf with pattern psp_swp_spe_sf0_L3_pad_20181026_v.*.cdf
# Yielding date: 2018-10-27
#     Searching for DAILY pattern: 'psp_swp_spe_sf0_L3_pad_20181027_v*.cdf' in dir: '../data/psp/sweap/spe/l3/spe_sf0_pad/2018'
#       MATCHED file: psp_swp_spe_sf0_l3_pad_20181027_v04.cdf with pattern psp_swp_spe_sf0_L3_pad_20181027_v.*.cdf
# Found 6 unique CDF files to process.
#
# Processing CDF file: ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181022_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593438611777144192 (2018-10-22T00:02:22.593144192) to 593523616503283456 (2018-10-22T23:39:07.319283456)
#     Comparison: File ends before request starts? False (FileEnd: 593523616503283456 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593438611777144192 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 96 time points
# Time indices: 49 to 96
# Extracted 47 time points within requested range
#
# Reading variable: EFLUX_VS_PA_E
# Raw data shape: (47, 12, 32)
# Successfully stored data slice for EFLUX_VS_PA_E
#
# Reading variable: PITCHANGLE
# Raw data shape: (47, 12)
# Successfully stored data slice for PITCHANGLE
#
# Processing CDF file: ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181023_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593524511289709824 (2018-10-22T23:54:02.105709824) to 593610410811576320 (2018-10-23T23:45:41.627576320)
#     Comparison: File ends before request starts? False (FileEnd: 593610410811576320 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593524511289709824 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 97 time points
# Time indices: 0 to 97
# Extracted 97 time points within requested range
#
# Reading variable: EFLUX_VS_PA_E
# Raw data shape: (97, 12, 32)
# Successfully stored data slice for EFLUX_VS_PA_E
#
# Reading variable: PITCHANGLE
# Raw data shape: (97, 12)
# Successfully stored data slice for PITCHANGLE
#
# Processing CDF file: ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181024_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593611305598265472 (2018-10-24T00:00:36.414265472) to 593697205097834368 (2018-10-24T23:52:15.913834368)
#     Comparison: File ends before request starts? False (FileEnd: 593697205097834368 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593611305598265472 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 97 time points
# Time indices: 0 to 97
# Extracted 97 time points within requested range
#
# Reading variable: EFLUX_VS_PA_E
# Raw data shape: (97, 12, 32)
# Successfully stored data slice for EFLUX_VS_PA_E
#
# Reading variable: PITCHANGLE
# Raw data shape: (97, 12)
# Successfully stored data slice for PITCHANGLE
#
# Processing CDF file: ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181025_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593698099884268032 (2018-10-25T00:07:10.700268032) to 593783104589350016 (2018-10-25T23:43:55.405350016)
#     Comparison: File ends before request starts? False (FileEnd: 593783104589350016 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593698099884268032 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 96 time points
# Time indices: 0 to 96
# Extracted 96 time points within requested range
#
# Reading variable: EFLUX_VS_PA_E
# Raw data shape: (96, 12, 32)
# Successfully stored data slice for EFLUX_VS_PA_E
#
# Reading variable: PITCHANGLE
# Raw data shape: (96, 12)
# Successfully stored data slice for PITCHANGLE
#
# Processing CDF file: ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181026_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593783999375603456 (2018-10-25T23:58:50.191603456) to 593869898853699456 (2018-10-26T23:50:29.669699456)
#     Comparison: File ends before request starts? False (FileEnd: 593869898853699456 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593783999375603456 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 97 time points
# Time indices: 0 to 97
# Extracted 97 time points within requested range
#
# Reading variable: EFLUX_VS_PA_E
# Raw data shape: (97, 12, 32)
# Successfully stored data slice for EFLUX_VS_PA_E
#
# Reading variable: PITCHANGLE
# Raw data shape: (97, 12)
# Successfully stored data slice for PITCHANGLE
#
# Processing CDF file: ../data/psp/sweap/spe/l3/spe_sf0_pad/2018/psp_swp_spe_sf0_l3_pad_20181027_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593870793639953152 (2018-10-27T00:05:24.455953152) to 593955798360337024 (2018-10-27T23:42:09.176337024)
#     Comparison: File ends before request starts? False (FileEnd: 593955798360337024 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593870793639953152 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 96 time points
# Time indices: 0 to 52
# Extracted 52 time points within requested range
#
# Reading variable: EFLUX_VS_PA_E
# Raw data shape: (52, 12, 32)
# Successfully stored data slice for EFLUX_VS_PA_E
#
# Reading variable: PITCHANGLE
# Raw data shape: (52, 12)
# Successfully stored data slice for PITCHANGLE
#
# Concatenating CDF data...
#   Concatenated EFLUX_VS_PA_E (Shape: (486, 12, 32))
#   Concatenated PITCHANGLE (Shape: (486, 12))
#
# Total CDF data points after concatenation: 486
# ☑️ - CDF Data import complete for spe_sf0_pad range ['2018-10-22 12:00:00', '2018-10-27 13:00:00'].
#
# *** IMPORT_DATA_DEBUG (CDF Path) for data_type 'spe_sf0_pad' (originally requested: 'spe_sf0_pad') ***
# [CUBBY]     data_object ID: 13831911616
# [CUBBY]     DataObject.times length: 486, dtype: int64
# [CUBBY]     data_object.data ID: 13831912320
# [CUBBY]     DataObject.data keys: ['EFLUX_VS_PA_E', 'PITCHANGLE']
# 📥 Requesting DataCubby to update/merge global instance for epad...
# [CUBBY] [CLASS_TYPE_DEBUG] Looking up 'epad' -> 'epad' -> <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Searching for instance of type <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'> in class_registry with 33 entries
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_auto' -> <class 'plotbot.data_classes.custom_classes.psp_waves_auto.psp_waves_auto_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.demo_spectral_waves.demo_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'demo_wave_power' -> <class 'plotbot.data_classes.custom_classes.demo_wave_power.demo_wave_power_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_waves_real_test' -> <class 'plotbot.data_classes.custom_classes.psp_waves_real_test.psp_waves_real_test_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'psp_spectral_waves' -> <class 'plotbot.data_classes.custom_classes.psp_spectral_waves.psp_spectral_waves_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'alpha_fits' -> <class 'plotbot.data_classes.psp_alpha_fits_classes.alpha_fits_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn_4sa' -> <class 'plotbot.data_classes.psp_mag_rtn_4sa.mag_rtn_4sa_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_rtn' -> <class 'plotbot.data_classes.psp_mag_rtn.mag_rtn_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_sc_4sa' -> <class 'plotbot.data_classes.psp_mag_sc_4sa.mag_sc_4sa_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'mag_sc' -> <class 'plotbot.data_classes.psp_mag_sc.mag_sc_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] Checking key 'epad' -> <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'> vs target <class 'plotbot.data_classes.psp_electron_classes.epad_strahl_class'>
# [CUBBY] [INSTANCE_LOOKUP_DEBUG] ✅ MATCH FOUND by type lookup
# [DataTracker][EPAD_DEBUG]   Converted requested start_dt: 2018-10-22 12:00:00+00:00, end_dt: 2018-10-27 13:00:00+00:00
# [DataTracker][EPAD_DEBUG]   Not contained in any existing range. Returning True (action needed).
# 🔍 PATH ANALYSIS for 'epad' (class: epad_strahl_class)
#    📊 datetime_array_exists: True, not_none: False, length: 0
#    ⚡ RESULT: has_existing_data = False
#    🔄 Taking UPDATE PATH for 'epad'
# [CUBBY] Global instance for epad is empty. Populating with new data via update()...
# [CUBBY] Calling update() on global instance of epad (ID: 6279970992). is_segment_merge=False
# [CUBBY]
# === Update Debug ===
# [CUBBY] Starting epad_strahl_class update...
# [CUBBY] Stored strahl state: {'colorbar_limits': '[8, 11]...', 'colorbar_scale': 'log'}
# [CUBBY] Stored centroids state: {}
# Setting attribute: time with value: [593482456324717312 593483351111383680 593484245897990016
#  593485140684596352 593486035471202176 593486930257808384
#  593487825044354688 593488719830961024 593489614617507200
#  593490509404113536 593491404190659712 593492298977265792
#  593493193763812096 593494088550358272 593494983336904576
#  593495878123390720 593496772909936896 593497667696483328
#  593498562482969344 593499457269515776 593500352056001920
#  593501246842548096 593502141629034240 593503036415520384
#  593503931202006528 593504825988492928 593505720774979072
#  91.02756  90.98427  90.15265  90.9361   91.13359  91.000656 91.1125
#  90.00006  91.24374  91.64239  91.51724  91.55299  91.17964  91.42473
#  91.79021  91.63186  91.08206  91.203026 90.75141  90.956085 90.80053
#  91.05703  91.22111  91.07846  91.11194  90.93057  91.25332        nan
#  90.50527  91.13451  91.18049 ]
# [CUBBY] Restoring saved state...
# [CUBBY] Restored strahl state: {'colorbar_limits': '[8, 11]...', 'colorbar_scale': 'log'}
# [CUBBY] Restored centroids state: {}
# [CUBBY] === End Update Debug ===
#
# [CUBBY] Successfully called update() with original_requested_trange on global instance of epad
# [CUBBY] ✅ Instance updated successfully via .update() method.
# [CUBBY] === End Global Instance Update ===
#
# ✅ DataCubby processed update for epad.
# Updated and merged ranges for spe_sf0_pad: [(datetime.datetime(2018, 10, 22, 12, 0, tzinfo=datetime.timezone.utc), datetime.datetime(2018, 10, 27, 13, 0, tzinfo=datetime.timezone.utc))]
# 🔄 Processing: spi_sf00_l3_mom
# [CUBBY]
# === Retrieving spi_sf00_l3_mom from data_cubby ===
# [CUBBY] GRAB CALLER: /Users/robertalexander/GitHub/Plotbot/plotbot/get_data.py:425
# [CUBBY] GRAB FAIL - Failed to retrieve spi_sf00_l3_mom
# [CUBBY] === End Retrieval Debug (LEAVING DATA CUBBY)===
#
# Attempting SPDF acquisition path for spi_sf00_l3_mom...
# [DOWNLOAD_SPDF_ENTRY] Received trange: ['2018-10-22 12:00:00', '2018-10-27 13:00:00'], data_type: spi_sf00_l3_mom
# Attempting SPDF download for spi_sf00_l3_mom in range ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
# ✅ Smart check found 6 local spi_sf00_l3_mom file(s):
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181022_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181023_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181024_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181025_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181026_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181027_v04.cdf
# ✅ Using local spi_sf00_l3_mom files (skipping pyspedas)
# Import data function called
# Input trange: ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
#
# Importing data for UTC time range: ['2018-10-22 12:00:00', '2018-10-27 13:00:00']
#   Requested datetime range (from TT2000 conversion): 2018-10-22T12:00:00.000000000 to 2018-10-27T13:00:00.000000000
# daterange called with start_date=2018-10-22 12:00:00+00:00, end_date=2018-10-27 13:00:00+00:00
# End date has time component, using full day: 2018-10-27
# Converted start_date to date: 2018-10-22
# Will generate 6 dates
# Yielding date: 2018-10-22
#     Searching for DAILY pattern: 'psp_swp_spi_sf00_L3_mom_20181022_v*.cdf' in dir: '../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018'
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20181022_v04.cdf with pattern psp_swp_spi_sf00_L3_mom_20181022_v.*.cdf
# Yielding date: 2018-10-23
#     Searching for DAILY pattern: 'psp_swp_spi_sf00_L3_mom_20181023_v*.cdf' in dir: '../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018'
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20181023_v04.cdf with pattern psp_swp_spi_sf00_L3_mom_20181023_v.*.cdf
# Yielding date: 2018-10-24
#     Searching for DAILY pattern: 'psp_swp_spi_sf00_L3_mom_20181024_v*.cdf' in dir: '../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018'
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20181024_v04.cdf with pattern psp_swp_spi_sf00_L3_mom_20181024_v.*.cdf
# Yielding date: 2018-10-25
#     Searching for DAILY pattern: 'psp_swp_spi_sf00_L3_mom_20181025_v*.cdf' in dir: '../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018'
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20181025_v04.cdf with pattern psp_swp_spi_sf00_L3_mom_20181025_v.*.cdf
# Yielding date: 2018-10-26
#     Searching for DAILY pattern: 'psp_swp_spi_sf00_L3_mom_20181026_v*.cdf' in dir: '../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018'
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20181026_v04.cdf with pattern psp_swp_spi_sf00_L3_mom_20181026_v.*.cdf
# Yielding date: 2018-10-27
#     Searching for DAILY pattern: 'psp_swp_spi_sf00_L3_mom_20181027_v*.cdf' in dir: '../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018'
#       MATCHED file: psp_swp_spi_sf00_l3_mom_20181027_v04.cdf with pattern psp_swp_spi_sf00_L3_mom_20181027_v.*.cdf
# Found 6 unique CDF files to process.
#
# Processing CDF file: ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181022_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593451600148784640 (2018-10-22T03:38:50.964784640) to 593523183077974272 (2018-10-22T23:31:53.893974272)
#     Comparison: File ends before request starts? False (FileEnd: 593523183077974272 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593451600148784640 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 6 time points
# Time indices: 3 to 6
# Extracted 3 time points within requested range
#
# Reading variable: VEL_RTN_SUN
# Raw data shape: (3, 3)
# Successfully stored data slice for VEL_RTN_SUN
#
# Reading variable: DENS
# Raw data shape: (3,)
# Successfully stored data slice for DENS
#
# Reading variable: TEMP
# Raw data shape: (3,)
# Successfully stored data slice for TEMP
#
# Reading variable: MAGF_INST
# Raw data shape: (3, 3)
# Successfully stored data slice for MAGF_INST
#
# Reading variable: T_TENSOR_INST
# Raw data shape: (3, 6)
# Successfully stored data slice for T_TENSOR_INST
#
# Reading variable: EFLUX_VS_ENERGY
# Raw data shape: (3, 32)
# Successfully stored data slice for EFLUX_VS_ENERGY
#
# Reading variable: EFLUX_VS_THETA
# Raw data shape: (3, 8)
# Successfully stored data slice for EFLUX_VS_THETA
#
# Reading variable: EFLUX_VS_PHI
# Raw data shape: (3, 8)
# Successfully stored data slice for EFLUX_VS_PHI
#
# Reading variable: ENERGY_VALS
# Raw data shape: (3, 32)
# Successfully stored data slice for ENERGY_VALS
#
# Reading variable: THETA_VALS
# Raw data shape: (3, 8)
# Successfully stored data slice for THETA_VALS
#
# Reading variable: PHI_VALS
# Raw data shape: (3, 8)
# Successfully stored data slice for PHI_VALS
#
# Reading variable: SUN_DIST
# Raw data shape: (3,)
# Successfully stored data slice for SUN_DIST
#
# Processing CDF file: ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181023_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593537499660513920 (2018-10-23T03:30:30.476513920) to 593609082597351296 (2018-10-23T23:23:33.413351296)
#     Comparison: File ends before request starts? False (FileEnd: 593609082597351296 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593537499660513920 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 6 time points
# Time indices: 0 to 6
# Extracted 6 time points within requested range
#
# Reading variable: VEL_RTN_SUN
# Raw data shape: (6, 3)
# Successfully stored data slice for VEL_RTN_SUN
#
# Reading variable: DENS
# Raw data shape: (6,)
# Successfully stored data slice for DENS
#
# Reading variable: TEMP
# Raw data shape: (6,)
# Successfully stored data slice for TEMP
#
# Reading variable: MAGF_INST
# Raw data shape: (6, 3)
# Successfully stored data slice for MAGF_INST
#
# Reading variable: T_TENSOR_INST
# Raw data shape: (6, 6)
# Successfully stored data slice for T_TENSOR_INST
#
# Reading variable: EFLUX_VS_ENERGY
# Raw data shape: (6, 32)
# Successfully stored data slice for EFLUX_VS_ENERGY
#
# Reading variable: EFLUX_VS_THETA
# Raw data shape: (6, 8)
# Successfully stored data slice for EFLUX_VS_THETA
#
# Reading variable: EFLUX_VS_PHI
# Raw data shape: (6, 8)
# Successfully stored data slice for EFLUX_VS_PHI
#
# Reading variable: ENERGY_VALS
# Raw data shape: (6, 32)
# Successfully stored data slice for ENERGY_VALS
#
# Reading variable: THETA_VALS
# Raw data shape: (6, 8)
# Successfully stored data slice for THETA_VALS
#
# Reading variable: PHI_VALS
# Raw data shape: (6, 8)
# Successfully stored data slice for PHI_VALS
#
# Reading variable: SUN_DIST
# Raw data shape: (6,)
# Successfully stored data slice for SUN_DIST
#
# Processing CDF file: ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181024_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593623399184237440 (2018-10-24T03:22:10.000237440) to 593694982100362496 (2018-10-24T23:15:12.916362496)
#     Comparison: File ends before request starts? False (FileEnd: 593694982100362496 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593623399184237440 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 6 time points
# Time indices: 0 to 6
# Extracted 6 time points within requested range
#
# Reading variable: VEL_RTN_SUN
# Raw data shape: (6, 3)
# Successfully stored data slice for VEL_RTN_SUN
#
# Reading variable: DENS
# Raw data shape: (6,)
# Successfully stored data slice for DENS
#
# Reading variable: TEMP
# Raw data shape: (6,)
# Successfully stored data slice for TEMP
#
# Reading variable: MAGF_INST
# Raw data shape: (6, 3)
# Successfully stored data slice for MAGF_INST
#
# Reading variable: T_TENSOR_INST
# Raw data shape: (6, 6)
# Successfully stored data slice for T_TENSOR_INST
#
# Reading variable: EFLUX_VS_ENERGY
# Raw data shape: (6, 32)
# Successfully stored data slice for EFLUX_VS_ENERGY
#
# Reading variable: EFLUX_VS_THETA
# Raw data shape: (6, 8)
# Successfully stored data slice for EFLUX_VS_THETA
#
# Reading variable: EFLUX_VS_PHI
# Raw data shape: (6, 8)
# Successfully stored data slice for EFLUX_VS_PHI
#
# Reading variable: ENERGY_VALS
# Raw data shape: (6, 32)
# Successfully stored data slice for ENERGY_VALS
#
# Reading variable: THETA_VALS
# Raw data shape: (6, 8)
# Successfully stored data slice for THETA_VALS
#
# Reading variable: PHI_VALS
# Raw data shape: (6, 8)
# Successfully stored data slice for PHI_VALS
#
# Reading variable: SUN_DIST
# Raw data shape: (6,)
# Successfully stored data slice for SUN_DIST
#
# Processing CDF file: ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2018/psp_swp_spi_sf00_l3_mom_20181025_v04.cdf
# Successfully opened CDF file
# Using time variable: Epoch
#   Epoch type: CDF_TIME_TT2000
#   File actual TT2000 range: 593709298682269568 (2018-10-25T03:13:49.498269568) to 593780881592705664 (2018-10-25T23:06:52.408705664)
#     Comparison: File ends before request starts? False (FileEnd: 593780881592705664 < ReqStart: 593481669184000000)
#     Comparison: File starts after request ends? False (FileStart: 593709298682269568 > ReqEnd: 593917269184000000)
# Reading full time data array...
# Read 6 time points
# Time indices: 0 to 6
# Extracted 6 time points within requested range
#
# Reading variable: VEL_RTN_SUN
# Raw data shape: (6, 3)

# %%
print_manager.show_status = False
print_manager.show_debug = False
# TRANGE = ['2023-09-28/00:00:00.000', '2023-09-29/00:00:00.000'] # 1 day
# plotbot(TRANGE, mag_rtn_4sa.br, 1, proton.anisotropy, 2, mag_rtn_4sa.br_norm, 3, epad.strahl, 4)
# plotbot(TRANGE, mag_rtn.br, 1, proton.anisotropy, 2, mag_rtn.br_norm, 3, epad.strahl, 4)

# %%
plt.options.reset()
#----Print manager----/// ✨ Two levels of print manager verbosity
print_manager.show_status = False
print_manager.show_debug = False

#an example for how to use the pb.config to change the data server setting
config.data_server = 'berkeley' #<--default to SPDF with Berkeley as a secondary choice
# Server options are 'dynamic', 'spdf' or 'berkeley'

print_manager.show_status = False

Jaye_epad_trange = ['2021/04/26 00:00:00.000', '2021/05/2 00:00:00.000']
plotbot(Jaye_epad_trange, mag_rtn_4sa.br, 1, epad.strahl, 2)

# %%
TRANGE = ['2023-09-28/00:00:00.000', '2023-09-29/00:00:00.000'] # 1 day
plotbot(TRANGE, mag_rtn_4sa.br, 1)

# %%
TRANGE = ['2023-09-28/00:00:00.000', '2023-09-29/00:00:00.000'] # 1 day
plotbot(TRANGE, proton.sun_dist_rsun, 1, mag_rtn_4sa.br_norm, 2)

# %%
# # ✨ Using the original import style for the remainder of the notebook 
# import plotbot
# from plotbot import *

# %%
config.data_server = 'dynamic' # Berkeley is generally the faster way to go!

# %%
#----Print manager----/// ✨ All the available print manager options 

print_manager.show_status = False  # Status prints ⭐️ useful for basic status updates

print_manager.show_debug = False  # Debug prints, helpful for debugging (will print a LOT of information)

print_manager.pyspedas_verbose = False

print_manager.show_processing = False # e.g. Processing mag_RTN_4sa...

print_manager.show_custom_debug = False  # Custom variable operations debugging

print_manager.show_time_tracking = False  # For tracking datetime array inputs and outputs
print_manager.show_warning = False     # Turn off warning messages
print_manager.show_variable_testing = False
print_manager.show_test = False  # Turn off test-specific output

print_manager.show_module_prefix = False  # Show/Hide [print_manager]
print_manager.show_category_prefix = False  # Show/Hide [PROCESS], [TIME], etc.

# %% [markdown]
# ## Proton Fits! (Local CSV required)

# %%
## Example of new proton fits naming convention!

print_manager.show_status = True
fits_trange = ['2024-09-30/11:45:00.000', '2024-09-30/12:45:00.000']

# data_snapshot.save_data_snapshot('project_data.pkl')

plotbot(fits_trange, proton_fits.abs_qz_p, 1, proton_fits.vdrift_va_pfits, 2, proton_fits.valfven_pfits, 3, proton_fits.beta_ppar_pfits, 4, proton_fits.beta_pperp_pfits, 5)
# Out:
# 02-Dec-25 13:12:00: Substituting symbol \perp from STIXGeneral
# 02-Dec-25 13:12:01: Substituting symbol \perp from STIXGeneral
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ proton_fits - acquiring variables: abs_qz_p, vdrift_va_pfits, valfven_pfits, beta_ppar_pfits, beta_pperp_pfits
#
# 📥 Acquiring data for 5 variables...
# 🕒 TimeRangeTracker: Stored trange ['2024-09-30/11:45:00.000', '2024-09-30/12:45:00.000']
# 🛰️ proton_fits - calculation may be needed
# 📋 Required data types: {'proton_fits'}
# 🔄 Processing: proton_fits
# 📈 Plotting proton_fits.abs_qz_p
# 📈 Plotting proton_fits.vdrift_va_pfits
# 📈 Plotting proton_fits.valfven_pfits
# 📈 Plotting proton_fits.beta_ppar_pfits
# 📈 Plotting proton_fits.beta_pperp_pfits
# 02-Dec-25 13:12:01: Substituting symbol \perp from STIXGeneral
# 02-Dec-25 13:12:01: Substituting symbol \perp from STIXGeneral

# %% [markdown]
# ## Generate Plots from HAM Files (Local CSV required)

# %%
#Example HAM 🍖 and fits plotbot calls!
plt.options.reset() 

print_manager.show_status = True  # Status prints, ⭐️ useful for basic status updates
print_manager.show_debug = False  # Debug prints, helpful for debugging (will print LOTS of lines)

# %matplotlib inline 
# %matplotlib widget

# ham_trange = ['2025-03-23 11:00:00.000', '2025-03-23 12:00:00.000']

#server_access.username = 'your_username_here'

# ham.trat_ham.y_limit = [0, 50]

# plotbot(ham_trange, ham.trat_ham, 1)

fits_trange = ['2024-09-30/11:45:00.000', '2024-09-30/12:45:00.000']

plotbot(fits_trange, proton_fits.np1, 1, proton_fits.ham_param, 2, proton_fits.Tperp1, 3, proton_fits.vdrift_va_pfits, 4)
# Out:
# 02-Dec-25 13:12:01: Substituting symbol \perp from STIXGeneral
# 02-Dec-25 13:12:01: Substituting symbol \perp from STIXGeneral
# 02-Dec-25 13:12:01: Substituting symbol \perp from STIXGeneral
# 02-Dec-25 13:12:01: Substituting symbol \perp from STIXGeneral
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ proton_fits - acquiring variables: np1, ham_param, Tperp1, vdrift_va_pfits
#
# 📥 Acquiring data for 4 variables...
# 🕒 TimeRangeTracker: Stored trange ['2024-09-30/11:45:00.000', '2024-09-30/12:45:00.000']
# 🛰️ proton_fits - calculation may be needed
# 📋 Required data types: {'proton_fits'}
# 🔄 Processing: proton_fits
# 📈 Plotting proton_fits.np1
# 📈 Plotting proton_fits.ham_param
# 📈 Plotting proton_fits.Tperp1
# 📈 Plotting proton_fits.vdrift_va_pfits

# %%
print_manager.show_status = True
print_manager.show_debug = False
trange = ['2025-03-19 00:00:00.000', '2025-03-27 23:59:59.000']
plotbot(trange,
        ham.hamogram_30s, 1,
        proton.m_alfven, 2,
        proton.density,3,
        proton.bmag,4,
        proton.sun_dist_rsun, 5)
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ spi_sf00_l3_mom - acquiring variables: m_alfven, density, bmag, sun_dist_rsun
# 🛰️ ham - acquiring variables: hamogram_30s
#
# 📥 Acquiring data for 5 variables...
# 🕒 TimeRangeTracker: Stored trange ['2025-03-19 00:00:00.000', '2025-03-27 23:59:59.000']
# 🛰️ spi_sf00_l3_mom - acquiring variables: m_alfven, density, bmag, sun_dist_rsun
# 🛰️ ham - acquiring variables: hamogram_30s
# 📋 Required data types: {'spi_sf00_l3_mom', 'ham'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting SPDF acquisition path (dynamic mode) for spi_sf00_l3_mom...
# ✅ Smart check found 18 local spi_sf00_l3_mom file(s):
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250319_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250319_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250320_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250320_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250321_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250321_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250322_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250322_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250323_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250323_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250324_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250324_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250325_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250325_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250326_v04.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250326_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250327_v00.cdf
#    📁 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250327_v04.cdf
# ✅ Using local spi_sf00_l3_mom files (skipping pyspedas)
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2025-03-19 00:00:00', '2025-03-27 23:59:59'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 147799
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🔄 Processing: ham
# Successfully loaded Hammerhead data with 246673 time points
# 📥 Requesting DataCubby to update/merge global instance for ham...
# 🔍 PATH ANALYSIS for 'ham' (class: ham_class)
#    📊 datetime_array_exists: True, not_none: False, length: 0
#    ⚡ RESULT: has_existing_data = False
#    🔄 Taking UPDATE PATH for 'ham'
# ✅ DataCubby processed update for ham.
# 📈 Plotting ham.hamogram_30s
# 🔍 TIME_CLIP_DEBUG for ham.hamogram_30s:
#    raw_datetime_array: len=246673, range=2025-03-19T00:00:03.512000000 to 2025-03-27T23:55:56.978000000
#    requested trange: 2025-03-19 00:00:00.000 to 2025-03-27 23:59:59.000
#    time_clip returned 246673 indices
# 🔍 DATA_CLIP_DEBUG for ham.hamogram_30s:
#    data.shape=(246673,), time_indices.shape=(246673,)
#    data_clipped.shape=(246673,), has_nans=False, all_nans=False
# 📈 Plotting proton.m_alfven
# 🔍 TIME_CLIP_DEBUG for proton.m_alfven:
#    raw_datetime_array: len=648711, range=2018-10-22T15:34:40.726075136 to 2025-03-27T23:59:58.151598976
#    requested trange: 2025-03-19 00:00:00.000 to 2025-03-27 23:59:59.000
#    time_clip returned 500912 indices
# 🔍 DATA_CLIP_DEBUG for proton.m_alfven:
#    data.shape=(648711,), time_indices.shape=(500912,)
#    data_clipped.shape=(500912,), has_nans=True, all_nans=False
# 📈 Plotting proton.density
# 🔍 TIME_CLIP_DEBUG for proton.density:
#    raw_datetime_array: len=648711, range=2018-10-22T15:34:40.726075136 to 2025-03-27T23:59:58.151598976
#    requested trange: 2025-03-19 00:00:00.000 to 2025-03-27 23:59:59.000
#    time_clip returned 500912 indices
# 🔍 DATA_CLIP_DEBUG for proton.density:
#    data.shape=(648711,), time_indices.shape=(500912,)
#    data_clipped.shape=(500912,), has_nans=False, all_nans=False
# 📈 Plotting proton.bmag
# 🔍 TIME_CLIP_DEBUG for proton.bmag:
#    raw_datetime_array: len=648711, range=2018-10-22T15:34:40.726075136 to 2025-03-27T23:59:58.151598976
#    requested trange: 2025-03-19 00:00:00.000 to 2025-03-27 23:59:59.000
#    time_clip returned 500912 indices
# 🔍 DATA_CLIP_DEBUG for proton.bmag:
#    data.shape=(648711,), time_indices.shape=(500912,)
#    data_clipped.shape=(500912,), has_nans=True, all_nans=False
# 📈 Plotting proton.sun_dist_rsun
# 🔍 TIME_CLIP_DEBUG for proton.sun_dist_rsun:
#    raw_datetime_array: len=648711, range=2018-10-22T15:34:40.726075136 to 2025-03-27T23:59:58.151598976
#    requested trange: 2025-03-19 00:00:00.000 to 2025-03-27 23:59:59.000
#    time_clip returned 500912 indices
# 🔍 DATA_CLIP_DEBUG for proton.sun_dist_rsun:
#    data.shape=(648711,), time_indices.shape=(500912,)
#    data_clipped.shape=(500912,), has_nans=False, all_nans=False

# %% [markdown]
# ## Interactive Plotting

# %%
print_manager.show_status = False # Status prints, ⭐️ useful for basic status updates

#Use inline for static plots and widget for interactive plots
#The panel at the left has options for moving and zooming the plot
# %matplotlib inline 
# %matplotlib widget

#E17 HCS Crossing

server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.

epad.strahl.colorbar_limits = 'default'
epad.strahl.colorbar_scale = 'log'

trange = ['2023-09-28/06:00:00.000', '2023-09-28/07:30:00.000']  # Enc 17 HCS Crossing


plotbot(trange, mag_rtn_4sa.br, 1, mag_rtn_4sa.bmag, 1, mag_rtn_4sa.bt, 2, mag_rtn_4sa.bn, 2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot Hodograms with Custom Variables and Showdahodo

print_manager.show_status = False  # Status prints, ⭐️ useful for basic status updates

#Use inline for static plots and widget for interactive plots
# %matplotlib inline 
# %matplotlib widget

# Define a time range
trange = ['2023-09-28/06:00:00.000', '2023-09-28/07:30:00.000']
# trange = ['2023-10-28/06:00:00.000', '2023-10-28/07:30:00.000']

# Create a custom variable with our elegant syntax
TAplusBmag = custom_variable('TAplusBmag', proton.anisotropy + mag_rtn_4sa.bmag)

# Then use showdahodo with proton.beta_ppar on x-axis and proton.anisotropy on y-axis
# showdahodo(trange, TAplusBmag, proton.anisotropy, brazil=True);
showdahodo(trange, TAplusBmag, proton.anisotropy);
# Out:
# 02-Dec-25 13:12:09: Substituting symbol \perp from STIXGeneral
# 02-Dec-25 13:12:09: Substituting symbol \perp from STIXGeneral
# 02-Dec-25 13:12:09: Substituting symbol \perp from STIXGeneral
# 02-Dec-25 13:12:09: Substituting symbol \perp from STIXGeneral

# %%
# #An example with password protected data

# #E21 Glory Region! 
# print_manager.show_status = False  # Status prints, useful for status updates
# print_manager.show_debug = False   # Debug prints, helpful for debugging

# server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.

# epad.strahl.colorbar_limits = [10.4, 11]
# epad.strahl.colorbar_scale = 'log'

# trange = ['2024-09-30/12:10:00.000', '2024-09-30/12:20:00.000']
# # plotbot(trange, mag_rtn_4sa.all, 1, mag_rtn_4sa.bmag, 1, 
# #         epad_hr.strahl, 2, 
# #         proton_hr.energy_flux, 3, 
# #         proton_hr.t_perp, 4, 
# #         proton_hr.t_par, 4, proton_hr.anisotropy, '4r', 
# #         proton_hr.v_sw, 5, proton_hr.v_alfven, '5r')

# plotbot(trange, mag_rtn_4sa.br, 1, mag_rtn_4sa.bmag, 1, 
#         mag_rtn_4sa.bt, 2, mag_rtn_4sa.bn, 2, 
#         epad.strahl, 3, 
#         proton.energy_flux, 4, 
#         proton.theta_flux, 5, 
#         proton.phi_flux, 6, 
#         proton.t_perp, 7, 
#         proton.t_par, 7, proton.anisotropy, '7r', 
#         proton.v_sw, 8, proton.v_alfven, 8)

# %% [markdown]
# ## Math with Plotbot.data

# %%
#Working with Plotbot.data!! (the format is actually "mag_rtn_4sa.bmag.data " but you know what I mean...)

# Statistical Analysis of Magnetic Field Data
print("=== Magnetic Field Data Analysis ===\n")

trange = ['2023-09-28/06:00:00.000', '2023-09-28/07:30:00.000']  # Enc 17 HCS Crossing

plotbot(trange, mag_rtn_4sa.bmag, 1)

# Convert plot_manager objects to numpy arrays for analysis
bmag_data = mag_rtn_4sa.bmag.data  
br_data = mag_rtn_4sa.br.data
bt_data = mag_rtn_4sa.bt.data
bn_data = mag_rtn_4sa.bn.data

# Basic checks
print("1. Data Structure Checks:")
print(f"Data type: {type(mag_rtn_4sa.bmag)}")
print(f"Shape: {np.shape(bmag_data)}")
print(f"Number of points: {len(bmag_data)}")
print(f"Memory usage: {bmag_data.nbytes / 1e6:.2f} MB\n")

# Basic statistics
print("2. Basic Statistics:")
print(f"Mean |B|: {np.nanmean(bmag_data):.2f} nT")
print(f"Median |B|: {np.nanmedian(bmag_data):.2f} nT")
print(f"Standard deviation: {np.nanstd(bmag_data):.2f} nT")
print(f"Min |B|: {np.nanmin(bmag_data):.2f} nT")
print(f"Max |B|: {np.nanmax(bmag_data):.2f} nT\n")

# Component analysis
print("3. Component Analysis:")
print("Mean values:")
print(f"⟨Br⟩: {np.nanmean(br_data):.2f} nT")
print(f"⟨Bt⟩: {np.nanmean(bt_data):.2f} nT")
print(f"⟨Bn⟩: {np.nanmean(bn_data):.2f} nT\n")

# Calculate field angles
theta = np.arctan2(np.sqrt(bt_data**2 + bn_data**2), br_data)
phi = np.arctan2(bn_data, bt_data)

print("4. Field Orientation:")
print(f"Mean θ (from radial): {np.degrees(np.nanmean(theta)):.2f}°")
print(f"Mean φ (azimuthal): {np.degrees(np.nanmean(phi)):.2f}°\n")

# Power and energy density
mu0 = 4 * np.pi * 1e-7  # permeability of free space
B_squared = bmag_data**2
energy_density = B_squared / (2 * mu0) * 1e-9  # Convert to J/m^3

print("5. Energy Analysis:")
print(f"Mean B²: {np.nanmean(B_squared):.2f} nT²")
print(f"Mean magnetic energy density: {np.nanmean(energy_density):.2e} J/m³\n")

# Time series analysis
if hasattr(mag_rtn_4sa, 'datetime_array'):
    print("6. Time Series Properties:")
    # Convert datetime array to numeric values for time difference calculation
    time_array = np.array(mag_rtn_4sa.datetime_array, dtype='datetime64[ns]')
    time_diffs = np.diff(time_array)
    mean_cadence_ns = np.mean(time_diffs)
    mean_cadence_s = mean_cadence_ns / np.timedelta64(1, 's')  # Convert to seconds
    print(f"Mean sampling cadence: {mean_cadence_s:.6f} seconds")
    
    # Calculate power spectrum using sampling frequency in Hz
    from scipy import signal
    fs = 1.0 / mean_cadence_s
    # Remove NaN values for spectrum calculation
    valid_data = bmag_data[~np.isnan(bmag_data)]
    if len(valid_data) > 0:
        f, Pxx = signal.welch(valid_data - np.mean(valid_data), fs=fs)
        peak_freq = f[np.argmax(Pxx)]
        print(f"Dominant frequency in power spectrum: {peak_freq:.2e} Hz\n")

# Data quality checks
print("7. Data Quality Metrics:")
print(f"Number of NaN values: {np.sum(np.isnan(bmag_data))}")
print(f"Number of zeros: {np.sum(bmag_data == 0)}")
print(f"Number of values > 3σ: {np.sum(np.abs(bmag_data - np.nanmean(bmag_data)) > 3*np.nanstd(bmag_data))}\n")

# Visualization
plt.figure(figsize=(12, 8))

# Plot 1: Histogram of |B|
plt.subplot(221)
plt.hist(bmag_data[~np.isnan(bmag_data)], bins=50, density=True)
plt.title('|B| Distribution')
plt.xlabel('|B| (nT)')
plt.ylabel('Density')

# Plot 2: Component correlations
plt.subplot(222)
mask = ~np.isnan(br_data) & ~np.isnan(bt_data)
plt.scatter(br_data[mask], bt_data[mask], alpha=0.1)
plt.xlabel('Br (nT)')
plt.ylabel('Bt (nT)')
plt.title('Br vs Bt')

# Plot 3: Field angle distribution
plt.subplot(223)
mask = ~np.isnan(theta) & ~np.isnan(phi)
plt.hist2d(np.degrees(theta[mask]), np.degrees(phi[mask]), bins=50)
plt.xlabel('θ (degrees)')
plt.ylabel('φ (degrees)')
plt.title('Field Angle Distribution')
plt.colorbar()

# Plot 4: Power spectrum
plt.subplot(224)
if hasattr(mag_rtn_4sa, 'datetime_array'):
    valid_data = bmag_data[~np.isnan(bmag_data)]
    if len(valid_data) > 0:
        plt.loglog(f, Pxx)
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('Power Spectral Density')
        plt.title('Power Spectrum')

plt.tight_layout()
plt.show()
# Out:
# === Magnetic Field Data Analysis ===
# 1. Data Structure Checks:
# Data type: <class 'plotbot.plot_manager.plot_manager'>
# Shape: (24719,)
# Number of points: 24719
# Memory usage: 0.10 MB
#
# 2. Basic Statistics:
# Mean |B|: 509.88 nT
# Median |B|: 638.14 nT
# Standard deviation: 207.27 nT
# Min |B|: 29.23 nT
# Max |B|: 773.99 nT
#
# 3. Component Analysis:
# Mean values:
# ⟨Br⟩: -70.07 nT
# ⟨Bt⟩: 28.33 nT
# ⟨Bn⟩: -25.11 nT
#
# 4. Field Orientation:
# Mean θ (from radial): 99.99°
# Mean φ (azimuthal): -24.55°
#
# 5. Energy Analysis:
# Mean B²: 302939.03 nT²
# Mean magnetic energy density: 1.21e+02 J/m³
#
# 6. Time Series Properties:
# Mean sampling cadence: 40.999245 seconds
# Dominant frequency in power spectrum: 9.53e-05 Hz
#
# 7. Data Quality Metrics:
# Number of NaN values: 0
# Number of zeros: 0
# Number of values > 3σ: 0
