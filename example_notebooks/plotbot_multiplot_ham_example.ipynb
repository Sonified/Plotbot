# %%
# #Remember to select the Plotbot Environment!
# import plotbot
from plotbot import *
# Out:
# initialized server_access
# initialized global_tracker
# initialized plot_config
# initialized data_cubby.
# initialized plot_manager
# CDF classes added to data_cubby type map.
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized proton_fits class
# initialized alpha_fits class
# initialized ham_class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# 🎛️ initialized ploptions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# ✅ Deferred heavy data libraries (cdflib, requests, bs4) - loaded when needed.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#
# 🤖 Plotbot Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_10_28_v3.73
#    Commit: v3.73 Bugfix: Fixed WIND data local file detection and x-axis time formatting for short time ranges at midnight
#
# Import timing is disabled.

# %%
# ------- 💽 CONFIGURE THE DEFAULT DATA DIRECTORY 💽 -------//
# This must be set before pyspedas is imported/run, as pyspedas caches configuration at import time.

config.data_dir = '../data'  # Go up one level to Plotbot/data/

import os
print(f"📁 Data directory absolute path: {os.path.abspath(config.data_dir)}")

# ------- 📡 CONFIGURE THE DEFAULT DATA SERVER 📡 -------//

config.data_server = 'berkeley'
# config.data_server = 'spdf'
# config.data_server = 'dynamic' #Will attempt to download from spdf first and then try berkeley

# ------- 🖨️ CONFIGURE PRINT MANAGER 🖨️ -------//
print_manager.show_status = True
# pm.show_debug = True      # Optional: uncomment for maximum detail
# pm.show_processing = True # Optional: uncomment for processing steps
# pm.show_datacubby = True  # Optional: uncomment for data caching steps
# Out:
# 📁 Plotbot data directory changed: /Users/robertalexander/GitHub/Plotbot/data → ../data
# 🔧 SPEDAS_DATA_DIR updated for pyspedas compatibility
# 📁 Data directory absolute path: /Users/robertalexander/GitHub/Plotbot/data

# %%
print_manager.show_status = True #⭐️
print_manager.show_error = True #⭐️
print_manager.show_debug = False
print_manager.show_processing = False
print_manager.show_datacubby = False
print_manager.show_warning = False
print_manager.show_time_tracking = False

# %%
#######-----📈📈📈📈📈 MULTIPLOTTING MAGIC 📉📉📉📉📉📉-----#######

plt.options.reset() # Resetting options to ensure a clean slate
#====================================================================
# CONFIGURE PRINT MANAGER AND SERVER ACCESS
#====================================================================

print_manager.show_status = True
print_manager.show_debug = False
print_manager.show_dependency_management = False

plt.options.x_axis_carrington_lon = False

server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.
# plt.options.x_axis_carrington_lon_from_perihelion = True
# RESET PLOTTING OPTIONS (safe practice!)
#====================================================================


# CONFIGURE Titles, Labels and axes
#====================================================================
plt.options.use_single_title = False
plt.options.use_single_x_axis = True

plt.options.y_label_uses_encounter = False

plt.options.use_custom_x_axis_label = True
plt.options.custom_x_axis_label = 'Relative Time (Hours From Noon)'
plt.options.single_title_text = "PSP FIELDS Mag RTN Around noon for Multiple Days"

# Rainbow Plot 🌈 -- Uncomment the second set for a single color plot!
#====================================================================
# plt.options.color_mode = 'rainbow'  # Options: 'default', 'rainbow', 'single'
plt.options.color_mode = 'default'  # Options: 'default', 'rainbow', 'single'

# CONFIGURE Vertical Line
#====================================================================
plt.options.draw_vertical_line = True
plt.options.vertical_line_width = 1
plt.options.vertical_line_color = 'red'
plt.options.vertical_line_style = '--'

# DATA SELECTION FOR PLOTTING
#====================================================================
plt.options.use_relative_time = True
plt.options.window = '24:00:00.000'
plt.options.position = 'around'  # Position, also try 'before' or 'after'
plt.options.relative_time_step_units = 'hours'
plt.options.relative_time_step = 1

# Data Selection
#====================================================================
pmag_multiplot_dates = [
    # {'noon_time': '2025-03-19/12:00:00.000'},
    {'noon_time': '2025-03-20/12:00:00.000'}, 
    {'noon_time': '2025-03-21/12:00:00.000'},
    {'noon_time': '2025-03-22/12:00:00.000'},
    {'noon_time': '2025-03-23/12:00:00.000'},
    {'noon_time': '2025-03-24/12:00:00.000'},
    {'noon_time': '2025-03-25/12:00:00.000'},
    # {'noon_time': '2025-03-26/12:00:00.000'},
    # {'noon_time': '2025-03-27/12:00:00.000'}
]

plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!
# plot_variable = proton.anisotropy #You'll need server access to plot this variable!

plot_data = [(encounter['noon_time'], plot_variable) for encounter in pmag_multiplot_dates]

# Initialize Ham! 🍖 ✨NEW!✨
#====================================================================
plt.options.hamify = True
plt.options.ham_var = ham.hamogram_30s
plt.options.ham_opacity = 0.7
# plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!

# CALL MULTIPLOT WITH UPDATED OPTIONS
#====================================================================
multiplot(plot_data); #You'll need server access to plot this variable! ✨Un-comment to Plot!
# Out:
# 🚀 PROCESSING ENCOUNTER E23 (Panel 1) - Center time: 2025-03-20/12:00:00.000
# 🕒 TimeRangeTracker: Stored trange ['2025-03-20/00:00:00.000000', '2025-03-21/00:00:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - A local .cdf file already exists:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250320_v00.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2025-03-20/00:00:00', '2025-03-21/00:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: False, length: 0
#    ⚡ RESULT: has_existing_data = False
#    🔄 Taking UPDATE PATH for 'mag_rtn_4sa'
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ ENCOUNTER E23 (Panel 1) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E23: Variable contains 395507 data points
# 🚀 PROCESSING ENCOUNTER E23 (Panel 2) - Center time: 2025-03-21/12:00:00.000
# 🕒 TimeRangeTracker: Stored trange ['2025-03-21/00:00:00.000000', '2025-03-22/00:00:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - A local .cdf file already exists:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250321_v00.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2025-03-21/00:00:00', '2025-03-22/00:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 395507
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ ENCOUNTER E23 (Panel 2) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E23: Variable contains 395507 data points
# 🚀 PROCESSING ENCOUNTER E23 (Panel 3) - Center time: 2025-03-22/12:00:00.000
# 🕒 TimeRangeTracker: Stored trange ['2025-03-22/00:00:00.000000', '2025-03-23/00:00:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - A local .cdf file already exists:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250322_v00.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2025-03-22/00:00:00', '2025-03-23/00:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 791014
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ ENCOUNTER E23 (Panel 3) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E23: Variable contains 395506 data points
# 🚀 PROCESSING ENCOUNTER E23 (Panel 4) - Center time: 2025-03-23/12:00:00.000
# 🕒 TimeRangeTracker: Stored trange ['2025-03-23/00:00:00.000000', '2025-03-24/00:00:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - A local .cdf file already exists:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250323_v00.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2025-03-23/00:00:00', '2025-03-24/00:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 1186520
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ ENCOUNTER E23 (Panel 4) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E23: Variable contains 395506 data points
# 🚀 PROCESSING ENCOUNTER E23 (Panel 5) - Center time: 2025-03-24/12:00:00.000
# 🕒 TimeRangeTracker: Stored trange ['2025-03-24/00:00:00.000000', '2025-03-25/00:00:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - A local .cdf file already exists:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250324_v00.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2025-03-24/00:00:00', '2025-03-25/00:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 1582026
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ ENCOUNTER E23 (Panel 5) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E23: Variable contains 395507 data points
# 🚀 PROCESSING ENCOUNTER E23 (Panel 6) - Center time: 2025-03-25/12:00:00.000
# 🕒 TimeRangeTracker: Stored trange ['2025-03-25/00:00:00.000000', '2025-03-26/00:00:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - A local .cdf file already exists:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250325_v00.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2025-03-25/00:00:00', '2025-03-26/00:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 1977533
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ ENCOUNTER E23 (Panel 6) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E23: Variable contains 395507 data points
# Using constrained_layout=True - letting matplotlib handle all spacing automatically.
# 🎨 PLOTTING ENCOUNTER E23 (Panel 1) - Center time: 2025-03-20/12:00:00.000
# ✅ ENCOUNTER E23: Ready to plot with 395507 data points
# 🕒 TimeRangeTracker: Stored trange ['2025-03-20/00:00:00.000000', '2025-03-21/00:00:00.000000']
# 🛰️ ham - acquiring variables: hamogram_30s
# 📋 Required data types: {'ham'}
# 🔄 Processing: ham
# Successfully loaded Hammerhead data with 24687 time points
# 📥 Requesting DataCubby to update/merge global instance for ham...
# 🔍 PATH ANALYSIS for 'ham' (class: ham_class)
#    📊 datetime_array_exists: True, not_none: False, length: 0
#    ⚡ RESULT: has_existing_data = False
#    🔄 Taking UPDATE PATH for 'ham'
# ✅ DataCubby processed update for ham.
# 🎨 PLOTTING ENCOUNTER E23 (Panel 2) - Center time: 2025-03-21/12:00:00.000
# ✅ ENCOUNTER E23: Ready to plot with 395507 data points
# 🕒 TimeRangeTracker: Stored trange ['2025-03-21/00:00:00.000000', '2025-03-22/00:00:00.000000']
# 🛰️ ham - acquiring variables: hamogram_30s
# 📋 Required data types: {'ham'}
# 🔄 Processing: ham
# Successfully loaded Hammerhead data with 26032 time points
# 📥 Requesting DataCubby to update/merge global instance for ham...
# 🔍 PATH ANALYSIS for 'ham' (class: ham_class)
#    📊 datetime_array_exists: True, not_none: True, length: 24687
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'ham'
# ✅ DataCubby processed update for ham.
# 🎨 PLOTTING ENCOUNTER E23 (Panel 3) - Center time: 2025-03-22/12:00:00.000
# ✅ ENCOUNTER E23: Ready to plot with 395506 data points
# 🕒 TimeRangeTracker: Stored trange ['2025-03-22/00:00:00.000000', '2025-03-23/00:00:00.000000']
# 🛰️ ham - acquiring variables: hamogram_30s
# 📋 Required data types: {'ham'}
# 🔄 Processing: ham
# Successfully loaded Hammerhead data with 48800 time points
# 📥 Requesting DataCubby to update/merge global instance for ham...
# 🔍 PATH ANALYSIS for 'ham' (class: ham_class)
#    📊 datetime_array_exists: True, not_none: True, length: 50719
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'ham'
# ✅ DataCubby processed update for ham.
# 🎨 PLOTTING ENCOUNTER E23 (Panel 4) - Center time: 2025-03-23/12:00:00.000
# ✅ ENCOUNTER E23: Ready to plot with 395506 data points
# 🕒 TimeRangeTracker: Stored trange ['2025-03-23/00:00:00.000000', '2025-03-24/00:00:00.000000']
# 🛰️ ham - acquiring variables: hamogram_30s
# 📋 Required data types: {'ham'}
# 🔄 Processing: ham
# Successfully loaded Hammerhead data with 25736 time points
# 📥 Requesting DataCubby to update/merge global instance for ham...
# 🔍 PATH ANALYSIS for 'ham' (class: ham_class)
#    📊 datetime_array_exists: True, not_none: True, length: 99519
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'ham'
# ✅ DataCubby processed update for ham.
# 🎨 PLOTTING ENCOUNTER E23 (Panel 5) - Center time: 2025-03-24/12:00:00.000
# ✅ ENCOUNTER E23: Ready to plot with 395507 data points
# 🕒 TimeRangeTracker: Stored trange ['2025-03-24/00:00:00.000000', '2025-03-25/00:00:00.000000']
# 🛰️ ham - acquiring variables: hamogram_30s
# 📋 Required data types: {'ham'}
# 🔄 Processing: ham
# Successfully loaded Hammerhead data with 24718 time points
# 📥 Requesting DataCubby to update/merge global instance for ham...
# 🔍 PATH ANALYSIS for 'ham' (class: ham_class)
#    📊 datetime_array_exists: True, not_none: True, length: 125255
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'ham'
# ✅ DataCubby processed update for ham.
# 🎨 PLOTTING ENCOUNTER E23 (Panel 6) - Center time: 2025-03-25/12:00:00.000
# ✅ ENCOUNTER E23: Ready to plot with 395507 data points
# 🕒 TimeRangeTracker: Stored trange ['2025-03-25/00:00:00.000000', '2025-03-26/00:00:00.000000']
# 🛰️ ham - acquiring variables: hamogram_30s
# 📋 Required data types: {'ham'}
# 🔄 Processing: ham
# Successfully loaded Hammerhead data with 26366 time points
# 📥 Requesting DataCubby to update/merge global instance for ham...
# 🔍 PATH ANALYSIS for 'ham' (class: ham_class)
#    📊 datetime_array_exists: True, not_none: True, length: 149973
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'ham'
# ✅ DataCubby processed update for ham.
# Generating multiplot...
