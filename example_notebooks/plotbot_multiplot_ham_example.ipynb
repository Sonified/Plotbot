# %%
# #Remember to select the Plotbot Environment!
# import plotbot
from plotbot import *
# Out:
# initialized server_access
# initialized global_tracker
# initialized plot_config
# initialized data_cubby.
# initialized plot_manager
# CDF classes added to data_cubby type map.
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized proton_fits class
# initialized alpha_fits class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# 🎛️ initialized ploptions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# ✅ Deferred heavy data libraries (cdflib, requests, bs4) - loaded when needed.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#
# 🤖 Plotbot Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_10_28_v3.73
#    Commit: v3.73 Bugfix: Fixed WIND data local file detection and x-axis time formatting for short time ranges at midnight
#
# Import timing is disabled.

# %%
# ------- 💽 CONFIGURE THE DEFAULT DATA DIRECTORY 💽 -------//
# This must be set before pyspedas is imported/run, as pyspedas caches configuration at import time.

config.data_dir = '../data'  # Go up one level to Plotbot/data/

import os
print(f"📁 Data directory absolute path: {os.path.abspath(config.data_dir)}")

# ------- 📡 CONFIGURE THE DEFAULT DATA SERVER 📡 -------//

config.data_server = 'berkeley'
# config.data_server = 'spdf'
# config.data_server = 'dynamic' #Will attempt to download from spdf first and then try berkeley

# ------- 🖨️ CONFIGURE PRINT MANAGER 🖨️ -------//
print_manager.show_status = True
# pm.show_debug = True      # Optional: uncomment for maximum detail
# pm.show_processing = True # Optional: uncomment for processing steps
# pm.show_datacubby = True  # Optional: uncomment for data caching steps
# Out:
# 📁 Plotbot data directory changed: /Users/robertalexander/GitHub/Plotbot/data → ../data
# 🔧 SPEDAS_DATA_DIR updated for pyspedas compatibility
# 📁 Data directory absolute path: /Users/robertalexander/GitHub/Plotbot/data

# %%
print_manager.show_status = True #⭐️
print_manager.show_ham_debugging = True
print_manager.show_error = True #⭐️
print_manager.show_debug = False
print_manager.show_processing = False
print_manager.show_data_cubby = False
print_manager.show_warning = False
print_manager.show_time_tracking = False

# %%
# load_simple_snapshot('Br_Norm_all_Encounters.pkl')

# %%
#######-----📈📈📈📈📈 MULTIPLOTTING MAGIC 📉📉📉📉📉📉-----#######

plt.options.reset() # Resetting options to ensure a clean slate
#====================================================================
# CONFIGURE PRINT MANAGER AND SERVER ACCESS
#====================================================================

plt.options.x_axis_carrington_lon = False

server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.
# plt.options.x_axis_carrington_lon_from_perihelion = True
# RESET PLOTTING OPTIONS (safe practice!)
#====================================================================


# CONFIGURE Titles, Labels and axes
#====================================================================
plt.options.use_single_title = True
plt.options.use_single_x_axis = True

plt.options.y_label_uses_encounter = False

plt.options.use_custom_x_axis_label = True
plt.options.custom_x_axis_label = 'Relative Time (Hours From Noon)'
# plt.options.single_title_text = "PSP FIELDS Mag RTN Around noon for Multiple Days"
plt.options.single_title_text = " "

# CONFIGURE GENERAL PLOT OPTIONS
#====================================================================

plt.options.constrained_layout = False  # True or False
plt.options.save_bbox_inches = 'tight' #options are 'none' and 'tight', this setting overrides the margin settings

# Plot Sizing
plt.options.width = 20
plt.options.height_per_panel = 1.3
plt.options.hspace = .15

# TITLE handling
plt.options.margin_top = 0.85 
plt.options.margin_bottom = 0.05
plt.options.title_font_size = 20
plt.options.title_y_position = 1.05
plt.options.title_pad = 10

# Font Sizes and Padding
plt.options.y_axis_label_font_size = 22
plt.options.x_axis_label_font_size = 22
plt.options.x_tick_label_font_size = 17
plt.options.y_tick_label_font_size = 17
plt.options.y_label_pad = 8
plt.options.x_label_pad = 7

plt.options.y_label_uses_encounter = True
plt.options.y_label_includes_time = False

# Rainbow Plot 🌈 -- Uncomment the second set for a single color plot!
#====================================================================
plt.options.color_mode = 'rainbow'  # Options: 'default', 'rainbow', 'single'
# plt.options.color_mode = 'default'  # Options: 'default', 'rainbow', 'single'

# CONFIGURE Vertical Line
#====================================================================
plt.options.draw_vertical_line = True
plt.options.vertical_line_width = 2
plt.options.vertical_line_color = 'red'
plt.options.vertical_line_style = '--'

# DATA SELECTION FOR PLOTTING
#====================================================================
plt.options.use_relative_time = True
# plt.options.window = '96:00:00.000'
# plt.options.window = '48:00:00.000'
plt.options.window = '144:00:00.000'
plt.options.position = 'around'  # Position, also try 'before' or 'after'
plt.options.relative_time_step_units = 'hours'
plt.options.relative_time_step = 6

# Data Selection
#====================================================================
# hcs_multiplot_dates = [
#     {'hcs_crossing_time': '2022-02-27/05:32:33.000'},  # E15
#     {'hcs_crossing_time': '2022-06-02/06:16:59.000'},  # E16
#     {'hcs_crossing_time': '2023-03-17/08:58:16.000'},  # E19
#     {'hcs_crossing_time': '2023-09-28/18:49:07.000'},  # E21
#     {'hcs_crossing_time': '2023-12-31/13:20:19.000'},  # E22
#     {'hcs_crossing_time': '2025-03-23/05:03:04.000'},  # E23
# ]

rainbow_encounters = [
    # {'perihelion': '2018/11/06 03:27:00.000'}, #Enc 1
    # {'perihelion': '2019/04/04 22:39:00.000'}, #Enc 2
    # {'perihelion': '2019/09/01 17:50:00.000'}, #Enc 3

    {'perihelion': '2020/01/29 09:37:00.000'}, #Enc 4
    {'perihelion': '2020/06/07 08:23:00.000'}, #Enc 5
    {'perihelion': '2020/09/27 09:16:00.000'}, #Enc 6
    {'perihelion': '2021/01/17 17:40:00.000'}, #Enc 7
    {'perihelion': '2021/04/29 08:48:00.000'}, #Enc 8
    {'perihelion': '2021/08/09 19:11:00.000'}, #Enc 9
    {'perihelion': '2021/11/21 08:23:00.000'}, #Enc 10
    {'perihelion': '2022/02/25 15:38:00.000'}, #Enc 11
    {'perihelion': '2022/06/01 22:51:00.000'}, #Enc 12
    {'perihelion': '2022/09/06 06:04:00.000'}, #Enc 13
    {'perihelion': '2022/12/11 13:16:00.000'}, #Enc 14
    {'perihelion': '2023/03/17 20:30:00.000'}, #Enc 15
    {'perihelion': '2023/06/22 03:46:00.000'}, #Enc 16
    {'perihelion': '2023/09/27 23:28:00.000'}, #Enc 17
    {'perihelion': '2023/12/29 00:56:00.000'}, #Enc 18
    {'perihelion': '2024/03/30 02:21:00.000'}, #Enc 19 
    {'perihelion': '2024/06/30 03:47:00.000'}, #Enc 20 
    {'perihelion': '2024/09/30 05:15:00.000'}, #Enc 21 
    {'perihelion': '2024/12/24 11:53:00.000'}, #Enc 22 
    {'perihelion': '2025/03/22 22:42:00.000'}, #Enc 23
]

plt.options.y_label_uses_encounter = True
plt.options.y_label_includes_time = False

# plt.options.y_label_alignment = 'right'

plt.options.y_label_x_position = -0.07  # Try values like -0.02, -0.04, -0.05
plt.options.y_label_alignment = 'left'

# Hide the right axis labels (n_ham, etc.)
plt.options.show_right_axis_label = False

plot_variable = mag_rtn_4sa.br_norm #You'll need server access to plot this variable!
# plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!
# plot_variable = proton.anisotropy #You'll need server access to plot this variable!

plot_data = [(encounter['perihelion'], plot_variable) for encounter in rainbow_encounters]

# ✨ ACTIVATE r_sunAXIS! ✨ NEW ✨ And Mutually Exclusive!
#====================================================================
# plt.options.x_axis_r_sun = False  # Use radial distance (R_sun)
# plt.options.x_axis_carrington_lat = False #May still need debugging.
# plt.options.x_axis_carrington_lon = False #May still need debugging.
plt.options.use_degrees_from_perihelion =  True #⭐️<---- Working! 

# Initialize Ham! 🍖 ✨NEW!✨
#====================================================================
# plt.options.hamify = False
# plt.options.r_hand_single_color = '#363737'  # Set your desired hex color
# plt.options.ham_var = ham.n_ham
# plt.options.ham_opacity = 0.2


# Ham Binned Overlay! 🗑️🍖🗑️ ✨NEW!✨
#====================================================================
plt.options.ham_binned_degrees_overlay = True
# ham_binned_degrees_color = '#4682B4' # (steelblue) - ONLY for new binned overlay
plt.options.ham_binned_degrees_color = '#363737' # (Grey / Default) - ONLY for new binned overlay
plt.options.ham_binned_degrees_overlay_opacity = 0.5 #- ONLY for new binned overlay
# plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!

# Draw a horizontal line 🗑️🍖🗑️ ✨NEW!✨
#====================================================================
plt.options.draw_horizontal_line = True
plt.options.horizontal_line_value = 0
plt.options.horizontal_line_alpha = 0.3  # faint line
plt.options.horizontal_line_color = 'gray'  # optional
# plt.options.horizontal_line_use_panel_color = True  # Uses rainbow panel color!


# Add a drop shadow ✨NEW!✨
#====================================================================
plt.options.use_drop_shadow = True
plt.options.drop_shadow_offset = (2, -2)  # (x, y) in points
plt.options.drop_shadow_color = 'gray'
plt.options.drop_shadow_alpha = 0.3

#A9A9A9 — lighter dark grey
#696969 — darker dark grey
#363737 — very dark grey

plt.options.x_axis_tight = True  # Remove gap between data and axis edges

plt.options.degrees_from_perihelion_clip_at_reversal = True
plt.options.degrees_from_perihelion_clip_tolerance = .6  # 1.0=strict, 0.99=1% tolerance

# CALL MULTIPLOT WITH UPDATED OPTIONS
#====================================================================
multiplot(plot_data); #You'll need server access to plot this variable! ✨Un-comment to Plot!
# Out:
# Enabling degrees from perihelion axis.
# Note: 'use_relative_time' is also active with 'degrees_from_perihelion'.
# Loading Parker Solar Probe positional data from /Users/robertalexander/GitHub/Plotbot/support_data/trajectories/psp_positional_data.npz
# -> Loaded 99768 positional data points with types: radial, longitude, latitude
# 🚀 PROCESSING ENCOUNTER E4 (Panel 1) - Center time: 2020/01/29 09:37:00.000
# 🕒 TimeRangeTracker: Stored trange ['2020-01-26/09:37:00.000000', '2020-02-01/09:37:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200126_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200127_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_rtn_4_sa_per_cyc_20200128_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_rtn_4_sa_per_cyc_20200129_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_rtn_4_sa_per_cyc_20200130_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200131_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200201_v02.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2020-01-26/09:37:00', '2020-02-01/09:37:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: False, length: 0
#    ⚡ RESULT: has_existing_data = False
#    🔄 Taking UPDATE PATH for 'mag_rtn_4sa'
# ✅ DataCubby processed update for mag_rtn_4sa.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting Berkeley acquisition path for spi_sf00_l3_mom...
# 📡 spi_sf00_l3_mom - Local .cdf files already exist:
# 📂 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200126_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200127_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200128_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200129_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200130_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200131_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200201_v04.cdf
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2020-01-26/09:37:00', '2020-02-01/09:37:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: False, length: 0
#    ⚡ RESULT: has_existing_data = False
#    🔄 Taking UPDATE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-01-26/09:37:00.000000 to 2020-02-01/09:37:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-01-26/09:37:00.000000 to 2020-02-01/09:37:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-01-26/09:37:00.000000 to 2020-02-01/09:37:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-01-26/09:37:00.000000 to 2020-02-01/09:37:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-01-26/09:37:00.000000 to 2020-02-01/09:37:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E4 (Panel 1) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E4: Variable contains 2373024 data points
# 🚀 PROCESSING ENCOUNTER E5 (Panel 2) - Center time: 2020/06/07 08:23:00.000
# 🕒 TimeRangeTracker: Stored trange ['2020-06-04/08:23:00.000000', '2020-06-10/08:23:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200604_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200605_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200606_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200607_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200608_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200609_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200610_v02.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2020-06-04/08:23:00', '2020-06-10/08:23:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 2373024
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting Berkeley acquisition path for spi_sf00_l3_mom...
# 📡 spi_sf00_l3_mom - Local .cdf files already exist:
# 📂 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200604_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200605_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200606_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200607_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200608_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200609_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200610_v04.cdf
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2020-06-04/08:23:00', '2020-06-10/08:23:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 74156
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ DataCubby processed update for mag_rtn_4sa.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-06-04/08:23:00.000000 to 2020-06-10/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E5 (Panel 2) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E5: Variable contains 4746056 data points
# 🚀 PROCESSING ENCOUNTER E6 (Panel 3) - Center time: 2020/09/27 09:16:00.000
# 🕒 TimeRangeTracker: Stored trange ['2020-09-24/09:16:00.000000', '2020-09-30/09:16:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200924_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200925_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200926_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200927_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200928_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200929_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2020/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20200930_v02.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2020-09-24/09:16:00', '2020-09-30/09:16:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 4746056
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting Berkeley acquisition path for spi_sf00_l3_mom...
# 📡 spi_sf00_l3_mom - Local .cdf files already exist:
# 📂 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200924_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200925_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200926_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200927_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200928_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200929_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200930_v04.cdf
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2020-09-24/09:16:00', '2020-09-30/09:16:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 148314
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ DataCubby processed update for mag_rtn_4sa.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2020-09-24/09:16:00.000000 to 2020-09-30/09:16:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E6 (Panel 3) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E6: Variable contains 7117503 data points
# 🚀 PROCESSING ENCOUNTER E7 (Panel 4) - Center time: 2021/01/17 17:40:00.000
# 🕒 TimeRangeTracker: Stored trange ['2021-01-14/17:40:00.000000', '2021-01-20/17:40:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210114_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210115_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210116_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210117_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210118_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210119_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210120_v02.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2021-01-14/17:40:00', '2021-01-20/17:40:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 7117503
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting Berkeley acquisition path for spi_sf00_l3_mom...
# 📡 spi_sf00_l3_mom - Local .cdf files already exist:
# 📂 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210114_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210115_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210116_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210117_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210118_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210119_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210120_v04.cdf
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2021-01-14/17:40:00', '2021-01-20/17:40:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 296597
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ DataCubby processed update for mag_rtn_4sa.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-01-14/17:40:00.000000 to 2021-01-20/17:40:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E7 (Panel 4) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E7: Variable contains 9490542 data points
# 🚀 PROCESSING ENCOUNTER E8 (Panel 5) - Center time: 2021/04/29 08:48:00.000
# 🕒 TimeRangeTracker: Stored trange ['2021-04-26/08:48:00.000000', '2021-05-02/08:48:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210426_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210427_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210428_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210429_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210430_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_rtn_4_sa_per_cyc_20210501_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210502_v02.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2021-04-26/08:48:00', '2021-05-02/08:48:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 9490542
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting Berkeley acquisition path for spi_sf00_l3_mom...
# 📡 spi_sf00_l3_mom - Local .cdf files already exist:
# 📂 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_l3_mom_20210426_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_l3_mom_20210427_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210428_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210429_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210430_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210501_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210502_v04.cdf
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2021-04-26/08:48:00', '2021-05-02/08:48:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 444865
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ DataCubby processed update for mag_rtn_4sa.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-04-26/08:48:00.000000 to 2021-05-02/08:48:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E8 (Panel 5) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E8: Variable contains 11863581 data points
# 🚀 PROCESSING ENCOUNTER E9 (Panel 6) - Center time: 2021/08/09 19:11:00.000
# 🕒 TimeRangeTracker: Stored trange ['2021-08-06/19:11:00.000000', '2021-08-12/19:11:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210806_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210807_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210808_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210809_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210810_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210811_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20210812_v02.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2021-08-06/19:11:00', '2021-08-12/19:11:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 11863581
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting Berkeley acquisition path for spi_sf00_l3_mom...
# 📡 spi_sf00_l3_mom - Local .cdf files already exist:
# 📂 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210806_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210807_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210808_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210809_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210810_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210811_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20210812_v04.cdf
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2021-08-06/19:11:00', '2021-08-12/19:11:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 593148
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ DataCubby processed update for mag_rtn_4sa.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-08-06/19:11:00.000000 to 2021-08-12/19:11:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E9 (Panel 6) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E9: Variable contains 14236620 data points
# 🚀 PROCESSING ENCOUNTER E10 (Panel 7) - Center time: 2021/11/21 08:23:00.000
# 🕒 TimeRangeTracker: Stored trange ['2021-11-18/08:23:00.000000', '2021-11-24/08:23:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20211118_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20211119_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20211120_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20211121_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20211122_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20211123_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2021/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20211124_v02.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2021-11-18/08:23:00', '2021-11-24/08:23:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 14236620
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting Berkeley acquisition path for spi_sf00_l3_mom...
# 📡 spi_sf00_l3_mom - Local .cdf files already exist:
# 📂 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20211118_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20211119_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20211120_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20211121_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20211122_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20211123_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2021/psp_swp_spi_sf00_L3_mom_20211124_v04.cdf
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2021-11-18/08:23:00', '2021-11-24/08:23:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 754788
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ DataCubby processed update for mag_rtn_4sa.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2021-11-18/08:23:00.000000 to 2021-11-24/08:23:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E10 (Panel 7) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E10: Variable contains 16609659 data points
# 🚀 PROCESSING ENCOUNTER E11 (Panel 8) - Center time: 2022/02/25 15:38:00.000
# 🕒 TimeRangeTracker: Stored trange ['2022-02-22/15:38:00.000000', '2022-02-28/15:38:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20220222_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20220223_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20220224_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_rtn_4_sa_per_cyc_20220225_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20220226_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20220227_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2022/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20220228_v02.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2022-02-22/15:38:00', '2022-02-28/15:38:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 16609659
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# ...
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2024-12-21/11:53:00.000000 to 2024-12-27/11:53:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E22 (Panel 19) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E22: Variable contains 46472289 data points
# 🚀 PROCESSING ENCOUNTER E23 (Panel 20) - Center time: 2025/03/22 22:42:00.000
# 🕒 TimeRangeTracker: Stored trange ['2025-03-19/22:42:00.000000', '2025-03-25/22:42:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: br_norm
# 📋 Required data types: {'mag_RTN_4sa'}
# 🔄 Processing: mag_RTN_4sa
# Attempting Berkeley acquisition path for mag_RTN_4sa...
# 📡 mag_RTN_4sa - Local .cdf files already exist:
# 📂 ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250319_v00.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250320_v00.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_rtn_4_sa_per_cyc_20250320_v02.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250321_v00.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250322_v00.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250323_v00.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250324_v00.cdf, ../data/psp/fields/l2/mag_rtn_4_per_cycle/2025/psp_fld_l2_mag_RTN_4_Sa_per_Cyc_20250325_v00.cdf
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2025-03-19/22:42:00', '2025-03-25/22:42:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# 🔍 PATH ANALYSIS for 'mag_rtn_4sa' (class: mag_rtn_4sa_class)
#    📊 datetime_array_exists: True, not_none: True, length: 46472289
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'mag_rtn_4sa'
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# Attempting Berkeley acquisition path for spi_sf00_l3_mom...
# 📡 spi_sf00_l3_mom - Local .cdf files already exist:
# 📂 ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250319_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250319_v00.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250320_v00.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250320_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250321_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250321_v00.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250322_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250322_v00.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250323_v00.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250323_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250324_v00.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250324_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250325_v04.cdf, ../data/psp/sweap/spi/l3/spi_sf00_l3_mom/2025/psp_swp_spi_sf00_l3_mom_20250325_v00.cdf
# 📁 Filtered to highest versions: 14 -> 7 files (removed 7 older versions)
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2025-03-19/22:42:00', '2025-03-25/22:42:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# 🔍 PATH ANALYSIS for 'spi_sf00_l3_mom' (class: proton_class)
#    📊 datetime_array_exists: True, not_none: True, length: 3145652
#    ⚡ RESULT: has_existing_data = True
#    🔀 Taking MERGE PATH for 'spi_sf00_l3_mom'
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ DataCubby processed update for mag_rtn_4sa.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# 🛰️ spi_sf00_l3_mom - acquiring variables: sun_dist_rsun
# 📋 Required data types: {'spi_sf00_l3_mom'}
# 🔄 Processing: spi_sf00_l3_mom
# spi_sf00_l3_mom already calculated for the time range: 2025-03-19/22:42:00.000000 to 2025-03-25/22:42:00.000000
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# ✅ ENCOUNTER E23 (Panel 20) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E23: Variable contains 49240835 data points
# Using constrained_layout=False - applying manual margins.
# Set margins (top=0.85, bottom=0.05, left=0.1, right=0.9) and hspace=0.15
# 🎨 PLOTTING ENCOUNTER E4 (Panel 1) - Center time: 2020/01/29 09:37:00.000
# ✅ ENCOUNTER E4: Ready to plot with 49240835 data points
# 🎨 Panel 1: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(1.0, 0.0, 0.0)
# 🎨 Spines colored to (1.0, 0.0, 0.0)
# HAM bins: kept 51/51 (removed 0 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E5 (Panel 2) - Center time: 2020/06/07 08:23:00.000
# ✅ ENCOUNTER E5: Ready to plot with 49240835 data points
# 🎨 Panel 2: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(1.0, 0.17337461300309598, 0.0)
# 🎨 Spines colored to (1.0, 0.17337461300309598, 0.0)
# HAM bins: kept 51/51 (removed 0 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E6 (Panel 3) - Center time: 2020/09/27 09:16:00.000
# ✅ ENCOUNTER E6: Ready to plot with 49240835 data points
# 🎨 Panel 3: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(1.0, 0.34674922600619196, 0.0)
# 🎨 Spines colored to (1.0, 0.34674922600619196, 0.0)
# HAM bins: kept 92/93 (removed 1 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E7 (Panel 4) - Center time: 2021/01/17 17:40:00.000
# ✅ ENCOUNTER E7: Ready to plot with 49240835 data points
# 🎨 Panel 4: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(1.0, 0.5201238390092879, 0.0)
# 🎨 Spines colored to (1.0, 0.5201238390092879, 0.0)
# HAM bins: kept 93/94 (removed 1 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E8 (Panel 5) - Center time: 2021/04/29 08:48:00.000
# ✅ ENCOUNTER E8: Ready to plot with 49240835 data points
# 🎨 Panel 5: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(1.0, 0.6264189886480909, 0.0)
# 🎨 Spines colored to (1.0, 0.6264189886480909, 0.0)
# HAM bins: kept 122/126 (removed 4 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E9 (Panel 6) - Center time: 2021/08/09 19:11:00.000
# ✅ ENCOUNTER E9: Ready to plot with 49240835 data points
# 🎨 Panel 6: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(1.0, 0.7192982456140351, 0.0)
# 🎨 Spines colored to (1.0, 0.7192982456140351, 0.0)
# HAM bins: kept 122/124 (removed 2 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E10 (Panel 7) - Center time: 2021/11/21 08:23:00.000
# ✅ ENCOUNTER E10: Ready to plot with 49240835 data points
# 🎨 Panel 7: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(1.0, 0.8121775025799793, 0.0)
# 🎨 Spines colored to (1.0, 0.8121775025799793, 0.0)
# HAM bins: kept 142/148 (removed 6 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E11 (Panel 8) - Center time: 2022/02/25 15:38:00.000
# ✅ ENCOUNTER E11: Ready to plot with 49240835 data points
# 🎨 Panel 8: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.7894736842105265, 0.771310629514964, 0.0)
# 🎨 Spines colored to (0.7894736842105265, 0.771310629514964, 0.0)
# HAM bins: kept 142/148 (removed 6 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E12 (Panel 9) - Center time: 2022/06/01 22:51:00.000
# ✅ ENCOUNTER E12: Ready to plot with 49240835 data points
# 🎨 Panel 9: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.47368421052631593, 0.6635706914344686, 0.0)
# 🎨 Spines colored to (0.47368421052631593, 0.6635706914344686, 0.0)
# HAM bins: kept 142/148 (removed 6 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E13 (Panel 10) - Center time: 2022/09/06 06:04:00.000
# ✅ ENCOUNTER E13: Ready to plot with 49240835 data points
# 🎨 Panel 10: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.1578947368421053, 0.5558307533539733, 0.0)
# 🎨 Spines colored to (0.1578947368421053, 0.5558307533539733, 0.0)
# HAM bins: kept 142/148 (removed 6 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E14 (Panel 11) - Center time: 2022/12/11 13:16:00.000
# ✅ ENCOUNTER E14: Ready to plot with 49240835 data points
# 🎨 Panel 11: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.0, 0.42270381836945303, 0.1578947368421053)
# 🎨 Spines colored to (0.0, 0.42270381836945303, 0.1578947368421053)
# HAM bins: kept 142/147 (removed 5 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E15 (Panel 12) - Center time: 2023/03/17 20:30:00.000
# ✅ ENCOUNTER E15: Ready to plot with 49240835 data points
# 🎨 Panel 12: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.0, 0.2641898864809081, 0.47368421052631593)
# 🎨 Spines colored to (0.0, 0.2641898864809081, 0.47368421052631593)
# HAM bins: kept 142/148 (removed 6 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E16 (Panel 13) - Center time: 2023/06/22 03:46:00.000
# ✅ ENCOUNTER E16: Ready to plot with 49240835 data points
# 🎨 Panel 13: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.0, 0.10567595459236334, 0.7894736842105261)
# 🎨 Spines colored to (0.0, 0.10567595459236334, 0.7894736842105261)
# HAM bins: kept 142/148 (removed 6 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E17 (Panel 14) - Center time: 2023/09/27 23:28:00.000
# ✅ ENCOUNTER E17: Ready to plot with 49240835 data points
# 🔍 DEBUG E14: Found 2373030 time indices
# 🔍 DEBUG E14: Data shape: (33220899,)
# 🔍 DEBUG E14: Time range: 2023-09-24T23:28:00.124117888 to 2023-09-30T23:27:59.811368320
# 🎨 Panel 14: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.03095975232198152, 0.0, 0.9484004127966975)
# 🎨 Spines colored to (0.03095975232198152, 0.0, 0.9484004127966975)
# HAM bins: kept 157/165 (removed 8 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E18 (Panel 15) - Center time: 2023/12/29 00:56:00.000
# ✅ ENCOUNTER E18: Ready to plot with 49240835 data points
# 🔍 DEBUG E15: Found 2373039 time indices
# 🔍 DEBUG E15: Data shape: (35593938,)
# 🔍 DEBUG E15: Time range: 2023-12-26T00:56:00.045665024 to 2024-01-01T00:55:59.934154496
# 🎨 Panel 15: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.12383900928792556, 0.0, 0.7936016511867907)
# 🎨 Spines colored to (0.12383900928792556, 0.0, 0.7936016511867907)
# HAM bins: kept 157/166 (removed 9 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E19 (Panel 16) - Center time: 2024/03/30 02:21:00.000
# ✅ ENCOUNTER E19: Ready to plot with 49240835 data points
# 🎨 Panel 16: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.21671826625386986, 0.0, 0.6388028895768836)
# 🎨 Spines colored to (0.21671826625386986, 0.0, 0.6388028895768836)
# HAM bins: kept 156/164 (removed 8 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E20 (Panel 17) - Center time: 2024/06/30 03:47:00.000
# ✅ ENCOUNTER E20: Ready to plot with 49240835 data points
# 🎨 Panel 17: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.30918472652218776, 0.0, 0.5265221878224973)
# 🎨 Spines colored to (0.30918472652218776, 0.0, 0.5265221878224973)
# HAM bins: kept 157/166 (removed 9 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E21 (Panel 18) - Center time: 2024/09/30 05:15:00.000
# ✅ ENCOUNTER E21: Ready to plot with 49240835 data points
# 🎨 Panel 18: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.3995872033023735, 0.0, 0.6268317853457172)
# 🎨 Spines colored to (0.3995872033023735, 0.0, 0.6268317853457172)
# HAM bins: kept 157/165 (removed 8 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E22 (Panel 19) - Center time: 2024/12/24 11:53:00.000
# ✅ ENCOUNTER E22: Ready to plot with 49240835 data points
# 🎨 Panel 19: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=(0.4899896800825594, 0.0, 0.727141382868937)
# 🎨 Spines colored to (0.4899896800825594, 0.0, 0.727141382868937)
# HAM bins: kept 170/181 (removed 11 curl-back bins)
# 🎨 PLOTTING ENCOUNTER E23 (Panel 20) - Center time: 2025/03/22 22:42:00.000
# ✅ ENCOUNTER E23: Ready to plot with 49240835 data points
# 🎨 Panel 20: Calling apply_panel_color (time_series)
# 🎨 apply_panel_color called: color=darkviolet
# 🎨 Spines colored to darkviolet
# HAM bins: kept 170/181 (removed 11 curl-back bins)
# Generating multiplot...

# %%
# #######-----📈📈📈📈📈 MULTIPLOTTING MAGIC 📉📉📉📉📉📉-----#######

# plt.options.reset() # Resetting options to ensure a clean slate
# #====================================================================
# # CONFIGURE PRINT MANAGER AND SERVER ACCESS
# #====================================================================

# plt.options.x_axis_carrington_lon = False

# server_access.username = None # Set to None for username prompt, or enter 'your_username' to hardcode.
# # plt.options.x_axis_carrington_lon_from_perihelion = True
# # RESET PLOTTING OPTIONS (safe practice!)
# #====================================================================


# # CONFIGURE Titles, Labels and axes
# #====================================================================
# plt.options.use_single_title = True
# plt.options.use_single_x_axis = True

# plt.options.y_label_uses_encounter = False

# plt.options.use_custom_x_axis_label = True
# plt.options.custom_x_axis_label = 'Relative Time (Hours From Noon)'
# # plt.options.single_title_text = "PSP FIELDS Mag RTN Around noon for Multiple Days"
# plt.options.single_title_text = " "

# # CONFIGURE GENERAL PLOT OPTIONS
# #====================================================================

# plt.options.constrained_layout = False  # True or False
# plt.options.save_bbox_inches = 'tight' #options are 'none' and 'tight', this setting overrides the margin settings

# # Plot Sizing
# plt.options.width = 20
# plt.options.height_per_panel = 1.3
# plt.options.hspace = .15

# # TITLE handling
# plt.options.margin_top = 0.85 
# plt.options.margin_bottom = 0.05
# plt.options.title_font_size = 20
# plt.options.title_y_position = 1.05
# plt.options.title_pad = 10

# # Font Sizes and Padding
# plt.options.y_axis_label_font_size = 22
# plt.options.x_axis_label_font_size = 22
# plt.options.x_tick_label_font_size = 17
# plt.options.y_tick_label_font_size = 17
# plt.options.y_label_pad = 8
# plt.options.x_label_pad = 7

# plt.options.y_label_uses_encounter = True
# plt.options.y_label_includes_time = False

# # Rainbow Plot 🌈 -- Uncomment the second set for a single color plot!
# #====================================================================
# plt.options.color_mode = 'rainbow'  # Options: 'default', 'rainbow', 'single'
# # plt.options.color_mode = 'default'  # Options: 'default', 'rainbow', 'single'

# # CONFIGURE Vertical Line
# #====================================================================
# plt.options.draw_vertical_line = True
# plt.options.vertical_line_width = 2
# plt.options.vertical_line_color = 'red'
# plt.options.vertical_line_style = '--'

# # DATA SELECTION FOR PLOTTING
# #====================================================================
# plt.options.use_relative_time = True
# # plt.options.window = '96:00:00.000'
# # plt.options.window = '48:00:00.000'
# plt.options.window = '144:00:00.000'
# plt.options.position = 'around'  # Position, also try 'before' or 'after'
# plt.options.relative_time_step_units = 'hours'
# plt.options.relative_time_step = 6

# # Data Selection
# #====================================================================
# # hcs_multiplot_dates = [
# #     {'hcs_crossing_time': '2022-02-27/05:32:33.000'},  # E15
# #     {'hcs_crossing_time': '2022-06-02/06:16:59.000'},  # E16
# #     {'hcs_crossing_time': '2023-03-17/08:58:16.000'},  # E19
# #     {'hcs_crossing_time': '2023-09-28/18:49:07.000'},  # E21
# #     {'hcs_crossing_time': '2023-12-31/13:20:19.000'},  # E22
# #     {'hcs_crossing_time': '2025-03-23/05:03:04.000'},  # E23
# # ]

# rainbow_encounters = [
#     # {'perihelion': '2018/11/06 03:27:00.000'}, #Enc 1
#     # {'perihelion': '2019/04/04 22:39:00.000'}, #Enc 2
#     # {'perihelion': '2019/09/01 17:50:00.000'}, #Enc 3

#     {'perihelion': '2020/01/29 09:37:00.000'}, #Enc 4
#     {'perihelion': '2020/06/07 08:23:00.000'}, #Enc 5
#     {'perihelion': '2020/09/27 09:16:00.000'}, #Enc 6
#     {'perihelion': '2021/01/17 17:40:00.000'}, #Enc 7
#     {'perihelion': '2021/04/29 08:48:00.000'}, #Enc 8
#     {'perihelion': '2021/08/09 19:11:00.000'}, #Enc 9
#     {'perihelion': '2021/11/21 08:23:00.000'}, #Enc 10
#     {'perihelion': '2022/02/25 15:38:00.000'}, #Enc 11
#     {'perihelion': '2022/06/01 22:51:00.000'}, #Enc 12
#     {'perihelion': '2022/09/06 06:04:00.000'}, #Enc 13
#     {'perihelion': '2022/12/11 13:16:00.000'}, #Enc 14
#     {'perihelion': '2023/03/17 20:30:00.000'}, #Enc 15
#     {'perihelion': '2023/06/22 03:46:00.000'}, #Enc 16
#     {'perihelion': '2023/09/27 23:28:00.000'}, #Enc 17
#     {'perihelion': '2023/12/29 00:56:00.000'}, #Enc 18
#     {'perihelion': '2024/03/30 02:21:00.000'}, #Enc 19 
#     {'perihelion': '2024/06/30 03:47:00.000'}, #Enc 20 
#     {'perihelion': '2024/09/30 05:15:00.000'}, #Enc 21 
#     {'perihelion': '2024/12/24 11:53:00.000'}, #Enc 22 
#     {'perihelion': '2025/03/22 22:42:00.000'}, #Enc 23
# ]

# plt.options.y_label_uses_encounter = True
# plt.options.y_label_includes_time = False
# # Hide the right axis labels (n_ham, etc.)
# plt.options.show_right_axis_label = False

# plot_variable = mag_rtn_4sa.br_norm #You'll need server access to plot this variable!
# # plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!
# # plot_variable = proton.anisotropy #You'll need server access to plot this variable!

# plot_data = [(encounter['perihelion'], plot_variable) for encounter in rainbow_encounters]

# # ✨ ACTIVATE r_sunAXIS! ✨ NEW ✨ And Mutually Exclusive!
# #====================================================================
# # plt.options.x_axis_r_sun = False  # Use radial distance (R_sun)
# # plt.options.x_axis_carrington_lat = False #May still need debugging.
# # plt.options.x_axis_carrington_lon = False #May still need debugging.
# plt.options.use_degrees_from_perihelion =  True #⭐️<---- Working! 

# # Initialize Ham! 🍖 ✨NEW!✨
# #====================================================================
# # plt.options.hamify = False
# # plt.options.r_hand_single_color = '#363737'  # Set your desired hex color
# # plt.options.ham_var = ham.n_ham
# # plt.options.ham_opacity = 0.2


# # Ham Binned Overlay! 🗑️🍖🗑️ ✨NEW!✨
# #====================================================================
# plt.options.ham_binned_degrees_overlay = True
# # ham_binned_degrees_color = '#4682B4' # (steelblue) - ONLY for new binned overlay
# plt.options.ham_binned_degrees_color = '#363737' # (Grey / Default) - ONLY for new binned overlay
# plt.options.ham_binned_degrees_overlay_opacity = 0.5 #- ONLY for new binned overlay
# # plot_variable = mag_rtn_4sa.br #You'll need server access to plot this variable!

# # Draw a horizontal line 🗑️🍖🗑️ ✨NEW!✨
# #====================================================================
# plt.options.draw_horizontal_line = True
# plt.options.horizontal_line_value = 0
# plt.options.horizontal_line_alpha = 0.3  # faint line
# plt.options.horizontal_line_color = 'gray'  # optional

# # Add a drop shadow ✨NEW!✨
# #====================================================================
# plt.options.use_drop_shadow = True
# plt.options.drop_shadow_offset = (2, -2)  # (x, y) in points
# plt.options.drop_shadow_color = 'gray'
# plt.options.drop_shadow_alpha = 0.3

# #A9A9A9 — lighter dark grey
# #696969 — darker dark grey
# #363737 — very dark grey

# plt.options.x_axis_tight = True  # Remove gap between data and axis edges

# # CALL MULTIPLOT WITH UPDATED OPTIONS
# #====================================================================
# multiplot(plot_data); #You'll need server access to plot this variable! ✨Un-comment to Plot!

# %%
save_simple_snapshot('Br_Norm_all_Encounters.pkl')
# Out:
# ✅ Snapshot saved. Included 2 data items from data_cubby.
#    Saved keys: ['mag_rtn_4sa', 'proton']
