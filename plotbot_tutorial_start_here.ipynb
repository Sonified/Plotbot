# %% [markdown]
# # 🤖 Plotbot Comprehensive Tutorial
#
# ## Welcome to Plotbot! 🌞
#
# **Plotbot** is a comprehensive tool for space physics data visualization, audification, and analysis for multiple spacecraft, currently featuring Parker Solar Probe and WIND. Created by Dr. Jaye Verniero and Dr. Robert Alexander.
#
# ### What makes Plotbot special?
# - **Class-based architecture** enabling intuitive data access (`mag_rtn.br`)
# - **Automatic data downloading** from multiple servers
# - **Active calculation caching** - calculate once, reuse forever
# - **Multi-mission support** - PSP, WIND, and extensible framework
# - **Interactive capabilities** - web-based plotting and VDF analysis
# - **Publication-ready plots** with beautiful defaults
#
# ### Core Philosophy
# ```python
# plotbot(trange, mag_rtn.br, 1, proton.anisotropy, 2)
# ```
# This simple call automatically downloads required data and generates professional plots!
#
# ---
#
# **First:** Click in the upper right corner to select the **plotbot_env** environment (Python 3.12.4)
#
# **Then:** Run through this tutorial to learn plotbot's capabilities step by step!

# %% [markdown]
# ## 🚀 Initial Setup & Core Concepts

# %%
# Import plotbot - this initializes all the data classes and core functionality
from plotbot import *
# Out:
# 🕒 Starting import timing session: plotbot_full_initialization
#   ✅ matplotlib.pyplot: 0.388s
#   ✅ numpy: 0.000s
#   🔧 Starting block: core_components
# initialized server_access
# initialized global_tracker
# initialized plot_config
# initialized plot_manager
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized ham_class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# initialized data_cubby.
# CDF classes added to data_cubby type map.
#   ✅ Block 'core_components' completed in 1.012s
#   🔧 Starting block: psp_data_classes
# initialized proton_fits class
# initialized alpha_fits class
#   ✅ Block 'psp_data_classes' completed in 0.002s
#   🔧 Starting block: wind_data_classes
#   ✅ Block 'wind_data_classes' completed in 0.000s
#   🔧 Starting block: data_cubby_registration
#   ✅ Block 'data_cubby_registration' completed in 0.001s
#   🔧 Starting block: auto_register_custom_classes
#   ✅ Block 'auto_register_custom_classes' completed in 0.002s
#   🔧 Starting block: custom_variables
#   ✅ Block 'custom_variables' completed in 0.000s
# 🔉 initialized audifier
#   ✅ from plotbot import audifier: 0.091s
#   🔧 Starting block: enhanced_plt
#   ✅ Block 'enhanced_plt' completed in 0.000s
#   🔧 Starting block: main_plotting_functions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# /Users/robertalexander/GitHub/Plotbot/plotbot/data_download_helpers.py:447: SyntaxWarning: invalid escape sequence '\d'
#   """
# ✅ Imported cdflib, BeautifulSoup, requests, dateutil, and datetime libraries.
#
# 🤖 Plotbot Initialized
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# 📈📉 Multiplot Initialized
#   ✅ Block 'main_plotting_functions' completed in 0.644s
#   🔧 Starting block: cdf_functions
#   ✅ Block 'cdf_functions' completed in 0.001s
#
# 🤖 Plotbot Initialized
# 📈📉 Multiplot Initialized
#    Version: 2025_09_24_v3.40
#    Commit: v3.40 Critical Fix: Complete micromamba installer overhaul - NASA network compatible with anaconda-avoiding flags
#
#
# 🏁 Session 'plotbot_full_initialization' completed in 2.142s
#
# ============================================================
# 📊 IMPORT TIMING REPORT - plotbot_full_initialization
# ============================================================
# Total session time: 2.142s
#
# 🐌 SLOWEST IMPORTS (Top 3):
# --------------------------------------------------
#  1. matplotlib.pyplot               0.388s (81.0%)
#  2. from plotbot import audifier    0.091s (19.0%)
#  3. numpy                           0.000s ( 0.0%)
#
# 🔧 BLOCK TIMING SUMMARY:
# --------------------------------------------------
# core_components                 1.012s (avg: 1.012s, runs: 1)
# psp_data_classes                0.002s (avg: 0.002s, runs: 1)
# wind_data_classes               0.000s (avg: 0.000s, runs: 1)
# data_cubby_registration         0.001s (avg: 0.001s, runs: 1)
# auto_register_custom_classes    0.002s (avg: 0.002s, runs: 1)
# custom_variables                0.000s (avg: 0.000s, runs: 1)
# enhanced_plt                    0.000s (avg: 0.000s, runs: 1)
# main_plotting_functions         0.644s (avg: 0.644s, runs: 1)
# cdf_functions                   0.001s (avg: 0.001s, runs: 1)
#
# ⏰ IMPORT TIMELINE:
# --------------------------------------------------
#  0.000s: matplotlib.pyplot              (+0.388s)
#  0.389s: numpy                          (+0.000s)
#  1.405s: from plotbot import audifier   (+0.091s)
#
# 💡 OPTIMIZATION SUGGESTIONS:
# --------------------------------------------------
# • Matplotlib imports: 0.4s - good candidate for lazy loading
# • Focus optimization on imports >0.5s for maximum impact

# %% [markdown]
# ### 🔧 Core Configuration & Print Manager
#
# Let's configure some key plotbot settings:

# %%
# 🖨️ PRINT MANAGER - Control what plotbot tells you
print_manager.show_status = True     # Show basic status messages (recommended!)
# print_manager.show_debug = True    # Uncomment for detailed debug info

# 🌐 DATA SERVER CONFIGURATION
# config.data_server = 'dynamic'     # Default: SPDF first, Berkeley fallback
# config.data_server = 'spdf'        # SPDF/CDAWeb only (public data)
# config.data_server = 'berkeley'    # Berkeley server only (latest data)

# 📁 CUSTOM DATA DIRECTORY (optional)
# You can point plotbot to a specific data directory:
# import os
# config.data_dir = '/path/to/your/data/folder'

print("✅ Core configuration complete!")
print(f"📂 Data server: {config.data_server}")
print(f"📁 Data directory: {config.data_dir}")
print(f"🖨️ Print manager status: {print_manager.show_status}")
# Out:
# ✅ Core configuration complete!
# 📂 Data server: dynamic
# 📁 Data directory: /Users/robertalexander/GitHub/Plotbot/data
# 🖨️ Print manager status: True

# %% [markdown]
# ## 📈 Basic Plotbot - Your First Plot
#
# Let's create a simple two-panel plot showing magnetic field and proton data:

# %%
# Define a time range during PSP Encounter 4
trange = ['2020-01-29/18:00:00', '2020-01-29/20:00:00']

# Create a basic two-panel plot
plotbot(trange, 
        mag_rtn_4sa.br, 1,       # Radial magnetic field component on panel 1
        proton.anisotropy, 2)    # Proton temperature anisotropy on panel 2

print("🎉 Your first plotbot plot is complete!")
# Out:
# 🤖 Plotbot starting (loading scientific libraries)...
# 🤖 Plotbot libraries loaded, proceeding...
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 🛰️ spi_sf00_l3_mom - acquiring variables: anisotropy
#
# 📥 Acquiring data for 2 regular variables...
# 🕒 TimeRangeTracker: Stored trange ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# 🛰️ mag_RTN_4sa - acquiring variables: br
# 🛰️ spi_sf00_l3_mom - acquiring variables: anisotropy
# Attempting SPDF acquisition path (dynamic mode) for mag_RTN_4sa...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2020-01-29/18:00:00', '2020-01-29/20:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# ✅ DataCubby processed update for mag_rtn_4sa.
# Attempting SPDF acquisition path (dynamic mode) for spi_sf00_l3_mom...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for spi_sf00_l3_mom range ['2020-01-29/18:00:00', '2020-01-29/20:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for spi_sf00_l3_mom...
# ✅ DataCubby processed update for spi_sf00_l3_mom.
# ✅ Complete
# 📈 Plotting mag_rtn_4sa.br
# 📈 Plotting proton.anisotropy
# 🎉 Your first plotbot plot is complete!

# %% [markdown]
# ## 🌐 Interactive Plotting - plotbot_interactive()
#
# Create web-based interactive plots that run inside your notebook:

# %%
# Configure interactive plotting for notebook display
pbi.enabled = True
pbi.port = 8050
# pbi.open_browser = False  # Keep plots in notebook instead of opening browser

print("🌐 Interactive plotting configured!")
# Out:
# 🌐 Interactive plotting configured!

# %%
# Create an interactive plot with both time series and spectral data
plotbot_interactive(trange,
                   mag_rtn_4sa.bt, 1,     # Tangential B-field (line plot)
                   epad.strahl, 2)        # Electron strahl (spectrogram)

print("✨ Interactive plot created! Try clicking on data points for VDF analysis.")
# Out:
# 🚀 plotbot_interactive() starting...
# 🌐 Web display enabled - will open in browser
# 🛰️ spe_sf0_pad - acquiring data...
# 🛰️ mag_RTN_4sa - acquiring data...
# ⚠️ No data in requested time range
# 📥 Acquiring data for 2 variables...
# 🕒 TimeRangeTracker: Stored trange ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# 🛰️ spe_sf0_pad - acquiring variables: strahl
# 🛰️ mag_RTN_4sa - acquiring variables: bt
# Attempting SPDF acquisition path (dynamic mode) for spe_sf0_pad...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for spe_sf0_pad range ['2020-01-29/18:00:00', '2020-01-29/20:00:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for epad...
# ✅ DataCubby processed update for epad.
# mag_RTN_4sa already calculated for the time range: 2020-01-29/18:00:00 to 2020-01-29/20:00:00
# 📤 Using existing mag_RTN_4sa data, calculation/import not needed.
# ✅ Complete
# 🎛️ Creating interactive Dash application...
# 🎛️ Creating interactive Dash application...
# 🔍 [DATA DEBUG] var.subclass_name: strahl
# 🔍 [DATA DEBUG] z_data shape: (6180, 12)
# 🔍 [DATA DEBUG] z_data.T shape: (12, 6180)
# 🔍 [DATA DEBUG] z_data range: 8.49e+00 to 1.02e+01
# 🔍 [Y-AXIS DEBUG] additional_data shape: (515, 12)
# 🔍 [Y-AXIS DEBUG] additional_data ndim: 2
# 🔍 [Y-AXIS DEBUG] First 5 values: [ 7.5 22.5 37.5 52.5 67.5]
# 🔍 [Y-AXIS DEBUG] Last 5 values: [112.5 127.5 142.5 157.5 172.5]
# 🔍 [Y-AXIS DEBUG] Using first row: [ 7.5 22.5 37.5 52.5 67.5] ... [112.5 127.5 142.5 157.5 172.5]
# ✅ Created spectral heatmap for strahl
# ✅ Dash app created successfully!
# 🌐 Launching interactive plot...
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Create an interactive plot with both time series and spectral data
# ----> 2 plotbot_interactive(trange,
#       3                    mag_rtn_4sa.bt, 1,     # Tangential B-field (line plot)
#       4                    epad.strahl, 2)        # Electron strahl (spectrogram)
#       6 print("✨ Interactive plot created! Try clicking on data points for VDF analysis.")
#
# File ~/GitHub/Plotbot/plotbot/plotbot_interactive.py:206, in plotbot_interactive(trange, backend, port, debug, *args)
#     204 print_manager.status("🌐 Launching interactive plot...")
#     205 inline_mode = not pbi.options.web_display  # False = browser, True = inline
# --> 206 app_thread = run_dash_app(app, port=port, debug=debug, inline=inline_mode)
#     208 print_manager.status("✅ plotbot_interactive() complete!")
#     209 print_manager.status("📌 Click on any data point to generate VDF analysis!")
#
# File ~/GitHub/Plotbot/plotbot/plotbot_dash.py:539, in run_dash_app(app, port, debug, inline)
#     537 # Give server time to start
#     538 import time
# --> 539 time.sleep(2)
#     541 # Open browser
#     542 try:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 📊 Multiplot - Multi-Panel Time Analysis
#
# Compare the same variable across different encounters or time periods:

# %%
# Define encounter times (we'll focus on encounters 11-16)
encounter_times = [
    # '2021/08/09 19:08:00.000',  # Enc 8
    # '2021/11/21 09:24:00.000',  # Enc 9  
    # '2022/02/25 08:02:00.000',  # Enc 10
    '2022/09/06 11:50:00.000',  # Enc 11
    '2022/12/11 13:46:00.000',  # Enc 12
    '2023/03/17 17:26:00.000',  # Enc 13
    '2023/06/22 05:49:00.000',  # Enc 14
    '2023/09/27 13:49:00.000',  # Enc 15
    '2023/12/30 00:53:00.000',  # Enc 16
]

# Create plot_data list for multiplot
plot_data = [(time, mag_rtn_4sa.bmag) for time in encounter_times]

# Reset multiplot options for clean slate
plt.options.reset()

# Basic multiplot
multiplot(plot_data)

print(f"📊 Multiplot created for {len(encounter_times)} encounters!")
# Out:
# 🚀 PROCESSING ENCOUNTER E13 (Panel 1) - Center time: 2022/09/06 11:50:00.000
# 🕒 TimeRangeTracker: Stored trange ['2022-09-06/11:44:00.000000', '2022-09-06/11:56:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: bmag
# Attempting SPDF acquisition path (dynamic mode) for mag_RTN_4sa...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2022-09-06/11:44:00', '2022-09-06/11:56:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ Complete
# ✅ ENCOUNTER E13 (Panel 1) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E13: Variable contains 3296 data points
# 🚀 PROCESSING ENCOUNTER E14 (Panel 2) - Center time: 2022/12/11 13:46:00.000
# 🕒 TimeRangeTracker: Stored trange ['2022-12-11/13:40:00.000000', '2022-12-11/13:52:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: bmag
# Attempting SPDF acquisition path (dynamic mode) for mag_RTN_4sa...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2022-12-11/13:40:00', '2022-12-11/13:52:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ Complete
# ✅ ENCOUNTER E14 (Panel 2) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E14: Variable contains 3295 data points
# 🚀 PROCESSING ENCOUNTER E15 (Panel 3) - Center time: 2023/03/17 17:26:00.000
# 🕒 TimeRangeTracker: Stored trange ['2023-03-17/17:20:00.000000', '2023-03-17/17:32:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: bmag
# Attempting SPDF acquisition path (dynamic mode) for mag_RTN_4sa...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2023-03-17/17:20:00', '2023-03-17/17:32:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ Complete
# ✅ ENCOUNTER E15 (Panel 3) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E15: Variable contains 3296 data points
# 🚀 PROCESSING ENCOUNTER E16 (Panel 4) - Center time: 2023/06/22 05:49:00.000
# 🕒 TimeRangeTracker: Stored trange ['2023-06-22/05:43:00.000000', '2023-06-22/05:55:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: bmag
# Attempting SPDF acquisition path (dynamic mode) for mag_RTN_4sa...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2023-06-22/05:43:00', '2023-06-22/05:55:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ Complete
# ✅ ENCOUNTER E16 (Panel 4) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E16: Variable contains 3296 data points
# 🚀 PROCESSING ENCOUNTER E17 (Panel 5) - Center time: 2023/09/27 13:49:00.000
# 🕒 TimeRangeTracker: Stored trange ['2023-09-27/13:43:00.000000', '2023-09-27/13:55:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: bmag
# Attempting SPDF acquisition path (dynamic mode) for mag_RTN_4sa...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2023-09-27/13:43:00', '2023-09-27/13:55:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ Complete
# ✅ ENCOUNTER E17 (Panel 5) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E17: Variable contains 3295 data points
# 🚀 PROCESSING ENCOUNTER E18 (Panel 6) - Center time: 2023/12/30 00:53:00.000
# 🕒 TimeRangeTracker: Stored trange ['2023-12-30/00:47:00.000000', '2023-12-30/00:59:00.000000']
# 🛰️ mag_RTN_4sa - acquiring variables: bmag
# Attempting SPDF acquisition path (dynamic mode) for mag_RTN_4sa...
# DEBUG: pyspedas module attributes: ['CDAWeb', 'HoverTime', 'MPLPlotter', 'OrderedDict', 'ace', 'add', 'add_across', 'akebono', 'analysis', 'annotate', 'avg_data', 'avg_res_data', 'barrel', 'cart2spc', 'cart_to_sphere', 'cdagui', 'cdagui_tools', 'cdf_to_tplot', 'check_downloaded_file', 'classify_null_type', 'clean_spikes', 'clip', 'cluster', 'cnofs', 'compare_versions', 'cotrans', 'cotrans_get_coord', 'cotrans_set_coord', 'cotrans_tools', 'count_traces', 'crop', 'csswe', 'ctime', 'dailynames', 'data_att_getters_setters', 'data_exists', 'data_quants', 'databar', 'de2', 'deflag', 'degap', 'del_data', 'deriv_data', 'derive', 'divide', 'download', 'download_file', 'download_ftp', 'dpwrspc', 'dscovr', 'elfin', 'environ', 'equator_s', 'erg', 'exporters', 'extra_layouts', 'fac_matrix_make', 'fast', 'find_datasets', 'find_ip_address', 'find_magnetic_nulls_fote', 'format_sandbox', 'full_module_path', 'geotail', 'get', 'get_coords', 'get_data', 'get_timespan', 'get_units', 'get_ylimits', 'goes', 'gsm2lmn', 'hapi', 'hapi_tools', 'highlight', 'hover_time', 'image', 'import_module', 'imported_module', 'importers', 'interactive_window', 'interp_nan', 'interpol', 'is_gzip', 'is_pseudovariable', 'join_vec', 'kompsat', 'kompsat_load', 'kyoto', 'lanl', 'libs', 'lim_info', 'lingradest', 'link', 'lmn_matrix_make', 'load_leap_table', 'logger', 'logger_fmt', 'logger_handler', 'logging', 'logging_date_fmt', 'logging_format', 'logging_level', 'makegap', 'maven', 'maven_load', 'mica', 'minvar', 'minvar_matrix_make', 'mms', 'mms_cotrans_lmn', 'mms_cotrans_qrotate', 'mms_cotrans_qtransformer', 'mms_eis_pad', 'mms_feeps_gpd', 'mms_feeps_pad', 'mms_hpca_calc_anodes', 'mms_hpca_spin_sum', 'mms_load_aspoc', 'mms_load_dsp', 'mms_load_edi', 'mms_load_edp', 'mms_load_eis', 'mms_load_feeps', 'mms_load_fgm', 'mms_load_fpi', 'mms_load_fsm', 'mms_load_hpca', 'mms_load_mec', 'mms_load_scm', 'mms_load_state', 'mms_overview_plot', 'mms_part_getspec', 'mms_part_slice2d', 'mms_qcotrans', 'moments_3d', 'mpause_2', 'mpause_t96', 'mtoq', 'multiply', 'netcdf_to_tplot', 'noaa', 'noaa_load_kp', 'omni', 'options', 'os', 'particles', 'poes', 'polar', 'projects', 'psp', 'pwr_spec', 'pwrspc', 'qcompose', 'qconj', 'qdecompose', 'qdotp', 'qmult', 'qnorm', 'qnormalize', 'qslerp', 'qtom', 'qvalidate', 'rbsp', 'replace_data', 'replace_metadata', 'rotmat_get_coords', 'rotmat_set_coords', 'secs', 'set_coords', 'set_units', 'slice1d_plot', 'slice2d', 'slice2d_plot', 'sm2mlt', 'smooth', 'soho', 'solo', 'spc2cart', 'spd_pgs_do_fac', 'spd_pgs_moments', 'spd_pgs_moments_tplot', 'spd_pgs_regrid', 'spd_pgs_v_shift', 'spec_mult', 'spedas_colorbar', 'sphere_to_cart', 'split_vec', 'st5', 'static_tavg_window', 'static_window', 'stereo', 'store', 'store_data', 'sts_to_tplot', 'submodule', 'submodules', 'subtract', 'subtract_average', 'subtract_median', 'swarm', 'sys', 'tcopy', 'tcrossp', 'tdeflag', 'tdotp', 'tdpwrspc', 'themis', 'time_clip', 'time_datetime', 'time_domain_filter', 'time_double', 'time_ephemeris', 'time_float', 'time_float_one', 'time_string', 'time_string_one', 'timebar', 'timespan', 'timestamp', 'tindex_byname', 'tinterp', 'tinterpol', 'tkm2re', 'tlimit', 'tname_byindex', 'tnames', 'tnormalize', 'tplot', 'tplot_copy', 'tplot_math', 'tplot_names', 'tplot_opt_glob', 'tplot_options', 'tplot_rename', 'tplot_restore', 'tplot_save', 'tplot_utilities', 'tplot_wildcard_expand', 'tpwrspc', 'tres', 'tsmooth', 'tvector_rotate', 'tvectot', 'twavpol', 'twins', 'ulysses', 'using_graphics', 'utilities', 'var_label_panel', 'version', 'vires', 'wavelet', 'wildcard_expand', 'wildcard_routines', 'wind', 'xdegap', 'xlim', 'xr', 'xyz_to_polar', 'yclip', 'ylim', 'zlim']
# ☑️ - CDF Data import complete for mag_RTN_4sa range ['2023-12-30/00:47:00', '2023-12-30/00:59:00'].
#
# 📥 Requesting DataCubby to update/merge global instance for mag_rtn_4sa...
# ✅ DataCubby processed update for mag_rtn_4sa.
# ✅ Complete
# ✅ ENCOUNTER E18 (Panel 6) DATA SUCCESSFULLY LOADED!
# ✅ ENCOUNTER E18: Variable contains 3296 data points
# Using constrained_layout=True - letting matplotlib handle all spacing automatically.
# 🎨 PLOTTING ENCOUNTER E13 (Panel 1) - Center time: 2022/09/06 11:50:00.000
# ✅ ENCOUNTER E13: Ready to plot with 3296 data points
# 🎨 PLOTTING ENCOUNTER E14 (Panel 2) - Center time: 2022/12/11 13:46:00.000
# ✅ ENCOUNTER E14: Ready to plot with 3295 data points
# 🎨 PLOTTING ENCOUNTER E15 (Panel 3) - Center time: 2023/03/17 17:26:00.000
# ✅ ENCOUNTER E15: Ready to plot with 3296 data points
# 🎨 PLOTTING ENCOUNTER E16 (Panel 4) - Center time: 2023/06/22 05:49:00.000
# ✅ ENCOUNTER E16: Ready to plot with 3296 data points
# 🎨 PLOTTING ENCOUNTER E17 (Panel 5) - Center time: 2023/09/27 13:49:00.000
# ✅ ENCOUNTER E17: Ready to plot with 3295 data points
# 🎨 PLOTTING ENCOUNTER E18 (Panel 6) - Center time: 2023/12/30 00:53:00.000
# ✅ ENCOUNTER E18: Ready to plot with 3296 data points
# Generating multiplot...
#
# 📊 Multiplot created for 6 encounters!

# %% [markdown]
# ## 🗂️ Data Cubby & Snapshots - Never Calculate Twice
#
# Plotbot's data cubby automatically caches calculations. You can also save snapshots for persistent storage:

# %%
# First, let's load some data to demonstrate caching
print("🔄 Loading data for the first time...")
get_data(trange, 'proton')  # This will download and calculate

print("✅ Data loaded and cached in data_cubby!")
print("🚀 Try running the same command again - it will be instant!")

# Demonstrate instant access
get_data(trange, 'proton')  # This will use cached data
print("⚡ That was instant - data retrieved from cache!")
# Out:
# 🔄 Loading data for the first time...
# ✅ Complete
# ✅ Data loaded and cached in data_cubby!
# 🚀 Try running the same command again - it will be instant!
# ✅ Complete
# ⚡ That was instant - data retrieved from cache!

# %%
# Save a snapshot of your current session for future use
snapshot_name = 'tutorial_session.pkl'

# Save current calculations
save_simple_snapshot(snapshot_name)
print(f"💾 Session saved as {snapshot_name}")

# You can load this snapshot later with:
# load_simple_snapshot(snapshot_name)
print("💡 Use load_simple_snapshot() to restore this session later!")
# Out:
# ✅ Snapshot saved. Included 3 data items from data_cubby.
#    Saved keys: ['mag_rtn_4sa', 'epad', 'proton']
# 💾 Session saved as tutorial_session.pkl
# 💡 Use load_simple_snapshot() to restore this session later!

# %% [markdown]
# ## 🔄 Showdahodo - Hodogram/Scatter Analysis
#
# Visualize relationships between variables with hodogram (scatter) plots:

# %%
# Create a 2D hodogram showing magnetic field components
showdahodo(trange, 
           mag_rtn_4sa.br,        # X-axis: Radial B-field
           mag_rtn_4sa.bt,        # Y-axis: Tangential B-field
           color_var=proton.temperature)  # Color by proton temperature

print("🔄 Hodogram complete! Notice how variables relate to each other.")
# Out:
# 🕒 TimeRangeTracker: Stored trange ['2020-01-29/18:00:00', '2020-01-29/20:00:00']
# 🛰️ spi_sf00_l3_mom - acquiring variables: temperature
# 🛰️ mag_RTN_4sa - acquiring variables: br, bt
# spi_sf00_l3_mom already calculated for the time range: 2020-01-29/18:00:00 to 2020-01-29/20:00:00
# 📤 Using existing spi_sf00_l3_mom data, calculation/import not needed.
# mag_RTN_4sa already calculated for the time range: 2020-01-29/18:00:00 to 2020-01-29/20:00:00
# 📤 Using existing mag_RTN_4sa data, calculation/import not needed.
# ✅ Complete
# 🔄 Hodogram complete! Notice how variables relate to each other.

# %% [markdown]
# ## 🌪️ VDF Analysis - Velocity Distribution Functions
#
# Analyze particle velocity distributions with the `vdyes()` function:

# %%
# Single time point for VDF analysis - creates static 3-panel plot
vdf_time = '2020/01/29 18:30:00.000'

# Configure VDF parameters
psp_span_vdf.theta_smart_padding = 150
psp_span_vdf.enable_zero_clipping = False
psp_span_vdf.vdf_colormap = 'plasma'

# Create VDF plot
fig = vdyes([vdf_time, vdf_time])  # Same time twice for single plot

print("🌪️ VDF plot created showing theta-plane, phi-plane, and collapsed distributions!")
# Out:
# 24-Sep-25 16:18:58: Local files found: ['/Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l2/spi_sf00_8dx32ex8a/2020/psp_swp_spi_sf00_l2_8dx32ex8a_20200129_v04.cdf', '/Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l3/spi_sf00_l3_mom/2020/psp_swp_spi_sf00_L3_mom_20200129_v04.cdf']
# 🚀 vdyes() - Processing trange: ['2020/01/29 18:30:00.000', '2020/01/29 18:30:00.000']
# 📡 Downloading PSP SPAN-I data using proven pyspedas approach...
# ✅ Using cached VDF files (no download needed)
# 📁 Downloaded: /Users/robertalexander/GitHub/Plotbot/data/psp/sweap/spi/l2/spi_sf00_8dx32ex8a/2020/psp_swp_spi_sf00_l2_8dx32ex8a_20200129_v04.cdf
# 📊 Found 0 time points in trange: ['2020/01/29 18:30:00.000', '2020/01/29 18:30:00.000']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 10
#       7 psp_span_vdf.vdf_colormap = 'plasma'
#       9 # Create VDF plot
# ---> 10 fig = vdyes([vdf_time, vdf_time])  # Same time twice for single plot
#      12 print("🌪️ VDF plot created showing theta-plane, phi-plane, and collapsed distributions!")
#
# File ~/GitHub/Plotbot/plotbot/vdyes.py:159, in vdyes(trange, force_static)
#     157 # Decide mode based on available data
#     158 if n_time_points == 0:
# --> 159     raise ValueError(f"No VDF data found in time range {trange}")
#     160 elif n_time_points == 1 or force_static:
#     161     print_manager.status(f"📈 Static mode: {n_time_points} time point(s) → single VDF plot")
#
# ValueError: No VDF data found in time range ['2020/01/29 18:30:00.000', '2020/01/29 18:30:00.000']

# %% [markdown]
# ## 🔊 Audification - Hear Your Data
#
# Convert time series data into audio for sonification analysis:

# %%
# Create audio from magnetic field data
# Note: This creates WAV files in your audio_files directory

# Configure audification parameters
audifier.audio_duration = 10.0    # 10 second audio file
audifier.sample_rate = 44100      # Standard audio sample rate
audifier.frequency_range = (200, 2000)  # Audible frequency range

# Create audio from magnetic field magnitude
# audifier(mag_rtn_4sa.bmag, trange)  # Uncomment to create audio file

print("🔊 Audification configured!")
print("💡 Uncomment the audifier() line above to create audio files")
print("📁 Audio files will be saved to the audio_files/ directory")

# %% [markdown]
# ## 🎨 Custom Variables - Create Your Own Quantities
#
# Combine existing variables to create new derived quantities:

# %%
# Import custom variable function
from plotbot.data_classes.custom_variables import custom_variable

# Create a custom variable: Temperature anisotropy normalized by B magnitude
ta_over_b = custom_variable('TempAniso_over_Bmag', 
                           proton.anisotropy / mag_rtn_4sa.bmag)

# Customize its appearance
ta_over_b.y_label = 'T⊥/T∥ / |B|'
ta_over_b.color = 'purple'

# Plot it like any other variable!
plotbot(trange, ta_over_b, 1)

print("🎨 Custom variable created and plotted!")
print(f"📊 Your custom variable is now globally accessible as: {ta_over_b.name}")

# %% [markdown]
# ## 📋 CDF Import - Automatic Class Generation
#
# Plotbot can automatically generate classes from any CDF (Common Data Format) files:

# %%
# Demonstrate CDF integration capabilities
# Note: This shows the functions - you would need actual CDF files to run

print("📋 CDF Integration Features:")
print("")
print("🔍 scan_cdf_directory('path/to/cdf/files/')")
print("   → Automatically scans directory and generates classes")
print("")
print("📄 cdf_to_plotbot('specific_file.cdf')")
print("   → Generates class for a specific CDF file")
print("")
print("💡 Generated classes work identically to built-in plotbot classes!")
print("")
print("Example usage after generating CDF classes:")
print("plotbot(trange, my_cdf_class.my_variable, 1)")

# Show where CDF files should be placed
import os
cdf_path = os.path.join(config.data_dir, 'cdf_files')
print(f"")
print(f"📁 Place your CDF files in: {cdf_path}")

# %% [markdown]
# ## 🚀 Advanced Multiplot - Positional Plotting & Presets
#
# Explore advanced multiplot features including positional x-axes and preset configurations:

# %% [markdown]
# ### 📍 Positional X-Axes - Plot vs Distance/Position
#
# Instead of time, plot against spacecraft position:

# %%
# Reset options for clean slate
plt.options.reset()

# ✨ ACTIVATE degrees from perihelion plotting ✨
plt.options.use_degrees_from_perihelion = True

# Ensure other positional options are disabled (mutually exclusive)
# plt.options.x_axis_r_sun = True              # Uncomment to plot vs radial distance
# plt.options.x_axis_carrington_lon = True     # Uncomment to plot vs Carrington longitude
# plt.options.x_axis_carrington_lat = True     # Uncomment to plot vs Carrington latitude

# Advanced positioning options
# plt.options.x_axis_positional_range = (0, 360)  # Uncomment to set fixed range
# plt.options.use_single_x_axis = True             # Uncomment for common x-axis
# plt.options.positional_tick_density = 2         # Uncomment for denser ticks

# Color options
plt.options.color_mode = 'rainbow'
# plt.options.color_mode = 'single'      # Uncomment for single color
# plt.options.single_color = 'blue'      # Uncomment to set specific color

# Create positional multiplot
plot_data = [(time, mag_rtn_4sa.bmag) for time in encounter_times]
multiplot(plot_data)

print("📍 Advanced positional multiplot created!")
print("💡 Try uncommenting different positional options above to experiment!")

# %% [markdown]
# ### 🎛️ Plot Presets - Professional Configurations
#
# Use predefined presets for different output types:

# %%
# Reset options
plt.options.reset()

# ✨ SAVE OUTPUT PRESETS ✨
plt.options.save_output = True

# Preset options (uncomment one to try):
plt.options.save_preset = 'medium'        # Medium resolution (default)
# plt.options.save_preset = 'high_res'    # High resolution for publications
# plt.options.save_preset = 'poster'      # Large format for posters
# plt.options.save_preset = 'presentation' # Optimized for presentations

# Custom dimensions (alternative to presets)
# plt.options.output_dimensions = (1920, 1080)  # Custom width x height

# Additional save options
plt.options.save_bbox_inches = 'tight'
plt.options.save_dpi = 300
# plt.options.save_format = 'png'         # Default format
# plt.options.save_format = 'pdf'         # Vector format

# Create a plot with preset applied
plotbot(trange, 
        mag_rtn_4sa.bmag, 1,
        proton.temperature, 2)

print(f"🎛️ Plot created with '{plt.options.save_preset}' preset!")
print("💡 Try uncommenting different presets above to see the differences")
print("📁 Output files saved to plots/ directory")

# %% [markdown]
# ## 🎉 Tutorial Complete!
#
# Congratulations! You've now explored the core capabilities of Plotbot:
#
# ✅ **Basic plotting** - Simple, beautiful time series plots
# ✅ **Interactive plotting** - Web-based analysis with click-to-VDF
# ✅ **Multiplot** - Multi-panel time comparisons
# ✅ **Data management** - Caching and snapshots
# ✅ **Hodograms** - Variable relationship analysis
# ✅ **VDF analysis** - Velocity distribution functions
# ✅ **Audification** - Audio representation of data
# ✅ **Custom variables** - Create derived quantities
# ✅ **CDF integration** - Automatic class generation
# ✅ **Advanced features** - Positional plotting and presets
#
# ### 🚀 Next Steps
#
# Explore the specific example notebooks for deeper dives into each capability:
#
# - `plotbot_interactive_example.ipynb` - Advanced interactive features
# - `plotbot_multiplot_examples.ipynb` - Comprehensive multiplot options
# - `plotbot_vdf_examples.ipynb` - Detailed VDF analysis
# - `plotbot_custom_variable_examples.ipynb` - Advanced custom variables
# - `plotbot_cdf_import_examples.ipynb` - CDF integration workflows
# - And many more in the `example_notebooks/` directory!
#
# ### 💡 Tips for Success
#
# 1. **Use `print_manager.show_status = True`** to see what plotbot is doing
# 2. **Save snapshots** of your work with `save_simple_snapshot()`
# 3. **Experiment with presets** for different output needs
# 4. **Combine features** - use custom variables in multiplots, create interactive hodograms, etc.
# 5. **Check the documentation** in the README files for comprehensive details
#
# **Happy Plotbotting!** 🤖✨
