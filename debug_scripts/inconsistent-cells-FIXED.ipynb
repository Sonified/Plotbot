# %%
import numpy as np
import plotbot
# Out:
# 🕒 Starting import timing session: plotbot_full_initialization
#   ✅ numpy: 0.000s
#   🔧 Starting block: core_components
# initialized server_access
# initialized global_tracker
# initialized plot_config
# initialized data_cubby.
# initialized plot_manager
# CDF classes added to data_cubby type map.
#   ✅ Block 'core_components' completed in 1.412s
#   🔧 Starting block: psp_data_classes
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized proton_fits class
# initialized alpha_fits class
# initialized ham_class
#   ✅ Block 'psp_data_classes' completed in 0.007s
#   🔧 Starting block: wind_data_classes
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
#   ✅ Block 'wind_data_classes' completed in 0.005s
#   🔧 Starting block: data_cubby_registration
#   ✅ Block 'data_cubby_registration' completed in 0.001s
# ...

# %%
### We first define the plotbot.custom_variable, phi_B 
# Using lambda ensures the expression is evaluated AFTER data loads
phi_B = plotbot.custom_variable(
    'phi_B',
    lambda: np.degrees(np.arctan2(plotbot.mag_rtn_4sa.br, plotbot.mag_rtn_4sa.bn)) + 180
) 
phi_B.y_label = r'$\phi_B \ (\circ)$'
phi_B.color = 'purple'
phi_B.plot_type = 'scatter'
phi_B.marker_style = 'o'
phi_B.marker_size = 3

# %%
### Next, we plotbot.plotbot a trange, and we call some variables, including the custom_variable
trange = ['12-20-2024/00:00:000','12-24-2024/00:00:000']

plotbot.plotbot(trange,plotbot.mag_rtn_4sa.br,1,plotbot.mag_rtn_4sa.bt,1,plotbot.mag_rtn_4sa.bn,1,
                plotbot.phi_B,2)
# Out:
# 🎯 Set requested_trange on mag_rtn_4sa.br: ['12-20-2024/00:00:000', '12-24-2024/00:00:000']
# 🎯 Set requested_trange on mag_rtn_4sa.bt: ['12-20-2024/00:00:000', '12-24-2024/00:00:000']
# 🎯 Set requested_trange on mag_rtn_4sa.bn: ['12-20-2024/00:00:000', '12-24-2024/00:00:000']
# 🎯 Set requested_trange on custom_variables.phi_B: ['12-20-2024/00:00:000', '12-24-2024/00:00:000']

# %%
### Let's redefine phi_B!
# Using lambda ensures the expression is evaluated AFTER data loads
phi_B = plotbot.custom_variable(
    'phi_B',
    lambda: np.degrees(np.arctan2(plotbot.mag_rtn_4sa.br, plotbot.mag_rtn_4sa.bn))
) 
phi_B.y_label = r'$\phi_B \ (\circ)$'
phi_B.color = 'purple'
phi_B.plot_type = 'scatter'
phi_B.marker_style = 'o'
phi_B.marker_size = 3

# %%
### Let's run plotbot.plotbot on the same trange
trange = ['12-20-2024/00:00:000','12-24-2024/00:00:000']

plotbot.plotbot(trange,plotbot.mag_rtn_4sa.br,1,plotbot.phi_B,2)
# Out:
# 🎯 Set requested_trange on mag_rtn_4sa.br: ['12-20-2024/00:00:000', '12-24-2024/00:00:000']
# 🎯 Set requested_trange on custom_variables.phi_B: ['12-20-2024/00:00:000', '12-24-2024/00:00:000']
